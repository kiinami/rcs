# %%
import os

from utils import *
from Recommenders.DataIO import DataIO
from Evaluation.Evaluator import EvaluatorHoldout

# %%
data = load_data()
users = load_users()
data, num_users, num_items, mapping_user_id = preprocess_data(data)
data_train, data_validation, data_test = split_data(
    data,
    num_users=num_users,
    num_items=num_items,
    validation_percentage=0.1,
    testing_percentage=0.20
)

# %%
evaluator_validation = EvaluatorHoldout(data_validation, cutoff_list=[10])
evaluator_test = EvaluatorHoldout(data_test, cutoff_list=[10])
# Out:
# EvaluatorHoldout: Ignoring 4185 (33.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 2132 (16.9%) Users that have less than 1 test interactions

# %%
from skopt.space import Real, Integer, Categorical

hyperparameters_range_dictionary = {
    "topK": Integer(5, 1000),
    "shrink": Integer(0, 1000),
    "similarity": Categorical(["cosine"]),
    "normalize": Categorical([True, False]),
}

# %%
from Recommenders.KNN.ItemKNNCFRecommender import ItemKNNCFRecommender
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

recommender_class = ItemKNNCFRecommender

hyperparameterSearch = SearchBayesianSkopt(recommender_class,
                                         evaluator_validation=evaluator_validation,
                                         evaluator_test=evaluator_test)
# Out:
# 2023-11-16 12:19:06.220469: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-11-16 12:19:06.220487: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs

recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [data_train],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {},
    EARLYSTOPPING_KEYWORD_ARGS = {},
)

# %%
recommender_input_args_last_test = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [data_validation],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {},
    EARLYSTOPPING_KEYWORD_ARGS = {},
)

# %%
output_folder_path = "result_experiments/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 50
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
hyperparameterSearch.search(recommender_input_args,
                       recommender_input_args_last_test = recommender_input_args_last_test,
                       hyperparameter_search_space = hyperparameters_range_dictionary,
                       n_cases = n_cases,
                       n_random_starts = n_random_starts,
                       save_model = "best",
                       output_folder_path = output_folder_path, # Where to save the results
                       output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
                       metric_to_optimize = metric_to_optimize,
                       cutoff_to_optimize = cutoff_to_optimize,
                      )
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 55, 'shrink': 606, 'similarity': 'cosine', 'normalize': False}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 11168.07 column/sec. Elapsed time 1.99 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 5.48 sec. Users per second: 1542
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 55, 'shrink': 606, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0269845, PRECISION_RECALL_MIN_DEN: 0.0852423, RECALL: 0.0832942, MAP: 0.0106849, MAP_MIN_DEN: 0.0348020, MRR: 0.0912916, NDCG: 0.0607616, F1: 0.0407631, HIT_RATE: 0.2291494, ARHR_ALL_HITS: 0.0987236, NOVELTY: 0.0042917, AVERAGE_POPULARITY: 0.5163746, DIVERSITY_MEAN_INTER_LIST: 0.7442185, DIVERSITY_HERFINDAHL: 0.9744130, COVERAGE_ITEM: 0.1707317, COVERAGE_ITEM_HIT: 0.0151202, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1532679, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0128894, SHANNON_ENTROPY: 6.9595880, RATIO_DIVERSITY_HERFINDAHL: 0.9747668, RATIO_DIVERSITY_GINI: 0.0371870, RATIO_SHANNON_ENTROPY: 0.5363381, RATIO_AVERAGE_POPULARITY: 4.2283418, RATIO_NOVELTY: 0.2694757,
#
# EvaluatorHoldout: Processed 10506 (100.0%) in 6.45 sec. Users per second: 1630
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 55, 'shrink': 606, 'similarity': 'cosine', 'normalize': False} - results:
# CUTOFF: 10 - PRECISION: 0.0546069, PRECISION_RECALL_MIN_DEN: 0.1033613, RECALL: 0.0903407, MAP: 0.0245107, MAP_MIN_DEN: 0.0468230, MRR: 0.1705704, NDCG: 0.0898804, F1: 0.0680691, HIT_RATE: 0.3763564, ARHR_ALL_HITS: 0.2036478, NOVELTY: 0.0043981, AVERAGE_POPULARITY: 0.4889069, DIVERSITY_MEAN_INTER_LIST: 0.7735863, DIVERSITY_HERFINDAHL: 0.9773513, COVERAGE_ITEM: 0.2356674, COVERAGE_ITEM_HIT: 0.0237602, ITEMS_IN_GT: 0.8000180, COVERAGE_USER: 0.8313024, COVERAGE_USER_HIT: 0.3128660, USERS_IN_GT: 0.8313024, DIVERSITY_GINI: 0.0193269, SHANNON_ENTROPY: 7.3303092, RATIO_DIVERSITY_HERFINDAHL: 0.9777061, RATIO_DIVERSITY_GINI: 0.0557596, RATIO_SHANNON_ENTROPY: 0.5649076, RATIO_AVERAGE_POPULARITY: 4.0034219, RATIO_NOVELTY: 0.2761568,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNCFRecommender
#
# ItemKNNCFRecommender: Saving model in file 'result_experiments/ItemKNNCFRecommender_best_model'
# ItemKNNCFRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 14.7148
# Function value obtained: -0.0107
# Current minimum: -0.0107
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 660, 'shrink': 794, 'similarity': 'cosine', 'normalize': False}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 11150.75 column/sec. Elapsed time 1.99 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 7.21 sec. Users per second: 1172
# SearchBayesianSkopt: Config 1 is suboptimal. Config: {'topK': 660, 'shrink': 794, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0228440, PRECISION_RECALL_MIN_DEN: 0.0737423, RECALL: 0.0720296, MAP: 0.0085636, MAP_MIN_DEN: 0.0285304, MRR: 0.0745413, NDCG: 0.0506614, F1: 0.0346870, HIT_RATE: 0.1979179, ARHR_ALL_HITS: 0.0798431, NOVELTY: 0.0041220, AVERAGE_POPULARITY: 0.6301058, DIVERSITY_MEAN_INTER_LIST: 0.5161401, DIVERSITY_HERFINDAHL: 0.9516079, COVERAGE_ITEM: 0.0823508, COVERAGE_ITEM_HIT: 0.0081001, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1323785, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0035521, SHANNON_ENTROPY: 5.4530919, RATIO_DIVERSITY_HERFINDAHL: 0.9519534, RATIO_DIVERSITY_GINI: 0.0102482, RATIO_SHANNON_ENTROPY: 0.4202405, RATIO_AVERAGE_POPULARITY: 5.1596312, RATIO_NOVELTY: 0.2588229,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 9.4625
# Function value obtained: -0.0086
# Current minimum: -0.0107
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 326, 'shrink': 767, 'similarity': 'cosine', 'normalize': False}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 11175.79 column/sec. Elapsed time 1.99 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 6.73 sec. Users per second: 1256
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'topK': 326, 'shrink': 767, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0240270, PRECISION_RECALL_MIN_DEN: 0.0770807, RECALL: 0.0753302, MAP: 0.0090396, MAP_MIN_DEN: 0.0303223, MRR: 0.0780074, NDCG: 0.0533624, F1: 0.0364333, HIT_RATE: 0.2069088, ARHR_ALL_HITS: 0.0839443, NOVELTY: 0.0040990, AVERAGE_POPULARITY: 0.6193848, DIVERSITY_MEAN_INTER_LIST: 0.5498929, DIVERSITY_HERFINDAHL: 0.9549828, COVERAGE_ITEM: 0.1065161, COVERAGE_ITEM_HIT: 0.0097201, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1383922, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0052162, SHANNON_ENTROPY: 5.6961091, RATIO_DIVERSITY_HERFINDAHL: 0.9553295, RATIO_DIVERSITY_GINI: 0.0150493, RATIO_SHANNON_ENTROPY: 0.4389686, RATIO_AVERAGE_POPULARITY: 5.0718421, RATIO_NOVELTY: 0.2573815,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 8.9200
# Function value obtained: -0.0090
# Current minimum: -0.0107
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 23, 'shrink': 575, 'similarity': 'cosine', 'normalize': True}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 11048.63 column/sec. Elapsed time 2.01 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 4.37 sec. Users per second: 1934
# SearchBayesianSkopt: New best config found. Config 3: {'topK': 23, 'shrink': 575, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0322489, PRECISION_RECALL_MIN_DEN: 0.0997657, RECALL: 0.0974202, MAP: 0.0132397, MAP_MIN_DEN: 0.0411193, MRR: 0.1094428, NDCG: 0.0719249, F1: 0.0484571, HIT_RATE: 0.2649947, ARHR_ALL_HITS: 0.1202598, NOVELTY: 0.0045578, AVERAGE_POPULARITY: 0.3732543, DIVERSITY_MEAN_INTER_LIST: 0.9044756, DIVERSITY_HERFINDAHL: 0.9904369, COVERAGE_ITEM: 0.1939969, COVERAGE_ITEM_HIT: 0.0221402, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1772432, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0196778, SHANNON_ENTROPY: 8.2732265, RATIO_DIVERSITY_HERFINDAHL: 0.9907965, RATIO_DIVERSITY_GINI: 0.0567721, RATIO_SHANNON_ENTROPY: 0.6375732, RATIO_AVERAGE_POPULARITY: 3.0563989, RATIO_NOVELTY: 0.2861862,
#
# EvaluatorHoldout: Processed 10506 (100.0%) in 5.24 sec. Users per second: 2004
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 23, 'shrink': 575, 'similarity': 'cosine', 'normalize': True} - results:
# CUTOFF: 10 - PRECISION: 0.0644203, PRECISION_RECALL_MIN_DEN: 0.1169173, RECALL: 0.1007856, MAP: 0.0314636, MAP_MIN_DEN: 0.0566843, MRR: 0.2027555, NDCG: 0.1059373, F1: 0.0786006, HIT_RATE: 0.4146202, ARHR_ALL_HITS: 0.2509157, NOVELTY: 0.0046592, AVERAGE_POPULARITY: 0.3531641, DIVERSITY_MEAN_INTER_LIST: 0.9151044, DIVERSITY_HERFINDAHL: 0.9915017, COVERAGE_ITEM: 0.2656377, COVERAGE_ITEM_HIT: 0.0325803, ITEMS_IN_GT: 0.8000180, COVERAGE_USER: 0.8313024, COVERAGE_USER_HIT: 0.3446748, USERS_IN_GT: 0.8313024, DIVERSITY_GINI: 0.0275611, SHANNON_ENTROPY: 8.5766041, RATIO_DIVERSITY_HERFINDAHL: 0.9918617, RATIO_DIVERSITY_GINI: 0.0795159, RATIO_SHANNON_ENTROPY: 0.6609529, RATIO_AVERAGE_POPULARITY: 2.8918899, RATIO_NOVELTY: 0.2925538,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNCFRecommender
#
# ItemKNNCFRecommender: Saving model in file 'result_experiments/ItemKNNCFRecommender_best_model'
# ItemKNNCFRecommender: Saving complete
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 12.0247
# Function value obtained: -0.0132
# Current minimum: -0.0132
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 977, 'shrink': 553, 'similarity': 'cosine', 'normalize': False}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 11109.59 column/sec. Elapsed time 2.00 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 7.35 sec. Users per second: 1150
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': 977, 'shrink': 553, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0219804, PRECISION_RECALL_MIN_DEN: 0.0709775, RECALL: 0.0693423, MAP: 0.0082244, MAP_MIN_DEN: 0.0274210, MRR: 0.0718212, NDCG: 0.0487435, F1: 0.0333799, HIT_RATE: 0.1910564, ARHR_ALL_HITS: 0.0768275, NOVELTY: 0.0041836, AVERAGE_POPULARITY: 0.6238831, DIVERSITY_MEAN_INTER_LIST: 0.5171964, DIVERSITY_HERFINDAHL: 0.9517135, COVERAGE_ITEM: 0.0719557, COVERAGE_ITEM_HIT: 0.0072901, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1277892, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0029991, SHANNON_ENTROPY: 5.4043732, RATIO_DIVERSITY_HERFINDAHL: 0.9520591, RATIO_DIVERSITY_GINI: 0.0086527, RATIO_SHANNON_ENTROPY: 0.4164860, RATIO_AVERAGE_POPULARITY: 5.1086765, RATIO_NOVELTY: 0.2626888,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 9.6609
# Function value obtained: -0.0082
# Current minimum: -0.0132
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 129, 'shrink': 825, 'similarity': 'cosine', 'normalize': False}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 11318.29 column/sec. Elapsed time 1.96 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 6.14 sec. Users per second: 1378
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'topK': 129, 'shrink': 825, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0254229, PRECISION_RECALL_MIN_DEN: 0.0806897, RECALL: 0.0788176, MAP: 0.0098461, MAP_MIN_DEN: 0.0324564, MRR: 0.0847879, NDCG: 0.0569381, F1: 0.0384452, HIT_RATE: 0.2181474, ARHR_ALL_HITS: 0.0913055, NOVELTY: 0.0041775, AVERAGE_POPULARITY: 0.5748978, DIVERSITY_MEAN_INTER_LIST: 0.6436895, DIVERSITY_HERFINDAHL: 0.9643613, COVERAGE_ITEM: 0.1413464, COVERAGE_ITEM_HIT: 0.0120601, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1459092, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0086870, SHANNON_ENTROPY: 6.2867633, RATIO_DIVERSITY_HERFINDAHL: 0.9647115, RATIO_DIVERSITY_GINI: 0.0250628, RATIO_SHANNON_ENTROPY: 0.4844871, RATIO_AVERAGE_POPULARITY: 4.7075602, RATIO_NOVELTY: 0.2623080,
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 8.2399
# Function value obtained: -0.0098
# Current minimum: -0.0132
# Iteration No: 7 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 373, 'shrink': 39, 'similarity': 'cosine', 'normalize': False}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 11222.92 column/sec. Elapsed time 1.98 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 6.87 sec. Users per second: 1230
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'topK': 373, 'shrink': 39, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0238022, PRECISION_RECALL_MIN_DEN: 0.0767248, RECALL: 0.0749443, MAP: 0.0089799, MAP_MIN_DEN: 0.0300985, MRR: 0.0776019, NDCG: 0.0530224, F1: 0.0361297, HIT_RATE: 0.2053709, ARHR_ALL_HITS: 0.0834375, NOVELTY: 0.0040948, AVERAGE_POPULARITY: 0.6232092, DIVERSITY_MEAN_INTER_LIST: 0.5409340, DIVERSITY_HERFINDAHL: 0.9540870, COVERAGE_ITEM: 0.1009360, COVERAGE_ITEM_HIT: 0.0094051, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1373635, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0048032, SHANNON_ENTROPY: 5.6355512, RATIO_DIVERSITY_HERFINDAHL: 0.9544334, RATIO_DIVERSITY_GINI: 0.0138575, RATIO_SHANNON_ENTROPY: 0.4343017, RATIO_AVERAGE_POPULARITY: 5.1031587, RATIO_NOVELTY: 0.2571166,
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 9.0531
# Function value obtained: -0.0090
# Current minimum: -0.0132
# Iteration No: 8 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 285, 'shrink': 72, 'similarity': 'cosine', 'normalize': True}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 10594.76 column/sec. Elapsed time 2.10 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 6.02 sec. Users per second: 1404
# SearchBayesianSkopt: New best config found. Config 7: {'topK': 285, 'shrink': 72, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0336449, PRECISION_RECALL_MIN_DEN: 0.1046741, RECALL: 0.1022614, MAP: 0.0136337, MAP_MIN_DEN: 0.0434118, MRR: 0.1107021, NDCG: 0.0750343, F1: 0.0506315, HIT_RATE: 0.2754052, ARHR_ALL_HITS: 0.1227685, NOVELTY: 0.0046095, AVERAGE_POPULARITY: 0.3934779, DIVERSITY_MEAN_INTER_LIST: 0.8772658, DIVERSITY_HERFINDAHL: 0.9877162, COVERAGE_ITEM: 0.1533615, COVERAGE_ITEM_HIT: 0.0261003, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1842064, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0160826, SHANNON_ENTROPY: 8.0400110, RATIO_DIVERSITY_HERFINDAHL: 0.9880748, RATIO_DIVERSITY_GINI: 0.0463997, RATIO_SHANNON_ENTROPY: 0.6196005, RATIO_AVERAGE_POPULARITY: 3.2219999, RATIO_NOVELTY: 0.2894310,
#
# EvaluatorHoldout: Processed 10506 (100.0%) in 7.08 sec. Users per second: 1483
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 285, 'shrink': 72, 'similarity': 'cosine', 'normalize': True} - results:
# CUTOFF: 10 - PRECISION: 0.0670760, PRECISION_RECALL_MIN_DEN: 0.1227732, RECALL: 0.1061850, MAP: 0.0320349, MAP_MIN_DEN: 0.0583417, MRR: 0.2036807, NDCG: 0.1092494, F1: 0.0822166, HIT_RATE: 0.4251856, ARHR_ALL_HITS: 0.2537243, NOVELTY: 0.0046810, AVERAGE_POPULARITY: 0.3748944, DIVERSITY_MEAN_INTER_LIST: 0.8906998, DIVERSITY_HERFINDAHL: 0.9890615, COVERAGE_ITEM: 0.1917019, COVERAGE_ITEM_HIT: 0.0411304, ITEMS_IN_GT: 0.8000180, COVERAGE_USER: 0.8313024, COVERAGE_USER_HIT: 0.3534578, USERS_IN_GT: 0.8313024, DIVERSITY_GINI: 0.0197237, SHANNON_ENTROPY: 8.2781554, RATIO_DIVERSITY_HERFINDAHL: 0.9894206, RATIO_DIVERSITY_GINI: 0.0569044, RATIO_SHANNON_ENTROPY: 0.6379530, RATIO_AVERAGE_POPULARITY: 3.0698286, RATIO_NOVELTY: 0.2939229,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNCFRecommender
#
# ItemKNNCFRecommender: Saving model in file 'result_experiments/ItemKNNCFRecommender_best_model'
# ItemKNNCFRecommender: Saving complete
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 18.3248
# Function value obtained: -0.0136
# Current minimum: -0.0136
# Iteration No: 9 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 493, 'shrink': 896, 'similarity': 'cosine', 'normalize': False}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 11218.71 column/sec. Elapsed time 1.98 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 7.13 sec. Users per second: 1185
# SearchBayesianSkopt: Config 8 is suboptimal. Config: {'topK': 493, 'shrink': 896, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0234591, PRECISION_RECALL_MIN_DEN: 0.0758471, RECALL: 0.0741112, MAP: 0.0087843, MAP_MIN_DEN: 0.0295113, MRR: 0.0762949, NDCG: 0.0521809, F1: 0.0356376, HIT_RATE: 0.2030049, ARHR_ALL_HITS: 0.0818324, NOVELTY: 0.0040988, AVERAGE_POPULARITY: 0.6288347, DIVERSITY_MEAN_INTER_LIST: 0.5252436, DIVERSITY_HERFINDAHL: 0.9525181, COVERAGE_ITEM: 0.0913959, COVERAGE_ITEM_HIT: 0.0088651, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1357810, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0041059, SHANNON_ENTROPY: 5.5270778, RATIO_DIVERSITY_HERFINDAHL: 0.9528640, RATIO_DIVERSITY_GINI: 0.0118457, RATIO_SHANNON_ENTROPY: 0.4259422, RATIO_AVERAGE_POPULARITY: 5.1492227, RATIO_NOVELTY: 0.2573658,
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 9.3476
# Function value obtained: -0.0088
# Current minimum: -0.0136
# Iteration No: 10 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 222, 'shrink': 96, 'similarity': 'cosine', 'normalize': True}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 10657.81 column/sec. Elapsed time 2.09 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 5.93 sec. Users per second: 1425
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'topK': 222, 'shrink': 96, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0340471, PRECISION_RECALL_MIN_DEN: 0.1055133, RECALL: 0.1030892, MAP: 0.0136184, MAP_MIN_DEN: 0.0428081, MRR: 0.1108098, NDCG: 0.0749733, F1: 0.0511883, HIT_RATE: 0.2783627, ARHR_ALL_HITS: 0.1227282, NOVELTY: 0.0045506, AVERAGE_POPULARITY: 0.4025411, DIVERSITY_MEAN_INTER_LIST: 0.8740218, DIVERSITY_HERFINDAHL: 0.9873918, COVERAGE_ITEM: 0.1492215, COVERAGE_ITEM_HIT: 0.0249302, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1861845, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0151138, SHANNON_ENTROPY: 7.9619709, RATIO_DIVERSITY_HERFINDAHL: 0.9877503, RATIO_DIVERSITY_GINI: 0.0436045, RATIO_SHANNON_ENTROPY: 0.6135864, RATIO_AVERAGE_POPULARITY: 3.2962145, RATIO_NOVELTY: 0.2857374,
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 8.1817
# Function value obtained: -0.0136
# Current minimum: -0.0136
# Iteration No: 11 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 798, 'shrink': 360, 'similarity': 'cosine', 'normalize': False}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 11074.39 column/sec. Elapsed time 2.01 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 7.36 sec. Users per second: 1148
# SearchBayesianSkopt: Config 10 is suboptimal. Config: {'topK': 798, 'shrink': 360, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0224536, PRECISION_RECALL_MIN_DEN: 0.0725143, RECALL: 0.0708374, MAP: 0.0084203, MAP_MIN_DEN: 0.0279486, MRR: 0.0733543, NDCG: 0.0497534, F1: 0.0340987, HIT_RATE: 0.1943689, ARHR_ALL_HITS: 0.0785544, NOVELTY: 0.0041462, AVERAGE_POPULARITY: 0.6285699, DIVERSITY_MEAN_INTER_LIST: 0.5141884, DIVERSITY_HERFINDAHL: 0.9514128, COVERAGE_ITEM: 0.0766808, COVERAGE_ITEM_HIT: 0.0078301, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1300047, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0032479, SHANNON_ENTROPY: 5.4204453, RATIO_DIVERSITY_HERFINDAHL: 0.9517582, RATIO_DIVERSITY_GINI: 0.0093703, RATIO_SHANNON_ENTROPY: 0.4177246, RATIO_AVERAGE_POPULARITY: 5.1470544, RATIO_NOVELTY: 0.2603438,
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 9.6436
# Function value obtained: -0.0084
# Current minimum: -0.0136
# Iteration No: 12 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 125, 'shrink': 173, 'similarity': 'cosine', 'normalize': True}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 10730.34 column/sec. Elapsed time 2.07 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 5.57 sec. Users per second: 1518
# SearchBayesianSkopt: New best config found. Config 11: {'topK': 125, 'shrink': 173, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0336922, PRECISION_RECALL_MIN_DEN: 0.1042480, RECALL: 0.1017092, MAP: 0.0139546, MAP_MIN_DEN: 0.0440928, MRR: 0.1147287, NDCG: 0.0759531, F1: 0.0506170, HIT_RATE: 0.2746954, ARHR_ALL_HITS: 0.1263682, NOVELTY: 0.0044859, AVERAGE_POPULARITY: 0.4089805, DIVERSITY_MEAN_INTER_LIST: 0.8752680, DIVERSITY_HERFINDAHL: 0.9875164, COVERAGE_ITEM: 0.1528665, COVERAGE_ITEM_HIT: 0.0231302, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1837316, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0146665, SHANNON_ENTROPY: 7.9148610, RATIO_DIVERSITY_HERFINDAHL: 0.9878750, RATIO_DIVERSITY_GINI: 0.0423139, RATIO_SHANNON_ENTROPY: 0.6099559, RATIO_AVERAGE_POPULARITY: 3.3489431, RATIO_NOVELTY: 0.2816722,
#
# EvaluatorHoldout: Processed 10506 (100.0%) in 6.56 sec. Users per second: 1601
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 125, 'shrink': 173, 'similarity': 'cosine', 'normalize': True} - results:
# CUTOFF: 10 - PRECISION: 0.0669617, PRECISION_RECALL_MIN_DEN: 0.1222239, RECALL: 0.1054670, MAP: 0.0326443, MAP_MIN_DEN: 0.0596088, MRR: 0.2098221, NDCG: 0.1107188, F1: 0.0819150, HIT_RATE: 0.4268037, ARHR_ALL_HITS: 0.2600269, NOVELTY: 0.0045684, AVERAGE_POPULARITY: 0.3902875, DIVERSITY_MEAN_INTER_LIST: 0.8876014, DIVERSITY_HERFINDAHL: 0.9887517, COVERAGE_ITEM: 0.2001170, COVERAGE_ITEM_HIT: 0.0350104, ITEMS_IN_GT: 0.8000180, COVERAGE_USER: 0.8313024, COVERAGE_USER_HIT: 0.3548030, USERS_IN_GT: 0.8313024, DIVERSITY_GINI: 0.0189360, SHANNON_ENTROPY: 8.1660904, RATIO_DIVERSITY_HERFINDAHL: 0.9891107, RATIO_DIVERSITY_GINI: 0.0546318, RATIO_SHANNON_ENTROPY: 0.6293168, RATIO_AVERAGE_POPULARITY: 3.1958754, RATIO_NOVELTY: 0.2868546,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNCFRecommender
#
# ItemKNNCFRecommender: Saving model in file 'result_experiments/ItemKNNCFRecommender_best_model'
# ItemKNNCFRecommender: Saving complete
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 15.7679
# Function value obtained: -0.0140
# Current minimum: -0.0140
# Iteration No: 13 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 692, 'shrink': 551, 'similarity': 'cosine', 'normalize': True}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 10564.95 column/sec. Elapsed time 2.10 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 6.97 sec. Users per second: 1213
# SearchBayesianSkopt: Config 12 is suboptimal. Config: {'topK': 692, 'shrink': 551, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0252691, PRECISION_RECALL_MIN_DEN: 0.0817811, RECALL: 0.0799202, MAP: 0.0099112, MAP_MIN_DEN: 0.0328623, MRR: 0.0847374, NDCG: 0.0573158, F1: 0.0383977, HIT_RATE: 0.2167278, ARHR_ALL_HITS: 0.0915929, NOVELTY: 0.0043068, AVERAGE_POPULARITY: 0.5635587, DIVERSITY_MEAN_INTER_LIST: 0.6479320, DIVERSITY_HERFINDAHL: 0.9647855, COVERAGE_ITEM: 0.0916209, COVERAGE_ITEM_HIT: 0.0115651, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1449596, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0049395, SHANNON_ENTROPY: 6.1210320, RATIO_DIVERSITY_HERFINDAHL: 0.9651358, RATIO_DIVERSITY_GINI: 0.0142508, RATIO_SHANNON_ENTROPY: 0.4717151, RATIO_AVERAGE_POPULARITY: 4.6147095, RATIO_NOVELTY: 0.2704246,
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 9.3358
# Function value obtained: -0.0099
# Current minimum: -0.0140
# Iteration No: 14 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 249, 'shrink': 753, 'similarity': 'cosine', 'normalize': False}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 11185.17 column/sec. Elapsed time 1.99 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 6.53 sec. Users per second: 1294
# SearchBayesianSkopt: Config 13 is suboptimal. Config: {'topK': 249, 'shrink': 753, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0244529, PRECISION_RECALL_MIN_DEN: 0.0784717, RECALL: 0.0766857, MAP: 0.0092525, MAP_MIN_DEN: 0.0308984, MRR: 0.0800882, NDCG: 0.0544418, F1: 0.0370815, HIT_RATE: 0.2114042, ARHR_ALL_HITS: 0.0860502, NOVELTY: 0.0041149, AVERAGE_POPULARITY: 0.6090223, DIVERSITY_MEAN_INTER_LIST: 0.5731009, DIVERSITY_HERFINDAHL: 0.9573033, COVERAGE_ITEM: 0.1164162, COVERAGE_ITEM_HIT: 0.0107101, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1413990, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0060788, SHANNON_ENTROPY: 5.8435965, RATIO_DIVERSITY_HERFINDAHL: 0.9576509, RATIO_DIVERSITY_GINI: 0.0175379, RATIO_SHANNON_ENTROPY: 0.4503346, RATIO_AVERAGE_POPULARITY: 4.9869884, RATIO_NOVELTY: 0.2583797,
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 8.6930
# Function value obtained: -0.0093
# Current minimum: -0.0140
# Iteration No: 15 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 162, 'shrink': 914, 'similarity': 'cosine', 'normalize': False}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 11232.50 column/sec. Elapsed time 1.98 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 6.25 sec. Users per second: 1352
# SearchBayesianSkopt: Config 14 is suboptimal. Config: {'topK': 162, 'shrink': 914, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0250680, PRECISION_RECALL_MIN_DEN: 0.0803797, RECALL: 0.0785565, MAP: 0.0096679, MAP_MIN_DEN: 0.0321116, MRR: 0.0832986, NDCG: 0.0563424, F1: 0.0380075, HIT_RATE: 0.2150716, ARHR_ALL_HITS: 0.0897086, NOVELTY: 0.0041526, AVERAGE_POPULARITY: 0.5882151, DIVERSITY_MEAN_INTER_LIST: 0.6171811, DIVERSITY_HERFINDAHL: 0.9617108, COVERAGE_ITEM: 0.1327513, COVERAGE_ITEM_HIT: 0.0117901, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1438519, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0077050, SHANNON_ENTROPY: 6.1182866, RATIO_DIVERSITY_HERFINDAHL: 0.9620600, RATIO_DIVERSITY_GINI: 0.0222295, RATIO_SHANNON_ENTROPY: 0.4715035, RATIO_AVERAGE_POPULARITY: 4.8166090, RATIO_NOVELTY: 0.2607425,
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 8.6181
# Function value obtained: -0.0097
# Current minimum: -0.0140
# Iteration No: 16 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 406, 'shrink': 875, 'similarity': 'cosine', 'normalize': True}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 10394.51 column/sec. Elapsed time 2.14 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 6.43 sec. Users per second: 1314
# SearchBayesianSkopt: Config 15 is suboptimal. Config: {'topK': 406, 'shrink': 875, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0260972, PRECISION_RECALL_MIN_DEN: 0.0837084, RECALL: 0.0817881, MAP: 0.0101781, MAP_MIN_DEN: 0.0338478, MRR: 0.0872777, NDCG: 0.0589475, F1: 0.0395687, HIT_RATE: 0.2237076, ARHR_ALL_HITS: 0.0941749, NOVELTY: 0.0041938, AVERAGE_POPULARITY: 0.5814403, DIVERSITY_MEAN_INTER_LIST: 0.6302032, DIVERSITY_HERFINDAHL: 0.9630129, COVERAGE_ITEM: 0.1041310, COVERAGE_ITEM_HIT: 0.0116551, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1496281, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0056414, SHANNON_ENTROPY: 6.0917606, RATIO_DIVERSITY_HERFINDAHL: 0.9633625, RATIO_DIVERSITY_GINI: 0.0162757, RATIO_SHANNON_ENTROPY: 0.4694593, RATIO_AVERAGE_POPULARITY: 4.7611333, RATIO_NOVELTY: 0.2633314,
#
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 9.0317
# Function value obtained: -0.0102
# Current minimum: -0.0140
# Iteration No: 17 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1000, 'shrink': 13, 'similarity': 'cosine', 'normalize': True}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 10389.01 column/sec. Elapsed time 2.14 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 7.15 sec. Users per second: 1182
# SearchBayesianSkopt: Config 16 is suboptimal. Config: {'topK': 1000, 'shrink': 13, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0324382, PRECISION_RECALL_MIN_DEN: 0.1017821, RECALL: 0.0995454, MAP: 0.0131850, MAP_MIN_DEN: 0.0426649, MRR: 0.1053321, NDCG: 0.0728847, F1: 0.0489314, HIT_RATE: 0.2584881, ARHR_ALL_HITS: 0.1176049, NOVELTY: 0.0050136, AVERAGE_POPULARITY: 0.3288628, DIVERSITY_MEAN_INTER_LIST: 0.9015403, DIVERSITY_HERFINDAHL: 0.9901434, COVERAGE_ITEM: 0.2655477, COVERAGE_ITEM_HIT: 0.0344253, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1728913, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0346307, SHANNON_ENTROPY: 8.7127208, RATIO_DIVERSITY_HERFINDAHL: 0.9905029, RATIO_DIVERSITY_GINI: 0.0999123, RATIO_SHANNON_ENTROPY: 0.6714426, RATIO_AVERAGE_POPULARITY: 2.6928981, RATIO_NOVELTY: 0.3148071,
#
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 9.8496
# Function value obtained: -0.0132
# Current minimum: -0.0140
# Iteration No: 18 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 991, 'shrink': 991, 'similarity': 'cosine', 'normalize': True}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 10328.84 column/sec. Elapsed time 2.15 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 7.26 sec. Users per second: 1165
# SearchBayesianSkopt: Config 17 is suboptimal. Config: {'topK': 991, 'shrink': 991, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0233290, PRECISION_RECALL_MIN_DEN: 0.0757859, RECALL: 0.0740466, MAP: 0.0089159, MAP_MIN_DEN: 0.0298519, MRR: 0.0769471, NDCG: 0.0524659, F1: 0.0354798, HIT_RATE: 0.2018218, ARHR_ALL_HITS: 0.0827665, NOVELTY: 0.0043065, AVERAGE_POPULARITY: 0.5826697, DIVERSITY_MEAN_INTER_LIST: 0.6003471, DIVERSITY_HERFINDAHL: 0.9600276, COVERAGE_ITEM: 0.0778508, COVERAGE_ITEM_HIT: 0.0094051, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1349897, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0037307, SHANNON_ENTROPY: 5.8037253, RATIO_DIVERSITY_HERFINDAHL: 0.9603762, RATIO_DIVERSITY_GINI: 0.0107633, RATIO_SHANNON_ENTROPY: 0.4472620, RATIO_AVERAGE_POPULARITY: 4.7712004, RATIO_NOVELTY: 0.2704077,
#
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 10.0950
# Function value obtained: -0.0089
# Current minimum: -0.0140
# Iteration No: 19 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 995, 'shrink': 4, 'similarity': 'cosine', 'normalize': False}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 10865.20 column/sec. Elapsed time 2.05 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 7.38 sec. Users per second: 1146
# SearchBayesianSkopt: Config 18 is suboptimal. Config: {'topK': 995, 'shrink': 4, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0218976, PRECISION_RECALL_MIN_DEN: 0.0707636, RECALL: 0.0691304, MAP: 0.0082191, MAP_MIN_DEN: 0.0274384, MRR: 0.0717579, NDCG: 0.0486762, F1: 0.0332598, HIT_RATE: 0.1902283, ARHR_ALL_HITS: 0.0767650, NOVELTY: 0.0041872, AVERAGE_POPULARITY: 0.6233278, DIVERSITY_MEAN_INTER_LIST: 0.5176695, DIVERSITY_HERFINDAHL: 0.9517608, COVERAGE_ITEM: 0.0710557, COVERAGE_ITEM_HIT: 0.0072901, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1272353, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0029673, SHANNON_ENTROPY: 5.4036519, RATIO_DIVERSITY_HERFINDAHL: 0.9521064, RATIO_DIVERSITY_GINI: 0.0085608, RATIO_SHANNON_ENTROPY: 0.4164305, RATIO_AVERAGE_POPULARITY: 5.1041298, RATIO_NOVELTY: 0.2629171,
#
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 10.0177
# Function value obtained: -0.0082
# Current minimum: -0.0140
# Iteration No: 20 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 647, 'shrink': 0, 'similarity': 'cosine', 'normalize': True}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 9675.84 column/sec. Elapsed time 2.30 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 6.62 sec. Users per second: 1277
# SearchBayesianSkopt: Config 19 is suboptimal. Config: {'topK': 647, 'shrink': 0, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0289720, PRECISION_RECALL_MIN_DEN: 0.0896353, RECALL: 0.0878978, MAP: 0.0112785, MAP_MIN_DEN: 0.0353555, MRR: 0.0912113, NDCG: 0.0626982, F1: 0.0435797, HIT_RATE: 0.2363658, ARHR_ALL_HITS: 0.1012533, NOVELTY: 0.0058159, AVERAGE_POPULARITY: 0.2395481, DIVERSITY_MEAN_INTER_LIST: 0.9411330, DIVERSITY_HERFINDAHL: 0.9941022, COVERAGE_ITEM: 0.4719647, COVERAGE_ITEM_HIT: 0.0401404, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1580946, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.1101628, SHANNON_ENTROPY: 10.2466062, RATIO_DIVERSITY_HERFINDAHL: 0.9944631, RATIO_DIVERSITY_GINI: 0.3178282, RATIO_SHANNON_ENTROPY: 0.7896510, RATIO_AVERAGE_POPULARITY: 1.9615438, RATIO_NOVELTY: 0.3651846,
#
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 9.4700
# Function value obtained: -0.0113
# Current minimum: -0.0140
# Iteration No: 21 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 17, 'shrink': 3, 'similarity': 'cosine', 'normalize': False}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 10833.49 column/sec. Elapsed time 2.05 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 4.57 sec. Users per second: 1851
# SearchBayesianSkopt: Config 20 is suboptimal. Config: {'topK': 17, 'shrink': 3, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0285579, PRECISION_RECALL_MIN_DEN: 0.0880755, RECALL: 0.0859339, MAP: 0.0114044, MAP_MIN_DEN: 0.0358949, MRR: 0.0956898, NDCG: 0.0631738, F1: 0.0428693, HIT_RATE: 0.2400331, ARHR_ALL_HITS: 0.1043889, NOVELTY: 0.0044721, AVERAGE_POPULARITY: 0.4330865, DIVERSITY_MEAN_INTER_LIST: 0.8471328, DIVERSITY_HERFINDAHL: 0.9847033, COVERAGE_ITEM: 0.2035370, COVERAGE_ITEM_HIT: 0.0184052, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1605476, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0195298, SHANNON_ENTROPY: 7.8466730, RATIO_DIVERSITY_HERFINDAHL: 0.9850608, RATIO_DIVERSITY_GINI: 0.0563451, RATIO_SHANNON_ENTROPY: 0.6047010, RATIO_AVERAGE_POPULARITY: 3.5463359, RATIO_NOVELTY: 0.2808077,
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 7.0178
# Function value obtained: -0.0114
# Current minimum: -0.0140
# Iteration No: 22 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 5, 'shrink': 0, 'similarity': 'cosine', 'normalize': True}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 10093.10 column/sec. Elapsed time 2.20 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 2.78 sec. Users per second: 3035
# SearchBayesianSkopt: New best config found. Config 21: {'topK': 5, 'shrink': 0, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0346741, PRECISION_RECALL_MIN_DEN: 0.1027179, RECALL: 0.1001089, MAP: 0.0148399, MAP_MIN_DEN: 0.0440241, MRR: 0.1186566, NDCG: 0.0764356, F1: 0.0515078, HIT_RATE: 0.2775346, ARHR_ALL_HITS: 0.1323148, NOVELTY: 0.0058926, AVERAGE_POPULARITY: 0.1244829, DIVERSITY_MEAN_INTER_LIST: 0.9863622, DIVERSITY_HERFINDAHL: 0.9986246, COVERAGE_ITEM: 0.5759158, COVERAGE_ITEM_HIT: 0.0563406, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1856306, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.1669047, SHANNON_ENTROPY: 11.5296958, RATIO_DIVERSITY_HERFINDAHL: 0.9989871, RATIO_DIVERSITY_GINI: 0.4815331, RATIO_SHANNON_ENTROPY: 0.8885318, RATIO_AVERAGE_POPULARITY: 1.0193299, RATIO_NOVELTY: 0.3699992,
#
# EvaluatorHoldout: Processed 10506 (100.0%) in 3.45 sec. Users per second: 3043
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 5, 'shrink': 0, 'similarity': 'cosine', 'normalize': True} - results:
# CUTOFF: 10 - PRECISION: 0.0712831, PRECISION_RECALL_MIN_DEN: 0.1230008, RECALL: 0.1034234, MAP: 0.0354441, MAP_MIN_DEN: 0.0601876, MRR: 0.2112272, NDCG: 0.1123192, F1: 0.0843968, HIT_RATE: 0.4231868, ARHR_ALL_HITS: 0.2708611, NOVELTY: 0.0059082, AVERAGE_POPULARITY: 0.1235397, DIVERSITY_MEAN_INTER_LIST: 0.9810599, DIVERSITY_HERFINDAHL: 0.9980967, COVERAGE_ITEM: 0.6166862, COVERAGE_ITEM_HIT: 0.1006660, ITEMS_IN_GT: 0.8000180, COVERAGE_USER: 0.8313024, COVERAGE_USER_HIT: 0.3517962, USERS_IN_GT: 0.8313024, DIVERSITY_GINI: 0.1636342, SHANNON_ENTROPY: 11.3511002, RATIO_DIVERSITY_HERFINDAHL: 0.9984590, RATIO_DIVERSITY_GINI: 0.4720975, RATIO_SHANNON_ENTROPY: 0.8747684, RATIO_AVERAGE_POPULARITY: 1.0116066, RATIO_NOVELTY: 0.3709817,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNCFRecommender
#
# ItemKNNCFRecommender: Saving model in file 'result_experiments/ItemKNNCFRecommender_best_model'
# ItemKNNCFRecommender: Saving complete
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 8.9787
# Function value obtained: -0.0148
# Current minimum: -0.0148
# Iteration No: 23 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 132, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 10038.41 column/sec. Elapsed time 2.21 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 5.87 sec. Users per second: 1440
# SearchBayesianSkopt: Config 22 is suboptimal. Config: {'topK': 132, 'shrink': 1000, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0282740, PRECISION_RECALL_MIN_DEN: 0.0901795, RECALL: 0.0882071, MAP: 0.0113240, MAP_MIN_DEN: 0.0367304, MRR: 0.0963815, NDCG: 0.0641171, F1: 0.0428218, HIT_RATE: 0.2397965, ARHR_ALL_HITS: 0.1043866, NOVELTY: 0.0042557, AVERAGE_POPULARITY: 0.5281996, DIVERSITY_MEAN_INTER_LIST: 0.7309272, DIVERSITY_HERFINDAHL: 0.9730841, COVERAGE_ITEM: 0.1431914, COVERAGE_ITEM_HIT: 0.0150752, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1603893, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0097644, SHANNON_ENTROPY: 6.7686225, RATIO_DIVERSITY_HERFINDAHL: 0.9734374, RATIO_DIVERSITY_GINI: 0.0281709, RATIO_SHANNON_ENTROPY: 0.5216214, RATIO_AVERAGE_POPULARITY: 4.3251707, RATIO_NOVELTY: 0.2672186,
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 8.5124
# Function value obtained: -0.0113
# Current minimum: -0.0148
# Iteration No: 24 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 608, 'shrink': 5, 'similarity': 'cosine', 'normalize': False}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 11075.72 column/sec. Elapsed time 2.01 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 6.89 sec. Users per second: 1227
# SearchBayesianSkopt: Config 23 is suboptimal. Config: {'topK': 608, 'shrink': 5, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0230687, PRECISION_RECALL_MIN_DEN: 0.0743133, RECALL: 0.0725803, MAP: 0.0086379, MAP_MIN_DEN: 0.0288129, MRR: 0.0752038, NDCG: 0.0511347, F1: 0.0350100, HIT_RATE: 0.1999290, ARHR_ALL_HITS: 0.0805558, NOVELTY: 0.0041145, AVERAGE_POPULARITY: 0.6299503, DIVERSITY_MEAN_INTER_LIST: 0.5181986, DIVERSITY_HERFINDAHL: 0.9518137, COVERAGE_ITEM: 0.0855009, COVERAGE_ITEM_HIT: 0.0083251, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1337237, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0037266, SHANNON_ENTROPY: 5.4734198, RATIO_DIVERSITY_HERFINDAHL: 0.9521593, RATIO_DIVERSITY_GINI: 0.0107515, RATIO_SHANNON_ENTROPY: 0.4218071, RATIO_AVERAGE_POPULARITY: 5.1583581, RATIO_NOVELTY: 0.2583513,
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 9.4296
# Function value obtained: -0.0086
# Current minimum: -0.0148
# Iteration No: 25 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 999, 'shrink': 990, 'similarity': 'cosine', 'normalize': False}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 11632.82 column/sec. Elapsed time 1.91 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 7.10 sec. Users per second: 1191
# SearchBayesianSkopt: Config 24 is suboptimal. Config: {'topK': 999, 'shrink': 990, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0219449, PRECISION_RECALL_MIN_DEN: 0.0710929, RECALL: 0.0694691, MAP: 0.0082465, MAP_MIN_DEN: 0.0275431, MRR: 0.0721296, NDCG: 0.0488667, F1: 0.0333536, HIT_RATE: 0.1909381, ARHR_ALL_HITS: 0.0770939, NOVELTY: 0.0041886, AVERAGE_POPULARITY: 0.6230720, DIVERSITY_MEAN_INTER_LIST: 0.5180277, DIVERSITY_HERFINDAHL: 0.9517966, COVERAGE_ITEM: 0.0715507, COVERAGE_ITEM_HIT: 0.0072901, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1277101, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0029816, SHANNON_ENTROPY: 5.4051291, RATIO_DIVERSITY_HERFINDAHL: 0.9521422, RATIO_DIVERSITY_GINI: 0.0086022, RATIO_SHANNON_ENTROPY: 0.4165443, RATIO_AVERAGE_POPULARITY: 5.1020354, RATIO_NOVELTY: 0.2630029,
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 9.6640
# Function value obtained: -0.0082
# Current minimum: -0.0148
# Iteration No: 26 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 5, 'shrink': 0, 'similarity': 'cosine', 'normalize': True}
# SearchBayesianSkopt: Config 25 was already explored at index 21. Config: {'topK': 5, 'shrink': 0, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0346741, PRECISION_RECALL_MIN_DEN: 0.1027179, RECALL: 0.1001089, MAP: 0.0148399, MAP_MIN_DEN: 0.0440241, MRR: 0.1186566, NDCG: 0.0764356, F1: 0.0515078, HIT_RATE: 0.2775346, ARHR_ALL_HITS: 0.1323148, NOVELTY: 0.0058926, AVERAGE_POPULARITY: 0.1244829, DIVERSITY_MEAN_INTER_LIST: 0.9863622, DIVERSITY_HERFINDAHL: 0.9986246, COVERAGE_ITEM: 0.5759158, COVERAGE_ITEM_HIT: 0.0563406, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1856306, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.1669047, SHANNON_ENTROPY: 11.5296958, RATIO_DIVERSITY_HERFINDAHL: 0.9989871, RATIO_DIVERSITY_GINI: 0.4815331, RATIO_SHANNON_ENTROPY: 0.8885318, RATIO_AVERAGE_POPULARITY: 1.0193299, RATIO_NOVELTY: 0.3699992,
# /home/kinami/.conda/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 0.4091
# Function value obtained: -0.0148
# Current minimum: -0.0148
# Iteration No: 27 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 38, 'shrink': 0, 'similarity': 'cosine', 'normalize': True}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 11086.75 column/sec. Elapsed time 2.00 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 2.99 sec. Users per second: 2830
# SearchBayesianSkopt: Config 26 is suboptimal. Config: {'topK': 38, 'shrink': 0, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0358808, PRECISION_RECALL_MIN_DEN: 0.1051336, RECALL: 0.1024235, MAP: 0.0147302, MAP_MIN_DEN: 0.0440403, MRR: 0.1166934, NDCG: 0.0770524, F1: 0.0531442, HIT_RATE: 0.2834497, ARHR_ALL_HITS: 0.1308862, NOVELTY: 0.0058302, AVERAGE_POPULARITY: 0.1662851, DIVERSITY_MEAN_INTER_LIST: 0.9826002, DIVERSITY_HERFINDAHL: 0.9982484, COVERAGE_ITEM: 0.5162002, COVERAGE_ITEM_HIT: 0.0537755, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1895870, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.1458066, SHANNON_ENTROPY: 11.3248240, RATIO_DIVERSITY_HERFINDAHL: 0.9986108, RATIO_DIVERSITY_GINI: 0.4206634, RATIO_SHANNON_ENTROPY: 0.8727434, RATIO_AVERAGE_POPULARITY: 1.3616286, RATIO_NOVELTY: 0.3660796,
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 5.4022
# Function value obtained: -0.0147
# Current minimum: -0.0148
# Iteration No: 28 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 840, 'shrink': 4, 'similarity': 'cosine', 'normalize': True}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 11015.76 column/sec. Elapsed time 2.02 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 6.47 sec. Users per second: 1306
# SearchBayesianSkopt: Config 27 is suboptimal. Config: {'topK': 840, 'shrink': 4, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0319768, PRECISION_RECALL_MIN_DEN: 0.0996158, RECALL: 0.0974607, MAP: 0.0129476, MAP_MIN_DEN: 0.0417211, MRR: 0.1037931, NDCG: 0.0715324, F1: 0.0481542, HIT_RATE: 0.2554123, ARHR_ALL_HITS: 0.1157419, NOVELTY: 0.0052991, AVERAGE_POPULARITY: 0.2911020, DIVERSITY_MEAN_INTER_LIST: 0.9196083, DIVERSITY_HERFINDAHL: 0.9919500, COVERAGE_ITEM: 0.4042840, COVERAGE_ITEM_HIT: 0.0397354, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1708340, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0712700, SHANNON_ENTROPY: 9.4446006, RATIO_DIVERSITY_HERFINDAHL: 0.9923101, RATIO_DIVERSITY_GINI: 0.2056196, RATIO_SHANNON_ENTROPY: 0.7278447, RATIO_AVERAGE_POPULARITY: 2.3836933, RATIO_NOVELTY: 0.3327303,
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 9.0644
# Function value obtained: -0.0129
# Current minimum: -0.0148
# Iteration No: 29 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 768, 'shrink': 999, 'similarity': 'cosine', 'normalize': True}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 11022.45 column/sec. Elapsed time 2.02 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 6.71 sec. Users per second: 1260
# ...
# EvaluatorHoldout: Processed 8453 (100.0%) in 3.27 sec. Users per second: 2584
# SearchBayesianSkopt: Config 40 is suboptimal. Config: {'topK': 5, 'shrink': 146, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0338933, PRECISION_RECALL_MIN_DEN: 0.1025320, RECALL: 0.1000842, MAP: 0.0140467, MAP_MIN_DEN: 0.0434302, MRR: 0.1157177, NDCG: 0.0754846, F1: 0.0506381, HIT_RATE: 0.2784810, ARHR_ALL_HITS: 0.1272208, NOVELTY: 0.0048792, AVERAGE_POPULARITY: 0.2460671, DIVERSITY_MEAN_INTER_LIST: 0.9652583, DIVERSITY_HERFINDAHL: 0.9965144, COVERAGE_ITEM: 0.2143371, COVERAGE_ITEM_HIT: 0.0300603, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1862636, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0309766, SHANNON_ENTROPY: 9.3980533, RATIO_DIVERSITY_HERFINDAHL: 0.9968762, RATIO_DIVERSITY_GINI: 0.0893700, RATIO_SHANNON_ENTROPY: 0.7242575, RATIO_AVERAGE_POPULARITY: 2.0149247, RATIO_NOVELTY: 0.3063651,
#
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 5.7351
# Function value obtained: -0.0140
# Current minimum: -0.0148
# Iteration No: 42 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 5, 'shrink': 0, 'similarity': 'cosine', 'normalize': True}
# SearchBayesianSkopt: Config 41 was already explored at index 21. Config: {'topK': 5, 'shrink': 0, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0346741, PRECISION_RECALL_MIN_DEN: 0.1027179, RECALL: 0.1001089, MAP: 0.0148399, MAP_MIN_DEN: 0.0440241, MRR: 0.1186566, NDCG: 0.0764356, F1: 0.0515078, HIT_RATE: 0.2775346, ARHR_ALL_HITS: 0.1323148, NOVELTY: 0.0058926, AVERAGE_POPULARITY: 0.1244829, DIVERSITY_MEAN_INTER_LIST: 0.9863622, DIVERSITY_HERFINDAHL: 0.9986246, COVERAGE_ITEM: 0.5759158, COVERAGE_ITEM_HIT: 0.0563406, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1856306, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.1669047, SHANNON_ENTROPY: 11.5296958, RATIO_DIVERSITY_HERFINDAHL: 0.9989871, RATIO_DIVERSITY_GINI: 0.4815331, RATIO_SHANNON_ENTROPY: 0.8885318, RATIO_AVERAGE_POPULARITY: 1.0193299, RATIO_NOVELTY: 0.3699992,
# /home/kinami/.conda/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 0.5197
# Function value obtained: -0.0148
# Current minimum: -0.0148
# Iteration No: 43 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 174, 'shrink': 264, 'similarity': 'cosine', 'normalize': False}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 11440.00 column/sec. Elapsed time 1.94 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 6.09 sec. Users per second: 1388
# SearchBayesianSkopt: Config 42 is suboptimal. Config: {'topK': 174, 'shrink': 264, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0249497, PRECISION_RECALL_MIN_DEN: 0.0794511, RECALL: 0.0776245, MAP: 0.0096087, MAP_MIN_DEN: 0.0316814, MRR: 0.0828590, NDCG: 0.0557391, F1: 0.0377621, HIT_RATE: 0.2138886, ARHR_ALL_HITS: 0.0892089, NOVELTY: 0.0041457, AVERAGE_POPULARITY: 0.5918623, DIVERSITY_MEAN_INTER_LIST: 0.6101353, DIVERSITY_HERFINDAHL: 0.9610063, COVERAGE_ITEM: 0.1299163, COVERAGE_ITEM_HIT: 0.0115201, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1430606, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0073972, SHANNON_ENTROPY: 6.0716393, RATIO_DIVERSITY_HERFINDAHL: 0.9613552, RATIO_DIVERSITY_GINI: 0.0213414, RATIO_SHANNON_ENTROPY: 0.4679087, RATIO_AVERAGE_POPULARITY: 4.8464735, RATIO_NOVELTY: 0.2603123,
#
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 8.6454
# Function value obtained: -0.0096
# Current minimum: -0.0148
# Iteration No: 44 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 231, 'shrink': 613, 'similarity': 'cosine', 'normalize': True}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 9993.56 column/sec. Elapsed time 2.22 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 6.05 sec. Users per second: 1398
# SearchBayesianSkopt: Config 43 is suboptimal. Config: {'topK': 231, 'shrink': 613, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0283923, PRECISION_RECALL_MIN_DEN: 0.0900321, RECALL: 0.0880006, MAP: 0.0113558, MAP_MIN_DEN: 0.0368091, MRR: 0.0965048, NDCG: 0.0642012, F1: 0.0429328, HIT_RATE: 0.2419259, ARHR_ALL_HITS: 0.1046129, NOVELTY: 0.0042379, AVERAGE_POPULARITY: 0.5417771, DIVERSITY_MEAN_INTER_LIST: 0.7073110, DIVERSITY_HERFINDAHL: 0.9707227, COVERAGE_ITEM: 0.1255513, COVERAGE_ITEM_HIT: 0.0147151, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1618136, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0080303, SHANNON_ENTROPY: 6.5827886, RATIO_DIVERSITY_HERFINDAHL: 0.9710752, RATIO_DIVERSITY_GINI: 0.0231679, RATIO_SHANNON_ENTROPY: 0.5073002, RATIO_AVERAGE_POPULARITY: 4.4363501, RATIO_NOVELTY: 0.2660994,
#
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 8.9149
# Function value obtained: -0.0114
# Current minimum: -0.0148
# Iteration No: 45 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 5, 'shrink': 0, 'similarity': 'cosine', 'normalize': True}
# SearchBayesianSkopt: Config 44 was already explored at index 21. Config: {'topK': 5, 'shrink': 0, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0346741, PRECISION_RECALL_MIN_DEN: 0.1027179, RECALL: 0.1001089, MAP: 0.0148399, MAP_MIN_DEN: 0.0440241, MRR: 0.1186566, NDCG: 0.0764356, F1: 0.0515078, HIT_RATE: 0.2775346, ARHR_ALL_HITS: 0.1323148, NOVELTY: 0.0058926, AVERAGE_POPULARITY: 0.1244829, DIVERSITY_MEAN_INTER_LIST: 0.9863622, DIVERSITY_HERFINDAHL: 0.9986246, COVERAGE_ITEM: 0.5759158, COVERAGE_ITEM_HIT: 0.0563406, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1856306, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.1669047, SHANNON_ENTROPY: 11.5296958, RATIO_DIVERSITY_HERFINDAHL: 0.9989871, RATIO_DIVERSITY_GINI: 0.4815331, RATIO_SHANNON_ENTROPY: 0.8885318, RATIO_AVERAGE_POPULARITY: 1.0193299, RATIO_NOVELTY: 0.3699992,
# /home/kinami/.conda/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 0.5302
# Function value obtained: -0.0148
# Current minimum: -0.0148
# Iteration No: 46 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 579, 'shrink': 993, 'similarity': 'cosine', 'normalize': True}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 9966.95 column/sec. Elapsed time 2.23 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 6.89 sec. Users per second: 1227
# SearchBayesianSkopt: Config 45 is suboptimal. Config: {'topK': 579, 'shrink': 993, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0247486, PRECISION_RECALL_MIN_DEN: 0.0791595, RECALL: 0.0772943, MAP: 0.0096059, MAP_MIN_DEN: 0.0316810, MRR: 0.0823194, NDCG: 0.0555134, F1: 0.0374926, HIT_RATE: 0.2119957, ARHR_ALL_HITS: 0.0888728, NOVELTY: 0.0042156, AVERAGE_POPULARITY: 0.5898824, DIVERSITY_MEAN_INTER_LIST: 0.6054838, DIVERSITY_HERFINDAHL: 0.9605412, COVERAGE_ITEM: 0.0931959, COVERAGE_ITEM_HIT: 0.0102151, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1417946, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0046833, SHANNON_ENTROPY: 5.9155247, RATIO_DIVERSITY_HERFINDAHL: 0.9608900, RATIO_DIVERSITY_GINI: 0.0135116, RATIO_SHANNON_ENTROPY: 0.4558778, RATIO_AVERAGE_POPULARITY: 4.8302612, RATIO_NOVELTY: 0.2646993,
#
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 9.8195
# Function value obtained: -0.0096
# Current minimum: -0.0148
# Iteration No: 47 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 493, 'shrink': 457, 'similarity': 'cosine', 'normalize': True}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 9794.27 column/sec. Elapsed time 2.27 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 6.86 sec. Users per second: 1232
# SearchBayesianSkopt: Config 46 is suboptimal. Config: {'topK': 493, 'shrink': 457, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0266296, PRECISION_RECALL_MIN_DEN: 0.0846449, RECALL: 0.0827092, MAP: 0.0106290, MAP_MIN_DEN: 0.0349993, MRR: 0.0907292, NDCG: 0.0605400, F1: 0.0402879, HIT_RATE: 0.2271383, ARHR_ALL_HITS: 0.0981577, NOVELTY: 0.0042887, AVERAGE_POPULARITY: 0.5515570, DIVERSITY_MEAN_INTER_LIST: 0.6783798, DIVERSITY_HERFINDAHL: 0.9678300, COVERAGE_ITEM: 0.1026910, COVERAGE_ITEM_HIT: 0.0126451, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1519228, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0060192, SHANNON_ENTROPY: 6.3441757, RATIO_DIVERSITY_HERFINDAHL: 0.9681813, RATIO_DIVERSITY_GINI: 0.0173658, RATIO_SHANNON_ENTROPY: 0.4889116, RATIO_AVERAGE_POPULARITY: 4.5164335, RATIO_NOVELTY: 0.2692908,
#
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 9.8535
# Function value obtained: -0.0106
# Current minimum: -0.0148
# Iteration No: 48 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 743, 'shrink': 992, 'similarity': 'cosine', 'normalize': False}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 10763.99 column/sec. Elapsed time 2.06 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 7.58 sec. Users per second: 1116
# SearchBayesianSkopt: Config 47 is suboptimal. Config: {'topK': 743, 'shrink': 992, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0226074, PRECISION_RECALL_MIN_DEN: 0.0734291, RECALL: 0.0717499, MAP: 0.0084802, MAP_MIN_DEN: 0.0281340, MRR: 0.0737444, NDCG: 0.0501551, F1: 0.0343816, HIT_RATE: 0.1955519, ARHR_ALL_HITS: 0.0790371, NOVELTY: 0.0041362, AVERAGE_POPULARITY: 0.6294732, DIVERSITY_MEAN_INTER_LIST: 0.5141615, DIVERSITY_HERFINDAHL: 0.9514101, COVERAGE_ITEM: 0.0787958, COVERAGE_ITEM_HIT: 0.0080101, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1307960, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0033530, SHANNON_ENTROPY: 5.4296836, RATIO_DIVERSITY_HERFINDAHL: 0.9517555, RATIO_DIVERSITY_GINI: 0.0096736, RATIO_SHANNON_ENTROPY: 0.4184366, RATIO_AVERAGE_POPULARITY: 5.1544511, RATIO_NOVELTY: 0.2597145,
#
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 10.4269
# Function value obtained: -0.0085
# Current minimum: -0.0148
# Iteration No: 49 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 797, 'shrink': 1, 'similarity': 'cosine', 'normalize': False}
# ItemKNNCFRecommender: URM Detected 338 ( 2.7%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 206 ( 0.9%) items with no interactions.
# Similarity column 22222 (100.0%), 10778.84 column/sec. Elapsed time 2.06 sec
# EvaluatorHoldout: Processed 8453 (100.0%) in 7.65 sec. Users per second: 1104
# SearchBayesianSkopt: Config 48 is suboptimal. Config: {'topK': 797, 'shrink': 1, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0224299, PRECISION_RECALL_MIN_DEN: 0.0724374, RECALL: 0.0707639, MAP: 0.0084204, MAP_MIN_DEN: 0.0279267, MRR: 0.0733762, NDCG: 0.0497174, F1: 0.0340629, HIT_RATE: 0.1942506, ARHR_ALL_HITS: 0.0785658, NOVELTY: 0.0041460, AVERAGE_POPULARITY: 0.6285188, DIVERSITY_MEAN_INTER_LIST: 0.5143459, DIVERSITY_HERFINDAHL: 0.9514285, COVERAGE_ITEM: 0.0765008, COVERAGE_ITEM_HIT: 0.0077401, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1299256, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.0032465, SHANNON_ENTROPY: 5.4211884, RATIO_DIVERSITY_HERFINDAHL: 0.9517739, RATIO_DIVERSITY_GINI: 0.0093663, RATIO_SHANNON_ENTROPY: 0.4177819, RATIO_AVERAGE_POPULARITY: 5.1466361, RATIO_NOVELTY: 0.2603322,
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 10.4972
# Function value obtained: -0.0084
# Current minimum: -0.0148
# Iteration No: 50 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 5, 'shrink': 0, 'similarity': 'cosine', 'normalize': True}
# SearchBayesianSkopt: Config 49 was already explored at index 21. Config: {'topK': 5, 'shrink': 0, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0346741, PRECISION_RECALL_MIN_DEN: 0.1027179, RECALL: 0.1001089, MAP: 0.0148399, MAP_MIN_DEN: 0.0440241, MRR: 0.1186566, NDCG: 0.0764356, F1: 0.0515078, HIT_RATE: 0.2775346, ARHR_ALL_HITS: 0.1323148, NOVELTY: 0.0058926, AVERAGE_POPULARITY: 0.1244829, DIVERSITY_MEAN_INTER_LIST: 0.9863622, DIVERSITY_HERFINDAHL: 0.9986246, COVERAGE_ITEM: 0.5759158, COVERAGE_ITEM_HIT: 0.0563406, ITEMS_IN_GT: 0.5502655, COVERAGE_USER: 0.6688558, COVERAGE_USER_HIT: 0.1856306, USERS_IN_GT: 0.6688558, DIVERSITY_GINI: 0.1669047, SHANNON_ENTROPY: 11.5296958, RATIO_DIVERSITY_HERFINDAHL: 0.9989871, RATIO_DIVERSITY_GINI: 0.4815331, RATIO_SHANNON_ENTROPY: 0.8885318, RATIO_AVERAGE_POPULARITY: 1.0193299, RATIO_NOVELTY: 0.3699992,
# /home/kinami/.conda/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 0.6870
# Function value obtained: -0.0148
# Current minimum: -0.0148
# SearchBayesianSkopt: Search complete. Best config is 21: {'topK': 5, 'shrink': 0, 'similarity': 'cosine', 'normalize': True}
#
# ItemKNNCFRecommender: URM Detected 4185 (33.1%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 9994 (45.0%) items with no interactions.
# SearchBayesianSkopt: Evaluation with constructor data for final test. Using best config: {'topK': 5, 'shrink': 0, 'similarity': 'cosine', 'normalize': True}
# Similarity column 22222 (100.0%), 13710.42 column/sec. Elapsed time 1.62 sec
# EvaluatorHoldout: Processed 10506 (100.0%) in 3.03 sec. Users per second: 3469
# SearchBayesianSkopt: Best config evaluated with evaluator_test with constructor data for final test. Config: {'topK': 5, 'shrink': 0, 'similarity': 'cosine', 'normalize': True} - results:
# CUTOFF: 10 - PRECISION: 0.0009328, PRECISION_RECALL_MIN_DEN: 0.0010987, RECALL: 0.0006603, MAP: 0.0003591, MAP_MIN_DEN: 0.0004136, MRR: 0.0034521, NDCG: 0.0011614, F1: 0.0007733, HIT_RATE: 0.0089473, ARHR_ALL_HITS: 0.0035213, NOVELTY: 0.0049811, AVERAGE_POPULARITY: 0.0063840, DIVERSITY_MEAN_INTER_LIST: 0.8123408, DIVERSITY_HERFINDAHL: 0.9812264, COVERAGE_ITEM: 0.3159932, COVERAGE_ITEM_HIT: 0.0041850, ITEMS_IN_GT: 0.8000180, COVERAGE_USER: 0.8313024, COVERAGE_USER_HIT: 0.0074379, USERS_IN_GT: 0.8313024, DIVERSITY_GINI: 0.0851191, SHANNON_ENTROPY: 9.2663334, RATIO_DIVERSITY_HERFINDAHL: 0.9816063, RATIO_DIVERSITY_GINI: 0.3380297, RATIO_SHANNON_ENTROPY: 0.7365029, RATIO_AVERAGE_POPULARITY: 0.0775565, RATIO_NOVELTY: 2.9031511,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNCFRecommender
#
# ItemKNNCFRecommender: Saving model in file 'result_experiments/ItemKNNCFRecommender_best_model_last'
# ItemKNNCFRecommender: Saving complete

# %%
data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + "_metadata.zip")

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters
# Out:
# {'topK': 5, 'shrink': 0, 'similarity': 'cosine', 'normalize': True}

# %%
search_metadata['result_on_test_best']
# Out:
#        PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
# cutoff
# 10      0.071283                 0.123001  0.103423  0.035444    0.060188
#
#              MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                        ...
# 10      0.211227  0.112319  0.084397  0.423187      0.270861  ...
#
#        COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
# cutoff
# 10          0.831302          0.351796    0.831302       0.163634
#
#        SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
# cutoff
# 10             11.3511                   0.998459             0.472097
#
#        RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
# cutoff
# 10                  0.874768                 1.011607      0.370982
#
# [1 rows x 27 columns]

# %%
recommender_object = recommender_class(data_train + data_validation)
# Out:
# ItemKNNCFRecommender: URM Detected 239 ( 1.9%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 113 ( 0.5%) items with no interactions.

# %%
recommender_object.load_model(output_folder_path, 
                              file_name = recommender_object.RECOMMENDER_NAME + "_best_model_last.zip" )
# Out:
# ItemKNNCFRecommender: Loading model from file 'result_experiments/ItemKNNCFRecommender_best_model_last.zip'
# ItemKNNCFRecommender: Loading complete

# %%
def prepare_submission(ratings: pd.DataFrame, users_to_recommend: np.array, urm_train: sp.csr_matrix, recommender: object):
    users_ids_and_mappings = ratings[ratings.user_id.isin(users_to_recommend)][["user_id", "mapped_user_id"]].drop_duplicates()

    mapping_to_item_id = dict(zip(ratings.mapped_item_id, ratings.item_id))
    item_ids = ratings.item_id.unique()


    recommendation_length = 10
    submission = dict()
    for idx, row in users_ids_and_mappings.iterrows():
        user_id = row.user_id
        mapped_user_id = row.mapped_user_id

        recommendations = recommender.recommend(mapped_user_id, cutoff = 10)

        submission[user_id] = [mapping_to_item_id[item_id] for item_id in recommendations]
    
    for user_id in users_to_recommend:
        if user_id not in submission:
            submission[user_id] = np.random.choice(item_ids, 10)

    return submission

# %%
from utils import write_submission

write_submission(prepare_submission(data, users, data_train + data_validation, recommender_object))
