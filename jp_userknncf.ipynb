# %%
import os

from utils import *
from Recommenders.DataIO import DataIO
from Evaluation.Evaluator import EvaluatorHoldout

# %%
data = load_data()
users = load_users()
data, num_users, num_items, mapping_user_id = preprocess_data(data)
data_train, data_validation, data_test = split_data(
    data,
    num_users=num_users,
    num_items=num_items,
    validation_percentage=0.1,
    testing_percentage=0.20
)

# %%
evaluator_validation = EvaluatorHoldout(data_validation, cutoff_list=[10])
evaluator_test = EvaluatorHoldout(data_test, cutoff_list=[10])
# Out:
# EvaluatorHoldout: Ignoring 4171 (33.0%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 2149 (17.0%) Users that have less than 1 test interactions

# %%
from skopt.space import Real, Integer, Categorical

hyperparameters_range_dictionary = {
    "epochs": Categorical([500]),
    "num_factors": Integer(1, 200),
    "sgd_mode": Categorical(["sgd", "adagrad", "adam"]),
    "batch_size": Categorical([1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]),
    "item_reg": Real(low = 1e-5, high = 1e-2, prior = 'log-uniform'),
    "user_reg": Real(low = 1e-5, high = 1e-2, prior = 'log-uniform'),
    "learning_rate": Real(low = 1e-4, high = 1e-1, prior = 'log-uniform'),
}

# %%
earlystopping_keywargs = {"validation_every_n": 5,
                          "stop_on_validation": True,
                          "evaluator_object": evaluator_validation,
                          "lower_validations_allowed": 5,
                          "validation_metric": "MAP",
                          }

# %%
from Recommenders.KNN.ItemKNNCFRecommender import ItemKNNCFRecommender
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

recommender_class = ItemKNNCFRecommender

hyperparameterSearch = SearchBayesianSkopt(recommender_class,
                                         evaluator_validation=evaluator_validation,
                                         evaluator_test=evaluator_test)
# Out:
# 2023-11-28 20:22:39.181822: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-11-28 20:22:39.181841: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs

recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [data_train],     # For a CBF model simply put [URM_train, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {},
    EARLYSTOPPING_KEYWORD_ARGS = earlystopping_keywargs,     # Additional hyperparameters for the fit function
)

# %%
recommender_input_args_last_test = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [data_validation],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {},
    EARLYSTOPPING_KEYWORD_ARGS = earlystopping_keywargs,
)

# %%
output_folder_path = "result_experiments/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 50
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from HyperparameterTuning.run_hyperparameter_search import runHyperparameterSearch_Collaborative
from Recommenders.KNN.UserKNNCFRecommender import UserKNNCFRecommender

recommender_class = UserKNNCFRecommender

runHyperparameterSearch_Collaborative(recommender_class,
       URM_train = data_train,
       URM_train_last_test = data_train + data_validation,
       metric_to_optimize = metric_to_optimize,
       cutoff_to_optimize = cutoff_to_optimize,
       evaluator_validation_earlystopping = evaluator_validation,
       evaluator_validation = evaluator_validation,
       evaluator_test = evaluator_test,
       output_folder_path = output_folder_path,
       parallelizeKNN = True,
       allow_weighting = True,
       resume_from_saved = True,
       save_model = "best",
       similarity_type_list = ['cosine', 'jaccard', "asymmetric", "dice", "tversky"],
       n_cases = n_cases,
       n_random_starts = n_random_starts)
# Out:
# SearchBayesianSkopt: Resuming 'UserKNNCFRecommender_cosine' Failed, no such file exists.
#
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 442, 'shrink': 297, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# SearchBayesianSkopt: Resuming 'UserKNNCFRecommender_jaccard' Failed, no such file exists.
#
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 76, 'shrink': 672, 'similarity': 'jaccard', 'normalize': True}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# SearchBayesianSkopt: Resuming 'UserKNNCFRecommender_asymmetric' Failed, no such file exists.
#
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 43, 'shrink': 448, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.8533268119047177, 'feature_weighting': 'TF-IDF'}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# SearchBayesianSkopt: Resuming 'UserKNNCFRecommender_dice' Failed, no such file exists.
#
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 199, 'shrink': 784, 'similarity': 'dice', 'normalize': True}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# SearchBayesianSkopt: Resuming 'UserKNNCFRecommender_tversky' Failed, no such file exists.
#
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 511, 'shrink': 711, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 1.5782901457973526, 'tversky_beta': 0.1954892780850091}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# Similarity column 12638 (100.0%), 9175.71 column/sec. Elapsed time 1.38 sec
# Similarity column 12638 (100.0%), 9316.08 column/sec. Elapsed time 1.36 sec
# Similarity column 12638 (100.0%), 9233.69 column/sec. Elapsed time 1.37 sec
# Similarity column 12638 (100.0%), 9366.02 column/sec. Elapsed time 1.35 sec
# Similarity column 12638 (100.0%), 8996.19 column/sec. Elapsed time 1.40 sec
# EvaluatorHoldout: Processed 8467 (100.0%) in 3.90 sec. Users per second: 2172
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 43, 'shrink': 448, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.8533268119047177, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0227944, PRECISION_RECALL_MIN_DEN: 0.0624931, RECALL: 0.0603656, MAP: 0.0093182, MAP_MIN_DEN: 0.0265737, MRR: 0.0793918, NDCG: 0.0478130, F1: 0.0330927, HIT_RATE: 0.1916854, ARHR_ALL_HITS: 0.0859903, NOVELTY: 0.0051797, AVERAGE_POPULARITY: 0.2178003, DIVERSITY_MEAN_INTER_LIST: 0.9755736, DIVERSITY_HERFINDAHL: 0.9975458, COVERAGE_ITEM: 0.3528035, COVERAGE_ITEM_HIT: 0.0289803, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1284222, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0821266, SHANNON_ENTROPY: 10.6281548, RATIO_DIVERSITY_HERFINDAHL: 0.9979069, RATIO_DIVERSITY_GINI: 0.2367924, RATIO_SHANNON_ENTROPY: 0.8190209, RATIO_AVERAGE_POPULARITY: 1.8008280, RATIO_NOVELTY: 0.3252250,
#
# EvaluatorHoldout: Processed 8467 (100.0%) in 4.11 sec. Users per second: 2061
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 76, 'shrink': 672, 'similarity': 'jaccard', 'normalize': True} - results: PRECISION: 0.0236565, PRECISION_RECALL_MIN_DEN: 0.0621759, RECALL: 0.0600031, MAP: 0.0098354, MAP_MIN_DEN: 0.0269224, MRR: 0.0829482, NDCG: 0.0487009, F1: 0.0339343, HIT_RATE: 0.1980631, ARHR_ALL_HITS: 0.0903739, NOVELTY: 0.0051426, AVERAGE_POPULARITY: 0.2289841, DIVERSITY_MEAN_INTER_LIST: 0.9721404, DIVERSITY_HERFINDAHL: 0.9972026, COVERAGE_ITEM: 0.4225092, COVERAGE_ITEM_HIT: 0.0295203, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1326950, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0920643, SHANNON_ENTROPY: 10.6120889, RATIO_DIVERSITY_HERFINDAHL: 0.9975635, RATIO_DIVERSITY_GINI: 0.2654452, RATIO_SHANNON_ENTROPY: 0.8177829, RATIO_AVERAGE_POPULARITY: 1.8932987, RATIO_NOVELTY: 0.3228906,
#
# EvaluatorHoldout: Processed 8467 (100.0%) in 4.65 sec. Users per second: 1821
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 199, 'shrink': 784, 'similarity': 'dice', 'normalize': True} - results: PRECISION: 0.0283808, PRECISION_RECALL_MIN_DEN: 0.0836552, RECALL: 0.0814968, MAP: 0.0118322, MAP_MIN_DEN: 0.0372665, MRR: 0.1004713, NDCG: 0.0638606, F1: 0.0421003, HIT_RATE: 0.2383371, ARHR_ALL_HITS: 0.1090518, NOVELTY: 0.0047481, AVERAGE_POPULARITY: 0.3216096, DIVERSITY_MEAN_INTER_LIST: 0.9351782, DIVERSITY_HERFINDAHL: 0.9935068, COVERAGE_ITEM: 0.2540275, COVERAGE_ITEM_HIT: 0.0263253, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1596772, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0370293, SHANNON_ENTROPY: 9.2235091, RATIO_DIVERSITY_HERFINDAHL: 0.9938664, RATIO_DIVERSITY_GINI: 0.1067651, RATIO_SHANNON_ENTROPY: 0.7107769, RATIO_AVERAGE_POPULARITY: 2.6591499, RATIO_NOVELTY: 0.2981215,
#
# EvaluatorHoldout: Processed 8467 (100.0%) in 5.74 sec. Users per second: 1476
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 442, 'shrink': 297, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0327152, PRECISION_RECALL_MIN_DEN: 0.1050447, RECALL: 0.1026250, MAP: 0.0137013, MAP_MIN_DEN: 0.0462284, MRR: 0.1154437, NDCG: 0.0772988, F1: 0.0496142, HIT_RATE: 0.2732963, ARHR_ALL_HITS: 0.1257791, NOVELTY: 0.0043876, AVERAGE_POPULARITY: 0.4427558, DIVERSITY_MEAN_INTER_LIST: 0.8455713, DIVERSITY_HERFINDAHL: 0.9845471, COVERAGE_ITEM: 0.1040860, COVERAGE_ITEM_HIT: 0.0228602, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1830986, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0102284, SHANNON_ENTROPY: 7.5795212, RATIO_DIVERSITY_HERFINDAHL: 0.9849035, RATIO_DIVERSITY_GINI: 0.0294913, RATIO_SHANNON_ENTROPY: 0.5840888, RATIO_AVERAGE_POPULARITY: 3.6608168, RATIO_NOVELTY: 0.2754902,
#
# EvaluatorHoldout: Processed 8467 (100.0%) in 5.71 sec. Users per second: 1482
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 511, 'shrink': 711, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 1.5782901457973526, 'tversky_beta': 0.1954892780850091} - results: PRECISION: 0.0306720, PRECISION_RECALL_MIN_DEN: 0.0995180, RECALL: 0.0975487, MAP: 0.0126018, MAP_MIN_DEN: 0.0431804, MRR: 0.1069830, NDCG: 0.0725627, F1: 0.0466698, HIT_RATE: 0.2588874, ARHR_ALL_HITS: 0.1161181, NOVELTY: 0.0044301, AVERAGE_POPULARITY: 0.4314203, DIVERSITY_MEAN_INTER_LIST: 0.8551124, DIVERSITY_HERFINDAHL: 0.9855011, COVERAGE_ITEM: 0.1387814, COVERAGE_ITEM_HIT: 0.0205202, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1734452, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0135881, SHANNON_ENTROPY: 7.7963127, RATIO_DIVERSITY_HERFINDAHL: 0.9858578, RATIO_DIVERSITY_GINI: 0.0391781, RATIO_SHANNON_ENTROPY: 0.6007951, RATIO_AVERAGE_POPULARITY: 3.5670926, RATIO_NOVELTY: 0.2781589,
#
# EvaluatorHoldout: Processed 10489 (100.0%) in 4.69 sec. Users per second: 2238
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 43, 'shrink': 448, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.8533268119047177, 'feature_weighting': 'TF-IDF'} - results:
# CUTOFF: 10 - PRECISION: 0.0455906, PRECISION_RECALL_MIN_DEN: 0.0704167, RECALL: 0.0557900, MAP: 0.0212491, MAP_MIN_DEN: 0.0332702, MRR: 0.1401203, NDCG: 0.0669997, F1: 0.0501773, HIT_RATE: 0.2948804, ARHR_ALL_HITS: 0.1712991, NOVELTY: 0.0052735, AVERAGE_POPULARITY: 0.2015413, DIVERSITY_MEAN_INTER_LIST: 0.9784702, DIVERSITY_HERFINDAHL: 0.9978377, COVERAGE_ITEM: 0.3819188, COVERAGE_ITEM_HIT: 0.0502205, ITEMS_IN_GT: 0.8001980, COVERAGE_USER: 0.8299573, COVERAGE_USER_HIT: 0.2447381, USERS_IN_GT: 0.8299573, DIVERSITY_GINI: 0.0887534, SHANNON_ENTROPY: 10.7698394, RATIO_DIVERSITY_HERFINDAHL: 0.9981989, RATIO_DIVERSITY_GINI: 0.2558989, RATIO_SHANNON_ENTROPY: 0.8299394, RATIO_AVERAGE_POPULARITY: 1.6663941, RATIO_NOVELTY: 0.3311103,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/UserKNNCFRecommender_asymmetric
#
# UserKNNCFRecommender: Saving model in file 'result_experiments/UserKNNCFRecommender_asymmetric_best_model'
# EvaluatorHoldout: Processed 10489 (100.0%) in 4.83 sec. Users per second: 2171
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 76, 'shrink': 672, 'similarity': 'jaccard', 'normalize': True} - results:
# CUTOFF: 10 - PRECISION: 0.0473448, PRECISION_RECALL_MIN_DEN: 0.0700332, RECALL: 0.0546764, MAP: 0.0221380, MAP_MIN_DEN: 0.0332686, MRR: 0.1447543, NDCG: 0.0680294, F1: 0.0507472, HIT_RATE: 0.3070836, ARHR_ALL_HITS: 0.1779061, NOVELTY: 0.0052525, AVERAGE_POPULARITY: 0.2081562, DIVERSITY_MEAN_INTER_LIST: 0.9767250, DIVERSITY_HERFINDAHL: 0.9976632, COVERAGE_ITEM: 0.4743947, COVERAGE_ITEM_HIT: 0.0484655, ITEMS_IN_GT: 0.8001980, COVERAGE_USER: 0.8299573, COVERAGE_USER_HIT: 0.2548663, USERS_IN_GT: 0.8299573, DIVERSITY_GINI: 0.1037039, SHANNON_ENTROPY: 10.8255704, RATIO_DIVERSITY_HERFINDAHL: 0.9980243, RATIO_DIVERSITY_GINI: 0.2990052, RATIO_SHANNON_ENTROPY: 0.8342341, RATIO_AVERAGE_POPULARITY: 1.7210880, RATIO_NOVELTY: 0.3297941,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/UserKNNCFRecommender_jaccard
#
# UserKNNCFRecommender: Saving model in file 'result_experiments/UserKNNCFRecommender_jaccard_best_model'
# UserKNNCFRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 10.5315
# Function value obtained: -0.0093
# Current minimum: -0.0093
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 491, 'shrink': 64, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.45259074875292826, 'feature_weighting': 'none'}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# UserKNNCFRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 11.1231
# Function value obtained: -0.0098
# Current minimum: -0.0098
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 366, 'shrink': 516, 'similarity': 'jaccard', 'normalize': False}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# EvaluatorHoldout: Processed 10489 (100.0%) in 5.79 sec. Users per second: 1810
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 199, 'shrink': 784, 'similarity': 'dice', 'normalize': True} - results:
# CUTOFF: 10 - PRECISION: 0.0575269, PRECISION_RECALL_MIN_DEN: 0.0954763, RECALL: 0.0795239, MAP: 0.0269708, MAP_MIN_DEN: 0.0453328, MRR: 0.1794759, NDCG: 0.0888599, F1: 0.0667601, HIT_RATE: 0.3773477, ARHR_ALL_HITS: 0.2187797, NOVELTY: 0.0048461, AVERAGE_POPULARITY: 0.2974251, DIVERSITY_MEAN_INTER_LIST: 0.9462338, DIVERSITY_HERFINDAHL: 0.9946144, COVERAGE_ITEM: 0.3027630, COVERAGE_ITEM_HIT: 0.0424354, ITEMS_IN_GT: 0.8001980, COVERAGE_USER: 0.8299573, COVERAGE_USER_HIT: 0.3131825, USERS_IN_GT: 0.8299573, DIVERSITY_GINI: 0.0441600, SHANNON_ENTROPY: 9.4871548, RATIO_DIVERSITY_HERFINDAHL: 0.9949744, RATIO_DIVERSITY_GINI: 0.1273248, RATIO_SHANNON_ENTROPY: 0.7310938, RATIO_AVERAGE_POPULARITY: 2.4591865, RATIO_NOVELTY: 0.3042797,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/UserKNNCFRecommender_dice
#
# UserKNNCFRecommender: Saving model in file 'result_experiments/UserKNNCFRecommender_dice_best_model'
# Similarity column 12638 (100.0%), 8462.92 column/sec. Elapsed time 1.49 sec
# Similarity column 12638 (100.0%), 8900.88 column/sec. Elapsed time 1.42 sec
# UserKNNCFRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 13.4782
# Function value obtained: -0.0118
# Current minimum: -0.0118
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 289, 'shrink': 908, 'similarity': 'dice', 'normalize': False}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# EvaluatorHoldout: Processed 10489 (100.0%) in 6.87 sec. Users per second: 1527
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 442, 'shrink': 297, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results:
# CUTOFF: 10 - PRECISION: 0.0651063, PRECISION_RECALL_MIN_DEN: 0.1191918, RECALL: 0.1020715, MAP: 0.0305131, MAP_MIN_DEN: 0.0553274, MRR: 0.2010517, NDCG: 0.1054900, F1: 0.0795021, HIT_RATE: 0.4247307, ARHR_ALL_HITS: 0.2462441, NOVELTY: 0.0044226, AVERAGE_POPULARITY: 0.4385390, DIVERSITY_MEAN_INTER_LIST: 0.8466035, DIVERSITY_HERFINDAHL: 0.9846523, COVERAGE_ITEM: 0.1287013, COVERAGE_ITEM_HIT: 0.0338403, ITEMS_IN_GT: 0.8001980, COVERAGE_USER: 0.8299573, COVERAGE_USER_HIT: 0.3525083, USERS_IN_GT: 0.8299573, DIVERSITY_GINI: 0.0113515, SHANNON_ENTROPY: 7.6377507, RATIO_DIVERSITY_HERFINDAHL: 0.9850087, RATIO_DIVERSITY_GINI: 0.0327292, RATIO_SHANNON_ENTROPY: 0.5885761, RATIO_AVERAGE_POPULARITY: 3.6259514, RATIO_NOVELTY: 0.2776889,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/UserKNNCFRecommender_cosine
#
# UserKNNCFRecommender: Saving model in file 'result_experiments/UserKNNCFRecommender_cosine_best_model'
# EvaluatorHoldout: Processed 10489 (100.0%) in 6.76 sec. Users per second: 1552
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 511, 'shrink': 711, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 1.5782901457973526, 'tversky_beta': 0.1954892780850091} - results:
# CUTOFF: 10 - PRECISION: 0.0605873, PRECISION_RECALL_MIN_DEN: 0.1112337, RECALL: 0.0965887, MAP: 0.0282184, MAP_MIN_DEN: 0.0521650, MRR: 0.1927715, NDCG: 0.0994553, F1: 0.0744649, HIT_RATE: 0.4077605, ARHR_ALL_HITS: 0.2322267, NOVELTY: 0.0045135, AVERAGE_POPULARITY: 0.4070001, DIVERSITY_MEAN_INTER_LIST: 0.8749865, DIVERSITY_HERFINDAHL: 0.9874903, COVERAGE_ITEM: 0.1791018, COVERAGE_ITEM_HIT: 0.0302403, ITEMS_IN_GT: 0.8001980, COVERAGE_USER: 0.8299573, COVERAGE_USER_HIT: 0.3384238, USERS_IN_GT: 0.8299573, DIVERSITY_GINI: 0.0170982, SHANNON_ENTROPY: 8.0630455, RATIO_DIVERSITY_HERFINDAHL: 0.9878477, RATIO_DIVERSITY_GINI: 0.0492984, RATIO_SHANNON_ENTROPY: 0.6213499, RATIO_AVERAGE_POPULARITY: 3.3651799, RATIO_NOVELTY: 0.2833937,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/UserKNNCFRecommender_tversky
#
# UserKNNCFRecommender: Saving model in file 'result_experiments/UserKNNCFRecommender_tversky_best_model'
# Similarity column 12638 (100.0%), 9310.83 column/sec. Elapsed time 1.36 sec
# UserKNNCFRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 17.0128
# Function value obtained: -0.0137
# Current minimum: -0.0137
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 167, 'shrink': 977, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'none'}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# UserKNNCFRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 17.2338
# Function value obtained: -0.0126
# Current minimum: -0.0126
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 587, 'shrink': 301, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 1.1753827810911606, 'tversky_beta': 0.30973246934784787}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# EvaluatorHoldout: Processed 8467 (100.0%) in 5.15 sec. Users per second: 1644
# SearchBayesianSkopt: New best config found. Config 1: {'topK': 366, 'shrink': 516, 'similarity': 'jaccard', 'normalize': False} - results: PRECISION: 0.0299752, PRECISION_RECALL_MIN_DEN: 0.0945199, RECALL: 0.0925261, MAP: 0.0123771, MAP_MIN_DEN: 0.0412276, MRR: 0.1051470, NDCG: 0.0698054, F1: 0.0452810, HIT_RATE: 0.2532184, ARHR_ALL_HITS: 0.1141212, NOVELTY: 0.0045265, AVERAGE_POPULARITY: 0.3947342, DIVERSITY_MEAN_INTER_LIST: 0.8870540, DIVERSITY_HERFINDAHL: 0.9886949, COVERAGE_ITEM: 0.1734767, COVERAGE_ITEM_HIT: 0.0227252, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1696471, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0192410, SHANNON_ENTROPY: 8.2633204, RATIO_DIVERSITY_HERFINDAHL: 0.9890528, RATIO_DIVERSITY_GINI: 0.0554769, RATIO_SHANNON_ENTROPY: 0.6367834, RATIO_AVERAGE_POPULARITY: 3.2637625, RATIO_NOVELTY: 0.2842077,
#
# EvaluatorHoldout: Processed 8467 (100.0%) in 5.66 sec. Users per second: 1497
# SearchBayesianSkopt: New best config found. Config 1: {'topK': 491, 'shrink': 64, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.45259074875292826, 'feature_weighting': 'none'} - results: PRECISION: 0.0308137, PRECISION_RECALL_MIN_DEN: 0.0993082, RECALL: 0.0972422, MAP: 0.0126699, MAP_MIN_DEN: 0.0430300, MRR: 0.1078681, NDCG: 0.0725683, F1: 0.0467982, HIT_RATE: 0.2599504, ARHR_ALL_HITS: 0.1168927, NOVELTY: 0.0044063, AVERAGE_POPULARITY: 0.4431471, DIVERSITY_MEAN_INTER_LIST: 0.8421058, DIVERSITY_HERFINDAHL: 0.9842006, COVERAGE_ITEM: 0.1345063, COVERAGE_ITEM_HIT: 0.0202502, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1741573, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0128081, SHANNON_ENTROPY: 7.6791473, RATIO_DIVERSITY_HERFINDAHL: 0.9845569, RATIO_DIVERSITY_GINI: 0.0369291, RATIO_SHANNON_ENTROPY: 0.5917662, RATIO_AVERAGE_POPULARITY: 3.6640521, RATIO_NOVELTY: 0.2766629,
#
# Similarity column 12638 (100.0%), 9391.23 column/sec. Elapsed time 1.35 sec
# Similarity column 12638 (100.0%), 8610.36 column/sec. Elapsed time 1.47 sec
# EvaluatorHoldout: Processed 8467 (100.0%) in 4.88 sec. Users per second: 1734
# SearchBayesianSkopt: New best config found. Config 1: {'topK': 289, 'shrink': 908, 'similarity': 'dice', 'normalize': False} - results: PRECISION: 0.0294792, PRECISION_RECALL_MIN_DEN: 0.0912764, RECALL: 0.0892308, MAP: 0.0122759, MAP_MIN_DEN: 0.0401668, MRR: 0.1052901, NDCG: 0.0683192, F1: 0.0443172, HIT_RATE: 0.2497933, ARHR_ALL_HITS: 0.1137163, NOVELTY: 0.0046123, AVERAGE_POPULARITY: 0.3633907, DIVERSITY_MEAN_INTER_LIST: 0.9104596, DIVERSITY_HERFINDAHL: 0.9910352, COVERAGE_ITEM: 0.2008370, COVERAGE_ITEM_HIT: 0.0236702, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1673524, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0249229, SHANNON_ENTROPY: 8.6551813, RATIO_DIVERSITY_HERFINDAHL: 0.9913939, RATIO_DIVERSITY_GINI: 0.0718592, RATIO_SHANNON_ENTROPY: 0.6669808, RATIO_AVERAGE_POPULARITY: 3.0046061, RATIO_NOVELTY: 0.2895964,
#
# EvaluatorHoldout: Processed 8467 (100.0%) in 4.40 sec. Users per second: 1925
# SearchBayesianSkopt: Config 1 is suboptimal. Config: {'topK': 167, 'shrink': 977, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'none'} - results: PRECISION: 0.0249793, PRECISION_RECALL_MIN_DEN: 0.0649914, RECALL: 0.0628882, MAP: 0.0103585, MAP_MIN_DEN: 0.0281612, MRR: 0.0879339, NDCG: 0.0513233, F1: 0.0357562, HIT_RATE: 0.2099917, ARHR_ALL_HITS: 0.0954499, NOVELTY: 0.0050866, AVERAGE_POPULARITY: 0.2546898, DIVERSITY_MEAN_INTER_LIST: 0.9611963, DIVERSITY_HERFINDAHL: 0.9961083, COVERAGE_ITEM: 0.4221942, COVERAGE_ITEM_HIT: 0.0257853, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1406868, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0862786, SHANNON_ENTROPY: 10.3072610, RATIO_DIVERSITY_HERFINDAHL: 0.9964688, RATIO_DIVERSITY_GINI: 0.2487635, RATIO_SHANNON_ENTROPY: 0.7942924, RATIO_AVERAGE_POPULARITY: 2.1058400, RATIO_NOVELTY: 0.3193793,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 5.9312
# Function value obtained: -0.0104
# Current minimum: -0.0137
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 127, 'shrink': 923, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# EvaluatorHoldout: Processed 10489 (100.0%) in 6.34 sec. Users per second: 1655
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 366, 'shrink': 516, 'similarity': 'jaccard', 'normalize': False} - results:
# CUTOFF: 10 - PRECISION: 0.0606159, PRECISION_RECALL_MIN_DEN: 0.1084660, RECALL: 0.0931443, MAP: 0.0283382, MAP_MIN_DEN: 0.0509735, MRR: 0.1911526, NDCG: 0.0978198, F1: 0.0734393, HIT_RATE: 0.4030890, ARHR_ALL_HITS: 0.2315935, NOVELTY: 0.0046135, AVERAGE_POPULARITY: 0.3699393, DIVERSITY_MEAN_INTER_LIST: 0.9041209, DIVERSITY_HERFINDAHL: 0.9904035, COVERAGE_ITEM: 0.2140671, COVERAGE_ITEM_HIT: 0.0355504, ITEMS_IN_GT: 0.8001980, COVERAGE_USER: 0.8299573, COVERAGE_USER_HIT: 0.3345466, USERS_IN_GT: 0.8299573, DIVERSITY_GINI: 0.0235172, SHANNON_ENTROPY: 8.5304513, RATIO_DIVERSITY_HERFINDAHL: 0.9907619, RATIO_DIVERSITY_GINI: 0.0678062, RATIO_SHANNON_ENTROPY: 0.6573689, RATIO_AVERAGE_POPULARITY: 3.0587517, RATIO_NOVELTY: 0.2896692,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/UserKNNCFRecommender_jaccard
#
# UserKNNCFRecommender: Saving model in file 'result_experiments/UserKNNCFRecommender_jaccard_best_model'
# Similarity column 12638 (100.0%), 9226.43 column/sec. Elapsed time 1.37 sec
# EvaluatorHoldout: Processed 10489 (100.0%) in 6.90 sec. Users per second: 1520
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 491, 'shrink': 64, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.45259074875292826, 'feature_weighting': 'none'} - results:
# CUTOFF: 10 - PRECISION: 0.0610068, PRECISION_RECALL_MIN_DEN: 0.1111954, RECALL: 0.0959851, MAP: 0.0282978, MAP_MIN_DEN: 0.0519951, MRR: 0.1927757, NDCG: 0.0994628, F1: 0.0745993, HIT_RATE: 0.4092859, ARHR_ALL_HITS: 0.2325797, NOVELTY: 0.0044893, AVERAGE_POPULARITY: 0.4185464, DIVERSITY_MEAN_INTER_LIST: 0.8635513, DIVERSITY_HERFINDAHL: 0.9863469, COVERAGE_ITEM: 0.1735667, COVERAGE_ITEM_HIT: 0.0307803, ITEMS_IN_GT: 0.8001980, COVERAGE_USER: 0.8299573, COVERAGE_USER_HIT: 0.3396898, USERS_IN_GT: 0.8299573, DIVERSITY_GINI: 0.0162167, SHANNON_ENTROPY: 7.9521817, RATIO_DIVERSITY_HERFINDAHL: 0.9867039, RATIO_DIVERSITY_GINI: 0.0467569, RATIO_SHANNON_ENTROPY: 0.6128066, RATIO_AVERAGE_POPULARITY: 3.4606473, RATIO_NOVELTY: 0.2818753,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/UserKNNCFRecommender_asymmetric
#
# UserKNNCFRecommender: Saving model in file 'result_experiments/UserKNNCFRecommender_asymmetric_best_model'
# EvaluatorHoldout: Processed 8467 (100.0%) in 6.00 sec. Users per second: 1412
# SearchBayesianSkopt: Config 1 is suboptimal. Config: {'topK': 587, 'shrink': 301, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 1.1753827810911606, 'tversky_beta': 0.30973246934784787} - results: PRECISION: 0.0304712, PRECISION_RECALL_MIN_DEN: 0.0997521, RECALL: 0.0977761, MAP: 0.0124901, MAP_MIN_DEN: 0.0431739, MRR: 0.1065507, NDCG: 0.0725345, F1: 0.0464627, HIT_RATE: 0.2595961, ARHR_ALL_HITS: 0.1153596, NOVELTY: 0.0043841, AVERAGE_POPULARITY: 0.4511851, DIVERSITY_MEAN_INTER_LIST: 0.8348935, DIVERSITY_HERFINDAHL: 0.9834795, COVERAGE_ITEM: 0.1257313, COVERAGE_ITEM_HIT: 0.0196652, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1739199, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0115501, SHANNON_ENTROPY: 7.5638445, RATIO_DIVERSITY_HERFINDAHL: 0.9838355, RATIO_DIVERSITY_GINI: 0.0333019, RATIO_SHANNON_ENTROPY: 0.5828808, RATIO_AVERAGE_POPULARITY: 3.7305126, RATIO_NOVELTY: 0.2752706,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 7.7414
# Function value obtained: -0.0125
# Current minimum: -0.0126
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 266, 'shrink': 777, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 1.5598185035192103, 'tversky_beta': 1.6373156113388752}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# EvaluatorHoldout: Processed 10489 (100.0%) in 5.99 sec. Users per second: 1750
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 289, 'shrink': 908, 'similarity': 'dice', 'normalize': False} - results:
# CUTOFF: 10 - PRECISION: 0.0598436, PRECISION_RECALL_MIN_DEN: 0.1038894, RECALL: 0.0883771, MAP: 0.0281020, MAP_MIN_DEN: 0.0492650, MRR: 0.1885681, NDCG: 0.0951177, F1: 0.0713639, HIT_RATE: 0.3960339, ARHR_ALL_HITS: 0.2289988, NOVELTY: 0.0047013, AVERAGE_POPULARITY: 0.3393665, DIVERSITY_MEAN_INTER_LIST: 0.9243974, DIVERSITY_HERFINDAHL: 0.9924309, COVERAGE_ITEM: 0.2459725, COVERAGE_ITEM_HIT: 0.0391054, ITEMS_IN_GT: 0.8001980, COVERAGE_USER: 0.8299573, COVERAGE_USER_HIT: 0.3286912, USERS_IN_GT: 0.8299573, DIVERSITY_GINI: 0.0301207, SHANNON_ENTROPY: 8.9135713, RATIO_DIVERSITY_HERFINDAHL: 0.9927901, RATIO_DIVERSITY_GINI: 0.0868458, RATIO_SHANNON_ENTROPY: 0.6868927, RATIO_AVERAGE_POPULARITY: 2.8059685, RATIO_NOVELTY: 0.2951827,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/UserKNNCFRecommender_dice
#
# UserKNNCFRecommender: Saving model in file 'result_experiments/UserKNNCFRecommender_dice_best_model'
# Similarity column 12638 (100.0%), 9463.73 column/sec. Elapsed time 1.34 sec
# UserKNNCFRecommender: Saving complete
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 15.5902
# Function value obtained: -0.0124
# Current minimum: -0.0124
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 428, 'shrink': 267, 'similarity': 'jaccard', 'normalize': False}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# UserKNNCFRecommender: Saving complete
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 17.3178
# Function value obtained: -0.0127
# Current minimum: -0.0127
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 634, 'shrink': 846, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 1.9824825763044123, 'feature_weighting': 'TF-IDF'}
# UserKNNCFRecommender: Saving complete
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 14.4176
# Function value obtained: -0.0123
# Current minimum: -0.0123
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 320, 'shrink': 822, 'similarity': 'dice', 'normalize': True}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# Similarity column 12638 (100.0%), 8877.19 column/sec. Elapsed time 1.42 sec
# EvaluatorHoldout: Processed 8467 (100.0%) in 4.21 sec. Users per second: 2013
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'topK': 127, 'shrink': 923, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0283690, PRECISION_RECALL_MIN_DEN: 0.0808413, RECALL: 0.0786081, MAP: 0.0117324, MAP_MIN_DEN: 0.0352941, MRR: 0.0999066, NDCG: 0.0618988, F1: 0.0416917, HIT_RATE: 0.2385733, ARHR_ALL_HITS: 0.1082875, NOVELTY: 0.0048514, AVERAGE_POPULARITY: 0.2963721, DIVERSITY_MEAN_INTER_LIST: 0.9469693, DIVERSITY_HERFINDAHL: 0.9946857, COVERAGE_ITEM: 0.3006030, COVERAGE_ITEM_HIT: 0.0285753, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1598354, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0488506, SHANNON_ENTROPY: 9.6059611, RATIO_DIVERSITY_HERFINDAHL: 0.9950458, RATIO_DIVERSITY_GINI: 0.1408490, RATIO_SHANNON_ENTROPY: 0.7402492, RATIO_AVERAGE_POPULARITY: 2.4504797, RATIO_NOVELTY: 0.3046070,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 5.7934
# Function value obtained: -0.0117
# Current minimum: -0.0137
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 549, 'shrink': 408, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# Similarity column 12638 (100.0%), 8589.18 column/sec. Elapsed time 1.47 sec
# Similarity column 12638 (100.0%), 9104.29 column/sec. Elapsed time 1.39 sec
# Similarity column 12638 (100.0%), 8901.88 column/sec. Elapsed time 1.42 sec
# EvaluatorHoldout: Processed 8467 (100.0%) in 4.88 sec. Users per second: 1736
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'topK': 266, 'shrink': 777, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 1.5598185035192103, 'tversky_beta': 1.6373156113388752} - results: PRECISION: 0.0292666, PRECISION_RECALL_MIN_DEN: 0.0890731, RECALL: 0.0869809, MAP: 0.0121739, MAP_MIN_DEN: 0.0394650, MRR: 0.1042538, NDCG: 0.0672112, F1: 0.0437968, HIT_RATE: 0.2474312, ARHR_ALL_HITS: 0.1126969, NOVELTY: 0.0046299, AVERAGE_POPULARITY: 0.3588664, DIVERSITY_MEAN_INTER_LIST: 0.9129849, DIVERSITY_HERFINDAHL: 0.9912877, COVERAGE_ITEM: 0.2099271, COVERAGE_ITEM_HIT: 0.0242102, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1657699, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0265645, SHANNON_ENTROPY: 8.7299404, RATIO_DIVERSITY_HERFINDAHL: 0.9916465, RATIO_DIVERSITY_GINI: 0.0765923, RATIO_SHANNON_ENTROPY: 0.6727418, RATIO_AVERAGE_POPULARITY: 2.9671986, RATIO_NOVELTY: 0.2907004,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 6.4907
# Function value obtained: -0.0122
# Current minimum: -0.0126
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 800, 'shrink': 903, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.6595825119014255, 'tversky_beta': 1.2448187068887964}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# Similarity column 12638 (100.0%), 8607.43 column/sec. Elapsed time 1.47 sec
# EvaluatorHoldout: Processed 8467 (100.0%) in 5.53 sec. Users per second: 1530
# SearchBayesianSkopt: New best config found. Config 2: {'topK': 428, 'shrink': 267, 'similarity': 'jaccard', 'normalize': False} - results: PRECISION: 0.0307901, PRECISION_RECALL_MIN_DEN: 0.0991401, RECALL: 0.0971158, MAP: 0.0125274, MAP_MIN_DEN: 0.0423684, MRR: 0.1060700, NDCG: 0.0718560, F1: 0.0467564, HIT_RATE: 0.2592418, ARHR_ALL_HITS: 0.1152742, NOVELTY: 0.0044639, AVERAGE_POPULARITY: 0.4187581, DIVERSITY_MEAN_INTER_LIST: 0.8664464, DIVERSITY_HERFINDAHL: 0.9866344, COVERAGE_ITEM: 0.1521915, COVERAGE_ITEM_HIT: 0.0216002, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1736825, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0155812, SHANNON_ENTROPY: 7.9671976, RATIO_DIVERSITY_HERFINDAHL: 0.9869915, RATIO_DIVERSITY_GINI: 0.0449246, RATIO_SHANNON_ENTROPY: 0.6139637, RATIO_AVERAGE_POPULARITY: 3.4623984, RATIO_NOVELTY: 0.2802787,
#
# EvaluatorHoldout: Processed 8467 (100.0%) in 5.14 sec. Users per second: 1648
# SearchBayesianSkopt: New best config found. Config 2: {'topK': 320, 'shrink': 822, 'similarity': 'dice', 'normalize': True} - results: PRECISION: 0.0299043, PRECISION_RECALL_MIN_DEN: 0.0942894, RECALL: 0.0922663, MAP: 0.0124257, MAP_MIN_DEN: 0.0415278, MRR: 0.1063774, NDCG: 0.0700646, F1: 0.0451690, HIT_RATE: 0.2536908, ARHR_ALL_HITS: 0.1150341, NOVELTY: 0.0045775, AVERAGE_POPULARITY: 0.3761428, DIVERSITY_MEAN_INTER_LIST: 0.9012370, DIVERSITY_HERFINDAHL: 0.9901131, COVERAGE_ITEM: 0.1902619, COVERAGE_ITEM_HIT: 0.0235802, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1699636, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0225357, SHANNON_ENTROPY: 8.4976819, RATIO_DIVERSITY_HERFINDAHL: 0.9904714, RATIO_DIVERSITY_GINI: 0.0649762, RATIO_SHANNON_ENTROPY: 0.6548436, RATIO_AVERAGE_POPULARITY: 3.1100438, RATIO_NOVELTY: 0.2874099,
#
# EvaluatorHoldout: Processed 8467 (100.0%) in 5.50 sec. Users per second: 1539
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'topK': 634, 'shrink': 846, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 1.9824825763044123, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0275304, PRECISION_RECALL_MIN_DEN: 0.0835723, RECALL: 0.0816724, MAP: 0.0111596, MAP_MIN_DEN: 0.0354319, MRR: 0.0953974, NDCG: 0.0617414, F1: 0.0411798, HIT_RATE: 0.2332585, ARHR_ALL_HITS: 0.1032343, NOVELTY: 0.0045048, AVERAGE_POPULARITY: 0.4269735, DIVERSITY_MEAN_INTER_LIST: 0.8511463, DIVERSITY_HERFINDAHL: 0.9851046, COVERAGE_ITEM: 0.1762668, COVERAGE_ITEM_HIT: 0.0153452, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1562747, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0184833, SHANNON_ENTROPY: 7.9045300, RATIO_DIVERSITY_HERFINDAHL: 0.9854611, RATIO_DIVERSITY_GINI: 0.0532922, RATIO_SHANNON_ENTROPY: 0.6091345, RATIO_AVERAGE_POPULARITY: 3.5303251, RATIO_NOVELTY: 0.2828460,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 7.2615
# Function value obtained: -0.0112
# Current minimum: -0.0127
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 607, 'shrink': 706, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.9399918652376726, 'feature_weighting': 'BM25'}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# EvaluatorHoldout: Processed 8467 (100.0%) in 5.97 sec. Users per second: 1419
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 549, 'shrink': 408, 'similarity': 'cosine', 'normalize': True, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0319594, PRECISION_RECALL_MIN_DEN: 0.1032706, RECALL: 0.1010090, MAP: 0.0135016, MAP_MIN_DEN: 0.0455417, MRR: 0.1140456, NDCG: 0.0760690, F1: 0.0485557, HIT_RATE: 0.2671548, ARHR_ALL_HITS: 0.1241257, NOVELTY: 0.0043280, AVERAGE_POPULARITY: 0.4708367, DIVERSITY_MEAN_INTER_LIST: 0.8146851, DIVERSITY_HERFINDAHL: 0.9814589, COVERAGE_ITEM: 0.0931959, COVERAGE_ITEM_HIT: 0.0200252, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1789840, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0083142, SHANNON_ENTROPY: 7.2677507, RATIO_DIVERSITY_HERFINDAHL: 0.9818141, RATIO_DIVERSITY_GINI: 0.0239719, RATIO_SHANNON_ENTROPY: 0.5600634, RATIO_AVERAGE_POPULARITY: 3.8929968, RATIO_NOVELTY: 0.2717460,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 7.6799
# Function value obtained: -0.0135
# Current minimum: -0.0137
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 758, 'shrink': 717, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'BM25'}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# Similarity column 12638 (100.0%), 9082.73 column/sec. Elapsed time 1.39 sec
# Similarity column 12638 (100.0%), 8953.29 column/sec. Elapsed time 1.41 sec
# EvaluatorHoldout: Processed 8467 (100.0%) in 6.42 sec. Users per second: 1318
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 800, 'shrink': 903, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.6595825119014255, 'tversky_beta': 1.2448187068887964} - results: PRECISION: 0.0301169, PRECISION_RECALL_MIN_DEN: 0.1010164, RECALL: 0.0991145, MAP: 0.0122999, MAP_MIN_DEN: 0.0436154, MRR: 0.1052467, NDCG: 0.0727271, F1: 0.0461966, HIT_RATE: 0.2568797, ARHR_ALL_HITS: 0.1137887, NOVELTY: 0.0043020, AVERAGE_POPULARITY: 0.4895198, DIVERSITY_MEAN_INTER_LIST: 0.7896288, DIVERSITY_HERFINDAHL: 0.9789535, COVERAGE_ITEM: 0.1072361, COVERAGE_ITEM_HIT: 0.0175502, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1721000, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0086806, SHANNON_ENTROPY: 7.1303046, RATIO_DIVERSITY_HERFINDAHL: 0.9793079, RATIO_DIVERSITY_GINI: 0.0250283, RATIO_SHANNON_ENTROPY: 0.5494716, RATIO_AVERAGE_POPULARITY: 4.0474737, RATIO_NOVELTY: 0.2701107,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 8.2278
# Function value obtained: -0.0123
# Current minimum: -0.0126
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 75, 'shrink': 183, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.7352650489395273, 'tversky_beta': 0.6906072422598092}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# EvaluatorHoldout: Processed 10489 (100.0%) in 6.66 sec. Users per second: 1575
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 428, 'shrink': 267, 'similarity': 'jaccard', 'normalize': False} - results:
# CUTOFF: 10 - PRECISION: 0.0607017, PRECISION_RECALL_MIN_DEN: 0.1095460, RECALL: 0.0944707, MAP: 0.0283858, MAP_MIN_DEN: 0.0517176, MRR: 0.1923208, NDCG: 0.0987599, F1: 0.0739117, HIT_RATE: 0.4059491, ARHR_ALL_HITS: 0.2325947, NOVELTY: 0.0045493, AVERAGE_POPULARITY: 0.3939874, DIVERSITY_MEAN_INTER_LIST: 0.8856330, DIVERSITY_HERFINDAHL: 0.9885549, COVERAGE_ITEM: 0.1925569, COVERAGE_ITEM_HIT: 0.0326253, ITEMS_IN_GT: 0.8001980, COVERAGE_USER: 0.8299573, COVERAGE_USER_HIT: 0.3369204, USERS_IN_GT: 0.8299573, DIVERSITY_GINI: 0.0194213, SHANNON_ENTROPY: 8.2376599, RATIO_DIVERSITY_HERFINDAHL: 0.9889127, RATIO_DIVERSITY_GINI: 0.0559967, RATIO_SHANNON_ENTROPY: 0.6348060, RATIO_AVERAGE_POPULARITY: 3.2575877, RATIO_NOVELTY: 0.2856440,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/UserKNNCFRecommender_jaccard
#
# UserKNNCFRecommender: Saving model in file 'result_experiments/UserKNNCFRecommender_jaccard_best_model'
# EvaluatorHoldout: Processed 10489 (100.0%) in 6.31 sec. Users per second: 1663
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 320, 'shrink': 822, 'similarity': 'dice', 'normalize': True} - results:
# CUTOFF: 10 - PRECISION: 0.0600439, PRECISION_RECALL_MIN_DEN: 0.1054852, RECALL: 0.0901264, MAP: 0.0282654, MAP_MIN_DEN: 0.0500923, MRR: 0.1900377, NDCG: 0.0962579, F1: 0.0720720, HIT_RATE: 0.3989894, ARHR_ALL_HITS: 0.2304146, NOVELTY: 0.0046658, AVERAGE_POPULARITY: 0.3517081, DIVERSITY_MEAN_INTER_LIST: 0.9165294, DIVERSITY_HERFINDAHL: 0.9916442, COVERAGE_ITEM: 0.2331023, COVERAGE_ITEM_HIT: 0.0375754, ITEMS_IN_GT: 0.8001980, COVERAGE_USER: 0.8299573, COVERAGE_USER_HIT: 0.3311442, USERS_IN_GT: 0.8299573, DIVERSITY_GINI: 0.0273671, SHANNON_ENTROPY: 8.7604767, RATIO_DIVERSITY_HERFINDAHL: 0.9920031, RATIO_DIVERSITY_GINI: 0.0789066, RATIO_SHANNON_ENTROPY: 0.6750950, RATIO_AVERAGE_POPULARITY: 2.9080115, RATIO_NOVELTY: 0.2929544,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/UserKNNCFRecommender_dice
#
# UserKNNCFRecommender: Saving model in file 'result_experiments/UserKNNCFRecommender_dice_best_model'
# Similarity column 12638 (100.0%), 9103.70 column/sec. Elapsed time 1.39 sec
# EvaluatorHoldout: Processed 8467 (100.0%) in 6.15 sec. Users per second: 1376
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 607, 'shrink': 706, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.9399918652376726, 'feature_weighting': 'BM25'} - results: PRECISION: 0.0202315, PRECISION_RECALL_MIN_DEN: 0.0504196, RECALL: 0.0480799, MAP: 0.0085100, MAP_MIN_DEN: 0.0211541, MRR: 0.0687433, NDCG: 0.0394412, F1: 0.0284792, HIT_RATE: 0.1634581, ARHR_ALL_HITS: 0.0763441, NOVELTY: 0.0066792, AVERAGE_POPULARITY: 0.0146215, DIVERSITY_MEAN_INTER_LIST: 0.9986038, DIVERSITY_HERFINDAHL: 0.9998486, COVERAGE_ITEM: 0.7317973, COVERAGE_ITEM_HIT: 0.0571506, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1095110, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.3787863, SHANNON_ENTROPY: 13.3706104, RATIO_DIVERSITY_HERFINDAHL: 1.0002105, RATIO_DIVERSITY_GINI: 1.0921389, RATIO_SHANNON_ENTROPY: 1.0303585, RATIO_AVERAGE_POPULARITY: 0.1208943, RATIO_NOVELTY: 0.4193716,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 7.8384
# Function value obtained: -0.0085
# Current minimum: -0.0127
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 547, 'shrink': 614, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 1.8427902472336755, 'feature_weighting': 'none'}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# UserKNNCFRecommender: Saving complete
# UserKNNCFRecommender: Saving completeIteration No: 3 ended. Evaluation done at random point.
#
# Time taken: 15.2740
# Function value obtained: -0.0124
# Current minimum: -0.0124
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 165, 'shrink': 177, 'similarity': 'dice', 'normalize': True}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 16.7112
# Function value obtained: -0.0125
# Current minimum: -0.0125
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 410, 'shrink': 638, 'similarity': 'jaccard', 'normalize': True}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# Similarity column 12638 (100.0%), 8773.41 column/sec. Elapsed time 1.44 sec
# Similarity column 12638 (100.0%), 9322.06 column/sec. Elapsed time 1.36 sec
# EvaluatorHoldout: Processed 8467 (100.0%) in 6.69 sec. Users per second: 1266
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': 758, 'shrink': 717, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'BM25'} - results: PRECISION: 0.0198181, PRECISION_RECALL_MIN_DEN: 0.0496618, RECALL: 0.0473981, MAP: 0.0083539, MAP_MIN_DEN: 0.0215041, MRR: 0.0685676, NDCG: 0.0393678, F1: 0.0279498, HIT_RATE: 0.1620409, ARHR_ALL_HITS: 0.0755222, NOVELTY: 0.0066807, AVERAGE_POPULARITY: 0.0137613, DIVERSITY_MEAN_INTER_LIST: 0.9985793, DIVERSITY_HERFINDAHL: 0.9998461, COVERAGE_ITEM: 0.7989380, COVERAGE_ITEM_HIT: 0.0577356, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1085615, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.3992516, SHANNON_ENTROPY: 13.4307533, RATIO_DIVERSITY_HERFINDAHL: 1.0002080, RATIO_DIVERSITY_GINI: 1.1511457, RATIO_SHANNON_ENTROPY: 1.0349932, RATIO_AVERAGE_POPULARITY: 0.1137822, RATIO_NOVELTY: 0.4194685,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 8.5355
# Function value obtained: -0.0084
# Current minimum: -0.0137
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 749, 'shrink': 895, 'similarity': 'cosine', 'normalize': False, 'feature_weighting': 'TF-IDF'}
# Similarity column 12638 (100.0%), 8783.28 column/sec. Elapsed time 1.44 sec
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# EvaluatorHoldout: Processed 8467 (100.0%) in 3.95 sec. Users per second: 2142
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': 75, 'shrink': 183, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.7352650489395273, 'tversky_beta': 0.6906072422598092} - results: PRECISION: 0.0253218, PRECISION_RECALL_MIN_DEN: 0.0673826, RECALL: 0.0651761, MAP: 0.0103992, MAP_MIN_DEN: 0.0293660, MRR: 0.0869812, NDCG: 0.0524891, F1: 0.0364733, HIT_RATE: 0.2099917, ARHR_ALL_HITS: 0.0951730, NOVELTY: 0.0050747, AVERAGE_POPULARITY: 0.2445662, DIVERSITY_MEAN_INTER_LIST: 0.9672449, DIVERSITY_HERFINDAHL: 0.9967131, COVERAGE_ITEM: 0.3995590, COVERAGE_ITEM_HIT: 0.0304653, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1406868, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0819146, SHANNON_ENTROPY: 10.3928941, RATIO_DIVERSITY_HERFINDAHL: 0.9970738, RATIO_DIVERSITY_GINI: 0.2361810, RATIO_SHANNON_ENTROPY: 0.8008914, RATIO_AVERAGE_POPULARITY: 2.0221354, RATIO_NOVELTY: 0.3186283,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 5.5378
# Function value obtained: -0.0104
# Current minimum: -0.0126
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 597, 'shrink': 771, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.5961877536282886, 'tversky_beta': 1.9150765383969302}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# Similarity column 12638 (100.0%), 8971.08 column/sec. Elapsed time 1.41 sec
# Similarity column 12638 (100.0%), 8624.42 column/sec. Elapsed time 1.47 sec
# EvaluatorHoldout: Processed 8467 (100.0%) in 4.73 sec. Users per second: 1792
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 165, 'shrink': 177, 'similarity': 'dice', 'normalize': True} - results: PRECISION: 0.0282390, PRECISION_RECALL_MIN_DEN: 0.0818482, RECALL: 0.0797001, MAP: 0.0118424, MAP_MIN_DEN: 0.0371436, MRR: 0.1013632, NDCG: 0.0634879, F1: 0.0417023, HIT_RATE: 0.2383371, ARHR_ALL_HITS: 0.1095982, NOVELTY: 0.0047394, AVERAGE_POPULARITY: 0.3264984, DIVERSITY_MEAN_INTER_LIST: 0.9320649, DIVERSITY_HERFINDAHL: 0.9931955, COVERAGE_ITEM: 0.2572226, COVERAGE_ITEM_HIT: 0.0262353, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1596772, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0370095, SHANNON_ENTROPY: 9.1858114, RATIO_DIVERSITY_HERFINDAHL: 0.9935550, RATIO_DIVERSITY_GINI: 0.1067081, RATIO_SHANNON_ENTROPY: 0.7078719, RATIO_AVERAGE_POPULARITY: 2.6995713, RATIO_NOVELTY: 0.2975780,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 6.2711
# Function value obtained: -0.0118
# Current minimum: -0.0124
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 57, 'shrink': 795, 'similarity': 'dice', 'normalize': True}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# EvaluatorHoldout: Processed 8467 (100.0%) in 5.37 sec. Users per second: 1577
# ...
# SearchBayesianSkopt: Best config evaluated with evaluator_test with constructor data for final test. Config: {'topK': 807, 'shrink': 0, 'similarity': 'tversky', 'normalize': True, 'tversky_alpha': 0.0, 'tversky_beta': 0.6840758892980197} - results:
# CUTOFF: 10 - PRECISION: 0.0639718, PRECISION_RECALL_MIN_DEN: 0.1158649, RECALL: 0.1004382, MAP: 0.0313446, MAP_MIN_DEN: 0.0551877, MRR: 0.2036320, NDCG: 0.1045408, F1: 0.0781608, HIT_RATE: 0.4129088, ARHR_ALL_HITS: 0.2505365, NOVELTY: 0.0045074, AVERAGE_POPULARITY: 0.4139447, DIVERSITY_MEAN_INTER_LIST: 0.8596843, DIVERSITY_HERFINDAHL: 0.9859602, COVERAGE_ITEM: 0.1565566, COVERAGE_ITEM_HIT: 0.0517505, ITEMS_IN_GT: 0.8001980, COVERAGE_USER: 0.8299573, COVERAGE_USER_HIT: 0.3426966, USERS_IN_GT: 0.8299573, DIVERSITY_GINI: 0.0159522, SHANNON_ENTROPY: 7.9878694, RATIO_DIVERSITY_HERFINDAHL: 0.9863168, RATIO_DIVERSITY_GINI: 0.0457209, RATIO_SHANNON_ENTROPY: 0.6152953, RATIO_AVERAGE_POPULARITY: 3.3943638, RATIO_NOVELTY: 0.2545987,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/UserKNNCFRecommender_tversky
#
# UserKNNCFRecommender: Saving model in file 'result_experiments/UserKNNCFRecommender_tversky_best_model_last'
# UserKNNCFRecommender: Saving complete
# EvaluatorHoldout: Processed 8467 (100.0%) in 5.43 sec. Users per second: 1559
# SearchBayesianSkopt: Config 48 is suboptimal. Config: {'topK': 523, 'shrink': 528, 'similarity': 'dice', 'normalize': False} - results: PRECISION: 0.0305421, PRECISION_RECALL_MIN_DEN: 0.0996555, RECALL: 0.0977117, MAP: 0.0125380, MAP_MIN_DEN: 0.0429284, MRR: 0.1065627, NDCG: 0.0723183, F1: 0.0465377, HIT_RATE: 0.2581788, ARHR_ALL_HITS: 0.1155819, NOVELTY: 0.0044201, AVERAGE_POPULARITY: 0.4361480, DIVERSITY_MEAN_INTER_LIST: 0.8501759, DIVERSITY_HERFINDAHL: 0.9850075, COVERAGE_ITEM: 0.1364414, COVERAGE_ITEM_HIT: 0.0204302, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1729704, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0132079, SHANNON_ENTROPY: 7.7470588, RATIO_DIVERSITY_HERFINDAHL: 0.9853641, RATIO_DIVERSITY_GINI: 0.0380818, RATIO_SHANNON_ENTROPY: 0.5969995, RATIO_AVERAGE_POPULARITY: 3.6061824, RATIO_NOVELTY: 0.2775310,
#
# EvaluatorHoldout: Processed 8467 (100.0%) in 4.75 sec. Users per second: 1782
# SearchBayesianSkopt: Config 47 is suboptimal. Config: {'topK': 415, 'shrink': 987, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 1.975033460220357, 'feature_weighting': 'none'} - results: PRECISION: 0.0264084, PRECISION_RECALL_MIN_DEN: 0.0747862, RECALL: 0.0728678, MAP: 0.0108100, MAP_MIN_DEN: 0.0326337, MRR: 0.0926410, NDCG: 0.0573990, F1: 0.0387671, HIT_RATE: 0.2240463, ARHR_ALL_HITS: 0.1001025, NOVELTY: 0.0048956, AVERAGE_POPULARITY: 0.3127192, DIVERSITY_MEAN_INTER_LIST: 0.9318142, DIVERSITY_HERFINDAHL: 0.9931704, COVERAGE_ITEM: 0.3387184, COVERAGE_ITEM_HIT: 0.0218252, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1501029, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0556596, SHANNON_ENTROPY: 9.4891437, RATIO_DIVERSITY_HERFINDAHL: 0.9935299, RATIO_DIVERSITY_GINI: 0.1604812, RATIO_SHANNON_ENTROPY: 0.7312471, RATIO_AVERAGE_POPULARITY: 2.5856419, RATIO_NOVELTY: 0.3073868,
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 8.8202
# Function value obtained: -0.0125
# Current minimum: -0.0131
# Iteration No: 50 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 357, 'shrink': 142, 'similarity': 'dice', 'normalize': False}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 8.0690
# Function value obtained: -0.0108
# Current minimum: -0.0136
# Iteration No: 49 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 435, 'shrink': 562, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.0, 'feature_weighting': 'TF-IDF'}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# UserKNNCFRecommender: Saving complete
# Similarity column 12638 (100.0%), 9052.30 column/sec. Elapsed time 1.40 sec
# EvaluatorHoldout: Processed 8467 (100.0%) in 6.65 sec. Users per second: 1273
# SearchBayesianSkopt: Config 49 is suboptimal. Config: {'topK': 697, 'shrink': 0, 'similarity': 'jaccard', 'normalize': True} - results: PRECISION: 0.0305539, PRECISION_RECALL_MIN_DEN: 0.0984819, RECALL: 0.0963923, MAP: 0.0125499, MAP_MIN_DEN: 0.0424867, MRR: 0.1062028, NDCG: 0.0716903, F1: 0.0464002, HIT_RATE: 0.2571159, ARHR_ALL_HITS: 0.1154442, NOVELTY: 0.0042592, AVERAGE_POPULARITY: 0.5125227, DIVERSITY_MEAN_INTER_LIST: 0.7581927, DIVERSITY_HERFINDAHL: 0.9758103, COVERAGE_ITEM: 0.1032760, COVERAGE_ITEM_HIT: 0.0169652, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1722583, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0073745, SHANNON_ENTROPY: 6.8698144, RATIO_DIVERSITY_HERFINDAHL: 0.9761635, RATIO_DIVERSITY_GINI: 0.0212626, RATIO_SHANNON_ENTROPY: 0.5293978, RATIO_AVERAGE_POPULARITY: 4.2376676, RATIO_NOVELTY: 0.2674249,
#
# Similarity column 12638 (100.0%), 9270.64 column/sec. Elapsed time 1.36 sec
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 8.9251
# Function value obtained: -0.0125
# Current minimum: -0.0131
# SearchBayesianSkopt: Search complete. Best config is 44: {'topK': 279, 'shrink': 0, 'similarity': 'jaccard', 'normalize': False}
#
# UserKNNCFRecommender: URM Detected 235 ( 1.9%) users with no interactions.
# UserKNNCFRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# SearchBayesianSkopt: Evaluation with constructor data for final test. Using best config: {'topK': 279, 'shrink': 0, 'similarity': 'jaccard', 'normalize': False}
# Similarity column 12638 (100.0%), 8990.49 column/sec. Elapsed time 1.41 sec
# EvaluatorHoldout: Processed 8467 (100.0%) in 5.12 sec. Users per second: 1653
# SearchBayesianSkopt: Config 49 is suboptimal. Config: {'topK': 357, 'shrink': 142, 'similarity': 'dice', 'normalize': False} - results: PRECISION: 0.0302941, PRECISION_RECALL_MIN_DEN: 0.0960548, RECALL: 0.0940101, MAP: 0.0124588, MAP_MIN_DEN: 0.0416607, MRR: 0.1061353, NDCG: 0.0706572, F1: 0.0458223, HIT_RATE: 0.2560529, ARHR_ALL_HITS: 0.1150160, NOVELTY: 0.0044848, AVERAGE_POPULARITY: 0.4106572, DIVERSITY_MEAN_INTER_LIST: 0.8735814, DIVERSITY_HERFINDAHL: 0.9873478, COVERAGE_ITEM: 0.1587166, COVERAGE_ITEM_HIT: 0.0218252, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1715461, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0166864, SHANNON_ENTROPY: 8.0674549, RATIO_DIVERSITY_HERFINDAHL: 0.9877052, RATIO_DIVERSITY_GINI: 0.0481112, RATIO_SHANNON_ENTROPY: 0.6216897, RATIO_AVERAGE_POPULARITY: 3.3954177, RATIO_NOVELTY: 0.2815903,
#
# EvaluatorHoldout: Processed 8467 (100.0%) in 5.40 sec. Users per second: 1569
# SearchBayesianSkopt: New best config found. Config 48: {'topK': 435, 'shrink': 562, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.0, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0322783, PRECISION_RECALL_MIN_DEN: 0.1033634, RECALL: 0.1011582, MAP: 0.0137417, MAP_MIN_DEN: 0.0454662, MRR: 0.1159746, NDCG: 0.0764226, F1: 0.0489403, HIT_RATE: 0.2695169, ARHR_ALL_HITS: 0.1262313, NOVELTY: 0.0044822, AVERAGE_POPULARITY: 0.4104326, DIVERSITY_MEAN_INTER_LIST: 0.8718442, DIVERSITY_HERFINDAHL: 0.9871741, COVERAGE_ITEM: 0.1345513, COVERAGE_ITEM_HIT: 0.0301503, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1805665, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0147675, SHANNON_ENTROPY: 8.0099407, RATIO_DIVERSITY_HERFINDAHL: 0.9875314, RATIO_DIVERSITY_GINI: 0.0425785, RATIO_SHANNON_ENTROPY: 0.6172576, RATIO_AVERAGE_POPULARITY: 3.3935608, RATIO_NOVELTY: 0.2814254,
#
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 7.3235
# Function value obtained: -0.0125
# Current minimum: -0.0131
# SearchBayesianSkopt: Search complete. Best config is 19: {'topK': 287, 'shrink': 11, 'similarity': 'dice', 'normalize': False}
#
# UserKNNCFRecommender: URM Detected 235 ( 1.9%) users with no interactions.
# UserKNNCFRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# SearchBayesianSkopt: Evaluation with constructor data for final test. Using best config: {'topK': 287, 'shrink': 11, 'similarity': 'dice', 'normalize': False}
# Similarity column 12638 (100.0%), 9239.90 column/sec. Elapsed time 1.37 sec
# EvaluatorHoldout: Processed 10489 (100.0%) in 6.11 sec. Users per second: 1717
# SearchBayesianSkopt: Best config evaluated with evaluator_test with constructor data for final test. Config: {'topK': 279, 'shrink': 0, 'similarity': 'jaccard', 'normalize': False} - results:
# CUTOFF: 10 - PRECISION: 0.0674135, PRECISION_RECALL_MIN_DEN: 0.1213836, RECALL: 0.1036183, MAP: 0.0325644, MAP_MIN_DEN: 0.0582804, MRR: 0.2103758, NDCG: 0.1097116, F1: 0.0816839, HIT_RATE: 0.4297836, ARHR_ALL_HITS: 0.2599320, NOVELTY: 0.0045178, AVERAGE_POPULARITY: 0.4039221, DIVERSITY_MEAN_INTER_LIST: 0.8768002, DIVERSITY_HERFINDAHL: 0.9876717, COVERAGE_ITEM: 0.1783818, COVERAGE_ITEM_HIT: 0.0409054, ITEMS_IN_GT: 0.8001980, COVERAGE_USER: 0.8299573, COVERAGE_USER_HIT: 0.3567020, USERS_IN_GT: 0.8299573, DIVERSITY_GINI: 0.0174498, SHANNON_ENTROPY: 8.1091688, RATIO_DIVERSITY_HERFINDAHL: 0.9880289, RATIO_DIVERSITY_GINI: 0.0500133, RATIO_SHANNON_ENTROPY: 0.6246388, RATIO_AVERAGE_POPULARITY: 3.3121782, RATIO_NOVELTY: 0.2551902,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/UserKNNCFRecommender_jaccard
#
# UserKNNCFRecommender: Saving model in file 'result_experiments/UserKNNCFRecommender_jaccard_best_model_last'
# UserKNNCFRecommender: Saving complete
# EvaluatorHoldout: Processed 10489 (100.0%) in 6.45 sec. Users per second: 1625
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 435, 'shrink': 562, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.0, 'feature_weighting': 'TF-IDF'} - results:
# CUTOFF: 10 - PRECISION: 0.0635904, PRECISION_RECALL_MIN_DEN: 0.1176484, RECALL: 0.1017824, MAP: 0.0300781, MAP_MIN_DEN: 0.0548598, MRR: 0.1971505, NDCG: 0.1039196, F1: 0.0782763, HIT_RATE: 0.4160549, ARHR_ALL_HITS: 0.2418087, NOVELTY: 0.0044855, AVERAGE_POPULARITY: 0.4185934, DIVERSITY_MEAN_INTER_LIST: 0.8617986, DIVERSITY_HERFINDAHL: 0.9861716, COVERAGE_ITEM: 0.1503465, COVERAGE_ITEM_HIT: 0.0446404, ITEMS_IN_GT: 0.8001980, COVERAGE_USER: 0.8299573, COVERAGE_USER_HIT: 0.3453078, USERS_IN_GT: 0.8299573, DIVERSITY_GINI: 0.0146302, SHANNON_ENTROPY: 7.9251453, RATIO_DIVERSITY_HERFINDAHL: 0.9865286, RATIO_DIVERSITY_GINI: 0.0421826, RATIO_SHANNON_ENTROPY: 0.6107231, RATIO_AVERAGE_POPULARITY: 3.4610360, RATIO_NOVELTY: 0.2816323,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/UserKNNCFRecommender_asymmetric
#
# UserKNNCFRecommender: Saving model in file 'result_experiments/UserKNNCFRecommender_asymmetric_best_model'
# EvaluatorHoldout: Processed 10489 (100.0%) in 5.83 sec. Users per second: 1800
# SearchBayesianSkopt: Best config evaluated with evaluator_test with constructor data for final test. Config: {'topK': 287, 'shrink': 11, 'similarity': 'dice', 'normalize': False} - results:
# CUTOFF: 10 - PRECISION: 0.0670417, PRECISION_RECALL_MIN_DEN: 0.1210765, RECALL: 0.1035343, MAP: 0.0325158, MAP_MIN_DEN: 0.0587099, MRR: 0.2122377, NDCG: 0.1100263, F1: 0.0813844, HIT_RATE: 0.4308323, ARHR_ALL_HITS: 0.2608216, NOVELTY: 0.0045062, AVERAGE_POPULARITY: 0.4057823, DIVERSITY_MEAN_INTER_LIST: 0.8755673, DIVERSITY_HERFINDAHL: 0.9875484, COVERAGE_ITEM: 0.1651067, COVERAGE_ITEM_HIT: 0.0393754, ITEMS_IN_GT: 0.8001980, COVERAGE_USER: 0.8299573, COVERAGE_USER_HIT: 0.3575724, USERS_IN_GT: 0.8299573, DIVERSITY_GINI: 0.0161654, SHANNON_ENTROPY: 8.0626929, RATIO_DIVERSITY_HERFINDAHL: 0.9879056, RATIO_DIVERSITY_GINI: 0.0463320, RATIO_SHANNON_ENTROPY: 0.6210588, RATIO_AVERAGE_POPULARITY: 3.3274321, RATIO_NOVELTY: 0.2545345,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/UserKNNCFRecommender_dice
#
# UserKNNCFRecommender: Saving model in file 'result_experiments/UserKNNCFRecommender_dice_best_model_last'
# UserKNNCFRecommender: Saving complete
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 16.6491
# Function value obtained: -0.0137
# Current minimum: -0.0137
# Iteration No: 50 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 991, 'shrink': 952, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 1.4322040177605517, 'feature_weighting': 'TF-IDF'}
# UserKNNCFRecommender: URM Detected 356 ( 2.8%) users with no interactions.
# UserKNNCFRecommender: URM Detected 194 ( 0.9%) items with no interactions.
# UserKNNCFRecommender: Saving complete
# Similarity column 12638 (100.0%), 9993.23 column/sec. Elapsed time 1.26 sec
# EvaluatorHoldout: Processed 8467 (100.0%) in 5.58 sec. Users per second: 1517
# SearchBayesianSkopt: Config 49 is suboptimal. Config: {'topK': 991, 'shrink': 952, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 1.4322040177605517, 'feature_weighting': 'TF-IDF'} - results: PRECISION: 0.0282036, PRECISION_RECALL_MIN_DEN: 0.0908645, RECALL: 0.0889482, MAP: 0.0115652, MAP_MIN_DEN: 0.0395024, MRR: 0.0988700, NDCG: 0.0665048, F1: 0.0428275, HIT_RATE: 0.2394000, ARHR_ALL_HITS: 0.1069679, NOVELTY: 0.0042922, AVERAGE_POPULARITY: 0.5109226, DIVERSITY_MEAN_INTER_LIST: 0.7542945, DIVERSITY_HERFINDAHL: 0.9754205, COVERAGE_ITEM: 0.1372514, COVERAGE_ITEM_HIT: 0.0130951, ITEMS_IN_GT: 0.5509405, COVERAGE_USER: 0.6699636, COVERAGE_USER_HIT: 0.1603893, USERS_IN_GT: 0.6699636, DIVERSITY_GINI: 0.0100744, SHANNON_ENTROPY: 6.9516004, RATIO_DIVERSITY_HERFINDAHL: 0.9757736, RATIO_DIVERSITY_GINI: 0.0290470, RATIO_SHANNON_ENTROPY: 0.5357004, RATIO_AVERAGE_POPULARITY: 4.2244372, RATIO_NOVELTY: 0.2694976,
#
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 7.7159
# Function value obtained: -0.0116
# Current minimum: -0.0137
# SearchBayesianSkopt: Search complete. Best config is 48: {'topK': 435, 'shrink': 562, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.0, 'feature_weighting': 'TF-IDF'}
#
# UserKNNCFRecommender: URM Detected 235 ( 1.9%) users with no interactions.
# UserKNNCFRecommender: URM Detected 118 ( 0.5%) items with no interactions.
# SearchBayesianSkopt: Evaluation with constructor data for final test. Using best config: {'topK': 435, 'shrink': 562, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.0, 'feature_weighting': 'TF-IDF'}
# Similarity column 12638 (100.0%), 9934.44 column/sec. Elapsed time 1.27 sec
# EvaluatorHoldout: Processed 10489 (100.0%) in 5.91 sec. Users per second: 1774
# SearchBayesianSkopt: Best config evaluated with evaluator_test with constructor data for final test. Config: {'topK': 435, 'shrink': 562, 'similarity': 'asymmetric', 'normalize': True, 'asymmetric_alpha': 0.0, 'feature_weighting': 'TF-IDF'} - results:
# CUTOFF: 10 - PRECISION: 0.0685099, PRECISION_RECALL_MIN_DEN: 0.1252938, RECALL: 0.1074553, MAP: 0.0338954, MAP_MIN_DEN: 0.0609752, MRR: 0.2157088, NDCG: 0.1131868, F1: 0.0836728, HIT_RATE: 0.4341691, ARHR_ALL_HITS: 0.2681419, NOVELTY: 0.0044900, AVERAGE_POPULARITY: 0.4158718, DIVERSITY_MEAN_INTER_LIST: 0.8625570, DIVERSITY_HERFINDAHL: 0.9862475, COVERAGE_ITEM: 0.1512915, COVERAGE_ITEM_HIT: 0.0508055, ITEMS_IN_GT: 0.8001980, COVERAGE_USER: 0.8299573, COVERAGE_USER_HIT: 0.3603418, USERS_IN_GT: 0.8299573, DIVERSITY_GINI: 0.0151511, SHANNON_ENTROPY: 7.9651674, RATIO_DIVERSITY_HERFINDAHL: 0.9866042, RATIO_DIVERSITY_GINI: 0.0434249, RATIO_SHANNON_ENTROPY: 0.6135466, RATIO_AVERAGE_POPULARITY: 3.4101660, RATIO_NOVELTY: 0.2536203,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/UserKNNCFRecommender_asymmetric
#
# UserKNNCFRecommender: Saving model in file 'result_experiments/UserKNNCFRecommender_asymmetric_best_model_last'
# UserKNNCFRecommender: Saving complete

# %%
data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + '_tversky' + "_metadata.zip")

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters
# Out:
# {'topK': 807,
#  'shrink': 0,
#  'similarity': 'tversky',
#  'normalize': True,
#  'tversky_alpha': 0.0,
#  'tversky_beta': 0.6840758892980197}

# %%
search_metadata['result_on_test_best']
# Out:
#        PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
# cutoff
# 10      0.059567                 0.108155  0.093883  0.028362    0.050123
#
#              MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                        ...
# 10      0.188961  0.096609  0.072888  0.394985      0.229999  ...
#
#        COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
# cutoff
# 10          0.829957          0.327821    0.829957       0.013764
#
#        SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
# cutoff
# 10            7.808504                   0.985301             0.039685
#
#        RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
# cutoff
# 10                  0.601735                 3.531594      0.280911
#
# [1 rows x 27 columns]

# %%
recommender_object = recommender_class(data_train + data_validation)
# Out:
# SLIMElasticNetRecommender: URM Detected 192 ( 1.5%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 127 ( 0.6%) items with no interactions.

# %%
recommender_object.load_model(output_folder_path, 
                              file_name = recommender_object.RECOMMENDER_NAME + "_best_model_last.zip" )
# Out:
# SLIMElasticNetRecommender: Loading model from file 'result_experiments/SLIMElasticNetRecommender_best_model_last.zip'
# SLIMElasticNetRecommender: Loading complete

# %%
def prepare_submission(ratings: pd.DataFrame, users_to_recommend: np.array, urm_train: sp.csr_matrix, recommender: object):
    users_ids_and_mappings = ratings[ratings.user_id.isin(users_to_recommend)][["user_id", "mapped_user_id"]].drop_duplicates()

    mapping_to_item_id = dict(zip(ratings.mapped_item_id, ratings.item_id))
    item_ids = ratings.item_id.unique()


    recommendation_length = 10
    submission = dict()
    for idx, row in users_ids_and_mappings.iterrows():
        user_id = row.user_id
        mapped_user_id = row.mapped_user_id

        recommendations = recommender.recommend(mapped_user_id, cutoff = 10)

        submission[user_id] = [mapping_to_item_id[item_id] for item_id in recommendations]
    
    for user_id in users_to_recommend:
        if user_id not in submission:
            submission[user_id] = np.random.choice(item_ids, 10)

    return submission

# %%
from utils import write_submission

write_submission(prepare_submission(data, users, data_train + data_validation, recommender_object))
