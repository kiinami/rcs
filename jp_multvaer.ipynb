# %%
import os

from utils import *
from Recommenders.DataIO import DataIO
from Evaluation.Evaluator import EvaluatorHoldout

# %%
data = load_data()
users = load_users()
data, num_users, num_items, mapping_user_id = preprocess_data(data)
data_train, data_validation, data_test = split_data(
    data,
    num_users=num_users,
    num_items=num_items,
    validation_percentage=0.1,
    testing_percentage=0.20
)

# %%
evaluator_validation = EvaluatorHoldout(data_validation, cutoff_list=[10])
evaluator_test = EvaluatorHoldout(data_test, cutoff_list=[10])
# Out:
# EvaluatorHoldout: Ignoring 4205 (33.3%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 2146 (17.0%) Users that have less than 1 test interactions

# %%
output_folder_path = "result_experiments/"
n_cases = 50
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from HyperparameterTuning.run_hyperparameter_search import runHyperparameterSearch_Collaborative
from Recommenders.Neural.MultVAERecommender import MultVAERecommender_OptimizerMask as MultVAERecommender

recommender_class = MultVAERecommender

runHyperparameterSearch_Collaborative(recommender_class,
       URM_train = data_train,
       URM_train_last_test = data_train + data_validation,
       metric_to_optimize = metric_to_optimize,
       cutoff_to_optimize = cutoff_to_optimize,
       evaluator_validation_earlystopping = evaluator_validation,
       evaluator_validation = evaluator_validation,
       evaluator_test = evaluator_test,
       output_folder_path = output_folder_path,
       parallelizeKNN = True,
       allow_weighting = True,
       resume_from_saved = True,
       save_model = "best",
       similarity_type_list = ['cosine', 'jaccard', "asymmetric", "dice", "tversky"],
       n_cases = n_cases,
       n_random_starts = n_random_starts)
# Out:
# 2023-12-14 10:39:33.409276: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-14 10:39:33.993270: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# SearchBayesianSkopt: Resuming 'MultVAERecommender'... Loaded 4 configurations.
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.0001
# Function value obtained: -0.0086
# Current minimum: -0.0086
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'epochs': 500, 'learning_rate': 2.0044786980713274e-06, 'l2_reg': 0.00222587404144642, 'dropout': 0.7771076453924075, 'total_anneal_steps': 425957, 'anneal_cap': 0.3260698189399362, 'batch_size': 512, 'encoding_size': 189, 'next_layer_size_multiplier': 2, 'max_n_hidden_layers': 2, 'max_parameters': 1750000000.0}
# MultVAERecommender: URM Detected 340 ( 2.7%) users with no interactions.
# MultVAERecommender: URM Detected 179 ( 0.8%) items with no interactions.
# MultVAERecommender: Architecture: [189, 378, 22222]
# MultVAERecommender: Using default Temp folder './result_experiments/__Temp_MultVAERecommender_6911/'
# 2023-12-14 10:39:34.730478: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-14 10:39:34.746115: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-14 10:39:34.746563: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-14 10:39:34.760322: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-14 10:39:34.760794: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-14 10:39:34.761111: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-14 10:39:34.842418: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-14 10:39:34.842651: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-14 10:39:34.842849: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-14 10:39:34.843019: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2795 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2023-12-14 10:39:35.208387: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 1 of 500. Elapsed time 2.21 sec
# MultVAERecommender: Epoch 2 of 500. Elapsed time 4.27 sec
# MultVAERecommender: Epoch 3 of 500. Elapsed time 6.35 sec
# MultVAERecommender: Epoch 4 of 500. Elapsed time 8.45 sec
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 4.78 sec. Users per second: 1763
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0002727, PRECISION_RECALL_MIN_DEN: 0.0007508, RECALL: 0.0007237, MAP: 0.0000606, MAP_MIN_DEN: 0.0001359, MRR: 0.0006065, NDCG: 0.0003945, F1: 0.0003962, HIT_RATE: 0.0027274, ARHR_ALL_HITS: 0.0006065, NOVELTY: 0.0067338, AVERAGE_POPULARITY: 0.0198638, DIVERSITY_MEAN_INTER_LIST: 0.9941466, DIVERSITY_HERFINDAHL: 0.9994029, COVERAGE_ITEM: 0.3700387, COVERAGE_ITEM_HIT: 0.0009900, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0018199, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.1188517, SHANNON_ENTROPY: 11.6704516, RATIO_DIVERSITY_HERFINDAHL: 0.9997648, RATIO_DIVERSITY_GINI: 0.3431465, RATIO_SHANNON_ENTROPY: 0.8994447, RATIO_AVERAGE_POPULARITY: 0.1657056, RATIO_NOVELTY: 0.4228469,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 5 of 500. Elapsed time 15.73 sec
# MultVAERecommender: Epoch 6 of 500. Elapsed time 17.82 sec
# MultVAERecommender: Epoch 7 of 500. Elapsed time 19.92 sec
# MultVAERecommender: Epoch 8 of 500. Elapsed time 22.01 sec
# MultVAERecommender: Epoch 9 of 500. Elapsed time 24.10 sec
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 4.71 sec. Users per second: 1790
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0004980, PRECISION_RECALL_MIN_DEN: 0.0015899, RECALL: 0.0015527, MAP: 0.0001162, MAP_MIN_DEN: 0.0003426, MRR: 0.0011622, NDCG: 0.0008469, F1: 0.0007542, HIT_RATE: 0.0049804, ARHR_ALL_HITS: 0.0011622, NOVELTY: 0.0064320, AVERAGE_POPULARITY: 0.0348037, DIVERSITY_MEAN_INTER_LIST: 0.9907743, DIVERSITY_HERFINDAHL: 0.9990657, COVERAGE_ITEM: 0.3262533, COVERAGE_ITEM_HIT: 0.0016200, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0033233, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0935654, SHANNON_ENTROPY: 11.2469597, RATIO_DIVERSITY_HERFINDAHL: 0.9994275, RATIO_DIVERSITY_GINI: 0.2701402, RATIO_SHANNON_ENTROPY: 0.8668061, RATIO_AVERAGE_POPULARITY: 0.2903359, RATIO_NOVELTY: 0.4038992,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 10 of 500. Elapsed time 31.27 sec
# MultVAERecommender: Epoch 11 of 500. Elapsed time 33.37 sec
# MultVAERecommender: Epoch 12 of 500. Elapsed time 35.47 sec
# MultVAERecommender: Epoch 13 of 500. Elapsed time 37.56 sec
# MultVAERecommender: Epoch 14 of 500. Elapsed time 39.66 sec
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 4.76 sec. Users per second: 1772
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0009724, PRECISION_RECALL_MIN_DEN: 0.0027231, RECALL: 0.0026257, MAP: 0.0002251, MAP_MIN_DEN: 0.0006669, MRR: 0.0022111, NDCG: 0.0015838, F1: 0.0014192, HIT_RATE: 0.0096051, ARHR_ALL_HITS: 0.0022308, NOVELTY: 0.0060961, AVERAGE_POPULARITY: 0.0551172, DIVERSITY_MEAN_INTER_LIST: 0.9828748, DIVERSITY_HERFINDAHL: 0.9982758, COVERAGE_ITEM: 0.2668077, COVERAGE_ITEM_HIT: 0.0027900, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0064092, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0635192, SHANNON_ENTROPY: 10.5753596, RATIO_DIVERSITY_HERFINDAHL: 0.9986374, RATIO_DIVERSITY_GINI: 0.1833915, RATIO_SHANNON_ENTROPY: 0.8150457, RATIO_AVERAGE_POPULARITY: 0.4597932, RATIO_NOVELTY: 0.3828039,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 15 of 500. Elapsed time 46.91 sec
# MultVAERecommender: Epoch 16 of 500. Elapsed time 48.64 sec
# MultVAERecommender: Epoch 17 of 500. Elapsed time 50.36 sec
# MultVAERecommender: Epoch 18 of 500. Elapsed time 52.09 sec
# MultVAERecommender: Epoch 19 of 500. Elapsed time 53.81 sec
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 4.77 sec. Users per second: 1766
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0013755, PRECISION_RECALL_MIN_DEN: 0.0036041, RECALL: 0.0034560, MAP: 0.0003633, MAP_MIN_DEN: 0.0010441, MRR: 0.0035539, NDCG: 0.0023184, F1: 0.0019679, HIT_RATE: 0.0136369, ARHR_ALL_HITS: 0.0035934, NOVELTY: 0.0057876, AVERAGE_POPULARITY: 0.0788257, DIVERSITY_MEAN_INTER_LIST: 0.9684103, DIVERSITY_HERFINDAHL: 0.9968295, COVERAGE_ITEM: 0.1984070, COVERAGE_ITEM_HIT: 0.0034200, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0090995, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0388130, SHANNON_ENTROPY: 9.7800776, RATIO_DIVERSITY_HERFINDAHL: 0.9971906, RATIO_DIVERSITY_GINI: 0.1120602, RATIO_SHANNON_ENTROPY: 0.7537531, RATIO_AVERAGE_POPULARITY: 0.6575719, RATIO_NOVELTY: 0.3634336,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 20 of 500. Elapsed time 1.01 min
# MultVAERecommender: Epoch 21 of 500. Elapsed time 1.05 min
# MultVAERecommender: Epoch 22 of 500. Elapsed time 1.08 min
# MultVAERecommender: Epoch 23 of 500. Elapsed time 1.12 min
# MultVAERecommender: Epoch 24 of 500. Elapsed time 1.15 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 4.84 sec. Users per second: 1742
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0018262, PRECISION_RECALL_MIN_DEN: 0.0048826, RECALL: 0.0046847, MAP: 0.0005354, MAP_MIN_DEN: 0.0015478, MRR: 0.0052753, NDCG: 0.0032624, F1: 0.0026279, HIT_RATE: 0.0181430, ARHR_ALL_HITS: 0.0053149, NOVELTY: 0.0055447, AVERAGE_POPULARITY: 0.1022413, DIVERSITY_MEAN_INTER_LIST: 0.9475906, DIVERSITY_HERFINDAHL: 0.9947478, COVERAGE_ITEM: 0.1441364, COVERAGE_ITEM_HIT: 0.0036900, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0121063, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0233058, SHANNON_ENTROPY: 9.0159743, RATIO_DIVERSITY_HERFINDAHL: 0.9951081, RATIO_DIVERSITY_GINI: 0.0672881, RATIO_SHANNON_ENTROPY: 0.6948635, RATIO_AVERAGE_POPULARITY: 0.8529074, RATIO_NOVELTY: 0.3481804,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 25 of 500. Elapsed time 1.27 min
# MultVAERecommender: Epoch 26 of 500. Elapsed time 1.31 min
# MultVAERecommender: Epoch 27 of 500. Elapsed time 1.34 min
# MultVAERecommender: Epoch 28 of 500. Elapsed time 1.38 min
# MultVAERecommender: Epoch 29 of 500. Elapsed time 1.42 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 4.87 sec. Users per second: 1731
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0022768, PRECISION_RECALL_MIN_DEN: 0.0057466, RECALL: 0.0055010, MAP: 0.0006334, MAP_MIN_DEN: 0.0017302, MRR: 0.0061651, NDCG: 0.0038169, F1: 0.0032206, HIT_RATE: 0.0224120, ARHR_ALL_HITS: 0.0062494, NOVELTY: 0.0053634, AVERAGE_POPULARITY: 0.1249572, DIVERSITY_MEAN_INTER_LIST: 0.9199536, DIVERSITY_HERFINDAHL: 0.9919845, COVERAGE_ITEM: 0.0992260, COVERAGE_ITEM_HIT: 0.0038700, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0149549, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0142654, SHANNON_ENTROPY: 8.3229496, RATIO_DIVERSITY_HERFINDAHL: 0.9923437, RATIO_DIVERSITY_GINI: 0.0411867, RATIO_SHANNON_ENTROPY: 0.6414519, RATIO_AVERAGE_POPULARITY: 1.0424056, RATIO_NOVELTY: 0.3367969,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 30 of 500. Elapsed time 1.54 min
# MultVAERecommender: Epoch 31 of 500. Elapsed time 1.57 min
# MultVAERecommender: Epoch 32 of 500. Elapsed time 1.61 min
# MultVAERecommender: Epoch 33 of 500. Elapsed time 1.64 min
# MultVAERecommender: Epoch 34 of 500. Elapsed time 1.68 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 4.93 sec. Users per second: 1711
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0027392, PRECISION_RECALL_MIN_DEN: 0.0071317, RECALL: 0.0068528, MAP: 0.0008052, MAP_MIN_DEN: 0.0021550, MRR: 0.0078348, NDCG: 0.0047308, F1: 0.0039140, HIT_RATE: 0.0269181, ARHR_ALL_HITS: 0.0079435, NOVELTY: 0.0052241, AVERAGE_POPULARITY: 0.1468171, DIVERSITY_MEAN_INTER_LIST: 0.8861968, DIVERSITY_HERFINDAHL: 0.9886092, COVERAGE_ITEM: 0.0717757, COVERAGE_ITEM_HIT: 0.0037350, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0179617, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0092648, SHANNON_ENTROPY: 7.7155382, RATIO_DIVERSITY_HERFINDAHL: 0.9889672, RATIO_DIVERSITY_GINI: 0.0267492, RATIO_SHANNON_ENTROPY: 0.5946385, RATIO_AVERAGE_POPULARITY: 1.2247632, RATIO_NOVELTY: 0.3280504,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 35 of 500. Elapsed time 1.80 min
# MultVAERecommender: Epoch 36 of 500. Elapsed time 1.84 min
# MultVAERecommender: Epoch 37 of 500. Elapsed time 1.87 min
# MultVAERecommender: Epoch 38 of 500. Elapsed time 1.91 min
# MultVAERecommender: Epoch 39 of 500. Elapsed time 1.94 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.01 sec. Users per second: 1684
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0031543, PRECISION_RECALL_MIN_DEN: 0.0091082, RECALL: 0.0088266, MAP: 0.0009242, MAP_MIN_DEN: 0.0025442, MRR: 0.0090043, NDCG: 0.0056619, F1: 0.0046477, HIT_RATE: 0.0309498, ARHR_ALL_HITS: 0.0091232, NOVELTY: 0.0051083, AVERAGE_POPULARITY: 0.1689915, DIVERSITY_MEAN_INTER_LIST: 0.8467902, DIVERSITY_HERFINDAHL: 0.9846690, COVERAGE_ITEM: 0.0540005, COVERAGE_ITEM_HIT: 0.0033300, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0206520, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0062261, SHANNON_ENTROPY: 7.1713156, RATIO_DIVERSITY_HERFINDAHL: 0.9850256, RATIO_DIVERSITY_GINI: 0.0179759, RATIO_SHANNON_ENTROPY: 0.5526952, RATIO_AVERAGE_POPULARITY: 1.4097441, RATIO_NOVELTY: 0.3207772,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 40 of 500. Elapsed time 2.07 min
# MultVAERecommender: Epoch 41 of 500. Elapsed time 2.10 min
# MultVAERecommender: Epoch 42 of 500. Elapsed time 2.14 min
# MultVAERecommender: Epoch 43 of 500. Elapsed time 2.17 min
# MultVAERecommender: Epoch 44 of 500. Elapsed time 2.21 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 4.98 sec. Users per second: 1694
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0034152, PRECISION_RECALL_MIN_DEN: 0.0098691, RECALL: 0.0095757, MAP: 0.0010626, MAP_MIN_DEN: 0.0029424, MRR: 0.0104415, NDCG: 0.0063772, F1: 0.0050347, HIT_RATE: 0.0337958, ARHR_ALL_HITS: 0.0105337, NOVELTY: 0.0050087, AVERAGE_POPULARITY: 0.1900843, DIVERSITY_MEAN_INTER_LIST: 0.7996231, DIVERSITY_HERFINDAHL: 0.9799528, COVERAGE_ITEM: 0.0402304, COVERAGE_ITEM_HIT: 0.0029700, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0225510, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0042088, SHANNON_ENTROPY: 6.6607095, RATIO_DIVERSITY_HERFINDAHL: 0.9803078, RATIO_DIVERSITY_GINI: 0.0121516, RATIO_SHANNON_ENTROPY: 0.5133426, RATIO_AVERAGE_POPULARITY: 1.5857021, RATIO_NOVELTY: 0.3145196,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 45 of 500. Elapsed time 2.33 min
# MultVAERecommender: Epoch 46 of 500. Elapsed time 2.37 min
# MultVAERecommender: Epoch 47 of 500. Elapsed time 2.40 min
# MultVAERecommender: Epoch 48 of 500. Elapsed time 2.44 min
# MultVAERecommender: Epoch 49 of 500. Elapsed time 2.47 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.00 sec. Users per second: 1686
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0037709, PRECISION_RECALL_MIN_DEN: 0.0110559, RECALL: 0.0107339, MAP: 0.0011990, MAP_MIN_DEN: 0.0034617, MRR: 0.0118125, NDCG: 0.0072675, F1: 0.0055811, HIT_RATE: 0.0374718, ARHR_ALL_HITS: 0.0119015, NOVELTY: 0.0049285, AVERAGE_POPULARITY: 0.2088920, DIVERSITY_MEAN_INTER_LIST: 0.7488212, DIVERSITY_HERFINDAHL: 0.9748732, COVERAGE_ITEM: 0.0301953, COVERAGE_ITEM_HIT: 0.0027000, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0250040, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0029767, SHANNON_ENTROPY: 6.2221587, RATIO_DIVERSITY_HERFINDAHL: 0.9752263, RATIO_DIVERSITY_GINI: 0.0085941, RATIO_SHANNON_ENTROPY: 0.4795434, RATIO_AVERAGE_POPULARITY: 1.7425986, RATIO_NOVELTY: 0.3094882,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 50 of 500. Elapsed time 2.60 min
# MultVAERecommender: Epoch 51 of 500. Elapsed time 2.63 min
# MultVAERecommender: Epoch 52 of 500. Elapsed time 2.67 min
# MultVAERecommender: Epoch 53 of 500. Elapsed time 2.70 min
# MultVAERecommender: Epoch 54 of 500. Elapsed time 2.74 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.04 sec. Users per second: 1672
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0040792, PRECISION_RECALL_MIN_DEN: 0.0122876, RECALL: 0.0119511, MAP: 0.0013251, MAP_MIN_DEN: 0.0040953, MRR: 0.0129840, NDCG: 0.0081856, F1: 0.0060824, HIT_RATE: 0.0403178, ARHR_ALL_HITS: 0.0131174, NOVELTY: 0.0048602, AVERAGE_POPULARITY: 0.2266881, DIVERSITY_MEAN_INTER_LIST: 0.6912209, DIVERSITY_HERFINDAHL: 0.9691139, COVERAGE_ITEM: 0.0223202, COVERAGE_ITEM_HIT: 0.0024300, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0269030, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0021850, SHANNON_ENTROPY: 5.8263732, RATIO_DIVERSITY_HERFINDAHL: 0.9694649, RATIO_DIVERSITY_GINI: 0.0063085, RATIO_SHANNON_ENTROPY: 0.4490401, RATIO_AVERAGE_POPULARITY: 1.8910549, RATIO_NOVELTY: 0.3051955,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 55 of 500. Elapsed time 2.86 min
# MultVAERecommender: Epoch 56 of 500. Elapsed time 2.90 min
# MultVAERecommender: Epoch 57 of 500. Elapsed time 2.93 min
# MultVAERecommender: Epoch 58 of 500. Elapsed time 2.97 min
# MultVAERecommender: Epoch 59 of 500. Elapsed time 3.00 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.12 sec. Users per second: 1649
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0044112, PRECISION_RECALL_MIN_DEN: 0.0136457, RECALL: 0.0132980, MAP: 0.0014610, MAP_MIN_DEN: 0.0045656, MRR: 0.0142843, NDCG: 0.0090416, F1: 0.0066249, HIT_RATE: 0.0434009, ARHR_ALL_HITS: 0.0144471, NOVELTY: 0.0048053, AVERAGE_POPULARITY: 0.2418014, DIVERSITY_MEAN_INTER_LIST: 0.6339158, DIVERSITY_HERFINDAHL: 0.9633841, COVERAGE_ITEM: 0.0166052, COVERAGE_ITEM_HIT: 0.0022500, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0289603, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0016806, SHANNON_ENTROPY: 5.4928498, RATIO_DIVERSITY_HERFINDAHL: 0.9637330, RATIO_DIVERSITY_GINI: 0.0048523, RATIO_SHANNON_ENTROPY: 0.4233354, RATIO_AVERAGE_POPULARITY: 2.0171315, RATIO_NOVELTY: 0.3017484,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 60 of 500. Elapsed time 3.13 min
# MultVAERecommender: Epoch 61 of 500. Elapsed time 3.17 min
# MultVAERecommender: Epoch 62 of 500. Elapsed time 3.20 min
# MultVAERecommender: Epoch 63 of 500. Elapsed time 3.24 min
# MultVAERecommender: Epoch 64 of 500. Elapsed time 3.27 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.11 sec. Users per second: 1651
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0047077, PRECISION_RECALL_MIN_DEN: 0.0146089, RECALL: 0.0142431, MAP: 0.0015397, MAP_MIN_DEN: 0.0049129, MRR: 0.0149781, NDCG: 0.0096803, F1: 0.0070764, HIT_RATE: 0.0461283, ARHR_ALL_HITS: 0.0151877, NOVELTY: 0.0047580, AVERAGE_POPULARITY: 0.2554125, DIVERSITY_MEAN_INTER_LIST: 0.5747578, DIVERSITY_HERFINDAHL: 0.9574690, COVERAGE_ITEM: 0.0126001, COVERAGE_ITEM_HIT: 0.0022500, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0307802, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0013405, SHANNON_ENTROPY: 5.1976268, RATIO_DIVERSITY_HERFINDAHL: 0.9578158, RATIO_DIVERSITY_GINI: 0.0038704, RATIO_SHANNON_ENTROPY: 0.4005824, RATIO_AVERAGE_POPULARITY: 2.1306772, RATIO_NOVELTY: 0.2987785,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 65 of 500. Elapsed time 3.40 min
# MultVAERecommender: Epoch 66 of 500. Elapsed time 3.43 min
# MultVAERecommender: Epoch 67 of 500. Elapsed time 3.47 min
# MultVAERecommender: Epoch 68 of 500. Elapsed time 3.50 min
# MultVAERecommender: Epoch 69 of 500. Elapsed time 3.54 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.11 sec. Users per second: 1649
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0049449, PRECISION_RECALL_MIN_DEN: 0.0153107, RECALL: 0.0149360, MAP: 0.0016227, MAP_MIN_DEN: 0.0052396, MRR: 0.0158311, NDCG: 0.0102233, F1: 0.0074299, HIT_RATE: 0.0483814, ARHR_ALL_HITS: 0.0160291, NOVELTY: 0.0047194, AVERAGE_POPULARITY: 0.2671684, DIVERSITY_MEAN_INTER_LIST: 0.5163948, DIVERSITY_HERFINDAHL: 0.9516334, COVERAGE_ITEM: 0.0100351, COVERAGE_ITEM_HIT: 0.0020700, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0322836, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0011093, SHANNON_ENTROPY: 4.9417813, RATIO_DIVERSITY_HERFINDAHL: 0.9519780, RATIO_DIVERSITY_GINI: 0.0032027, RATIO_SHANNON_ENTROPY: 0.3808644, RATIO_AVERAGE_POPULARITY: 2.2287459, RATIO_NOVELTY: 0.2963544,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 70 of 500. Elapsed time 3.66 min
# MultVAERecommender: Epoch 71 of 500. Elapsed time 3.70 min
# MultVAERecommender: Epoch 72 of 500. Elapsed time 3.73 min
# MultVAERecommender: Epoch 73 of 500. Elapsed time 3.77 min
# MultVAERecommender: Epoch 74 of 500. Elapsed time 3.81 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.12 sec. Users per second: 1648
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0051227, PRECISION_RECALL_MIN_DEN: 0.0158562, RECALL: 0.0154689, MAP: 0.0017355, MAP_MIN_DEN: 0.0057318, MRR: 0.0169052, NDCG: 0.0108623, F1: 0.0076966, HIT_RATE: 0.0500415, ARHR_ALL_HITS: 0.0171303, NOVELTY: 0.0046861, AVERAGE_POPULARITY: 0.2777422, DIVERSITY_MEAN_INTER_LIST: 0.4626415, DIVERSITY_HERFINDAHL: 0.9462587, COVERAGE_ITEM: 0.0075601, COVERAGE_ITEM_HIT: 0.0017550, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0333914, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0009487, SHANNON_ENTROPY: 4.7251412, RATIO_DIVERSITY_HERFINDAHL: 0.9466014, RATIO_DIVERSITY_GINI: 0.0027390, RATIO_SHANNON_ENTROPY: 0.3641679, RATIO_AVERAGE_POPULARITY: 2.3169539, RATIO_NOVELTY: 0.2942633,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 75 of 500. Elapsed time 3.93 min
# MultVAERecommender: Epoch 76 of 500. Elapsed time 3.97 min
# MultVAERecommender: Epoch 77 of 500. Elapsed time 4.00 min
# MultVAERecommender: Epoch 78 of 500. Elapsed time 4.04 min
# MultVAERecommender: Epoch 79 of 500. Elapsed time 4.07 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.15 sec. Users per second: 1638
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0053006, PRECISION_RECALL_MIN_DEN: 0.0164858, RECALL: 0.0160718, MAP: 0.0018095, MAP_MIN_DEN: 0.0059044, MRR: 0.0176104, NDCG: 0.0112583, F1: 0.0079720, HIT_RATE: 0.0519388, ARHR_ALL_HITS: 0.0178525, NOVELTY: 0.0046591, AVERAGE_POPULARITY: 0.2865170, DIVERSITY_MEAN_INTER_LIST: 0.4165296, DIVERSITY_HERFINDAHL: 0.9416480, COVERAGE_ITEM: 0.0059851, COVERAGE_ITEM_HIT: 0.0015300, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0346574, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0008386, SHANNON_ENTROPY: 4.5463414, RATIO_DIVERSITY_HERFINDAHL: 0.9419891, RATIO_DIVERSITY_GINI: 0.0024213, RATIO_SHANNON_ENTROPY: 0.3503877, RATIO_AVERAGE_POPULARITY: 2.3901540, RATIO_NOVELTY: 0.2925702,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 80 of 500. Elapsed time 4.20 min
# MultVAERecommender: Epoch 81 of 500. Elapsed time 4.24 min
# MultVAERecommender: Epoch 82 of 500. Elapsed time 4.27 min
# MultVAERecommender: Epoch 83 of 500. Elapsed time 4.31 min
# MultVAERecommender: Epoch 84 of 500. Elapsed time 4.34 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.09 sec. Users per second: 1658
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0053362, PRECISION_RECALL_MIN_DEN: 0.0168108, RECALL: 0.0163825, MAP: 0.0018329, MAP_MIN_DEN: 0.0059539, MRR: 0.0178285, NDCG: 0.0114071, F1: 0.0080502, HIT_RATE: 0.0521760, ARHR_ALL_HITS: 0.0180726, NOVELTY: 0.0046389, AVERAGE_POPULARITY: 0.2931448, DIVERSITY_MEAN_INTER_LIST: 0.3768805, DIVERSITY_HERFINDAHL: 0.9376836, COVERAGE_ITEM: 0.0051751, COVERAGE_ITEM_HIT: 0.0012150, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0348156, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0007607, SHANNON_ENTROPY: 4.3938099, RATIO_DIVERSITY_HERFINDAHL: 0.9380232, RATIO_DIVERSITY_GINI: 0.0021962, RATIO_SHANNON_ENTROPY: 0.3386321, RATIO_AVERAGE_POPULARITY: 2.4454437, RATIO_NOVELTY: 0.2913007,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 85 of 500. Elapsed time 4.47 min
# MultVAERecommender: Epoch 86 of 500. Elapsed time 4.50 min
# MultVAERecommender: Epoch 87 of 500. Elapsed time 4.54 min
# MultVAERecommender: Epoch 88 of 500. Elapsed time 4.57 min
# MultVAERecommender: Epoch 89 of 500. Elapsed time 4.61 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.14 sec. Users per second: 1642
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0053362, PRECISION_RECALL_MIN_DEN: 0.0170461, RECALL: 0.0166389, MAP: 0.0018936, MAP_MIN_DEN: 0.0062862, MRR: 0.0184519, NDCG: 0.0117681, F1: 0.0080808, HIT_RATE: 0.0522946, ARHR_ALL_HITS: 0.0186940, NOVELTY: 0.0046247, AVERAGE_POPULARITY: 0.2975369, DIVERSITY_MEAN_INTER_LIST: 0.3425805, DIVERSITY_HERFINDAHL: 0.9342540, COVERAGE_ITEM: 0.0040500, COVERAGE_ITEM_HIT: 0.0011700, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0348948, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0007031, SHANNON_ENTROPY: 4.2624743, RATIO_DIVERSITY_HERFINDAHL: 0.9345924, RATIO_DIVERSITY_GINI: 0.0020298, RATIO_SHANNON_ENTROPY: 0.3285100, RATIO_AVERAGE_POPULARITY: 2.4820827, RATIO_NOVELTY: 0.2904090,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 90 of 500. Elapsed time 4.74 min
# MultVAERecommender: Epoch 91 of 500. Elapsed time 4.77 min
# MultVAERecommender: Epoch 92 of 500. Elapsed time 4.81 min
# MultVAERecommender: Epoch 93 of 500. Elapsed time 4.84 min
# MultVAERecommender: Epoch 94 of 500. Elapsed time 4.88 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.12 sec. Users per second: 1648
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0054192, PRECISION_RECALL_MIN_DEN: 0.0171515, RECALL: 0.0167386, MAP: 0.0019667, MAP_MIN_DEN: 0.0064289, MRR: 0.0191881, NDCG: 0.0120115, F1: 0.0081876, HIT_RATE: 0.0531246, ARHR_ALL_HITS: 0.0194274, NOVELTY: 0.0046167, AVERAGE_POPULARITY: 0.3002679, DIVERSITY_MEAN_INTER_LIST: 0.3145731, DIVERSITY_HERFINDAHL: 0.9314536, COVERAGE_ITEM: 0.0035100, COVERAGE_ITEM_HIT: 0.0011700, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0354486, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0006598, SHANNON_ENTROPY: 4.1547364, RATIO_DIVERSITY_HERFINDAHL: 0.9317909, RATIO_DIVERSITY_GINI: 0.0019049, RATIO_SHANNON_ENTROPY: 0.3202066, RATIO_AVERAGE_POPULARITY: 2.5048650, RATIO_NOVELTY: 0.2899066,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 95 of 500. Elapsed time 5.00 min
# MultVAERecommender: Epoch 96 of 500. Elapsed time 5.04 min
# MultVAERecommender: Epoch 97 of 500. Elapsed time 5.07 min
# MultVAERecommender: Epoch 98 of 500. Elapsed time 5.11 min
# MultVAERecommender: Epoch 99 of 500. Elapsed time 5.14 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.14 sec. Users per second: 1640
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0054073, PRECISION_RECALL_MIN_DEN: 0.0172164, RECALL: 0.0168030, MAP: 0.0019932, MAP_MIN_DEN: 0.0065398, MRR: 0.0194537, NDCG: 0.0121405, F1: 0.0081817, HIT_RATE: 0.0530060, ARHR_ALL_HITS: 0.0196929, NOVELTY: 0.0046088, AVERAGE_POPULARITY: 0.3031798, DIVERSITY_MEAN_INTER_LIST: 0.2925721, DIVERSITY_HERFINDAHL: 0.9292537, COVERAGE_ITEM: 0.0030600, COVERAGE_ITEM_HIT: 0.0009450, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0353695, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0006309, SHANNON_ENTROPY: 4.0710507, RATIO_DIVERSITY_HERFINDAHL: 0.9295903, RATIO_DIVERSITY_GINI: 0.0018216, RATIO_SHANNON_ENTROPY: 0.3137569, RATIO_AVERAGE_POPULARITY: 2.5291567, RATIO_NOVELTY: 0.2894082,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 100 of 500. Elapsed time 5.27 min
# MultVAERecommender: Epoch 101 of 500. Elapsed time 5.31 min
# MultVAERecommender: Epoch 102 of 500. Elapsed time 5.34 min
# MultVAERecommender: Epoch 103 of 500. Elapsed time 5.38 min
# MultVAERecommender: Epoch 104 of 500. Elapsed time 5.41 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.12 sec. Users per second: 1646
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0054192, PRECISION_RECALL_MIN_DEN: 0.0171008, RECALL: 0.0166913, MAP: 0.0020424, MAP_MIN_DEN: 0.0067083, MRR: 0.0199526, NDCG: 0.0123078, F1: 0.0081819, HIT_RATE: 0.0531246, ARHR_ALL_HITS: 0.0201885, NOVELTY: 0.0045997, AVERAGE_POPULARITY: 0.3068449, DIVERSITY_MEAN_INTER_LIST: 0.2739031, DIVERSITY_HERFINDAHL: 0.9273871, COVERAGE_ITEM: 0.0025650, COVERAGE_ITEM_HIT: 0.0009000, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0354486, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0006091, SHANNON_ENTROPY: 4.0005460, RATIO_DIVERSITY_HERFINDAHL: 0.9277230, RATIO_DIVERSITY_GINI: 0.0017587, RATIO_SHANNON_ENTROPY: 0.3083231, RATIO_AVERAGE_POPULARITY: 2.5597315, RATIO_NOVELTY: 0.2888384,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 105 of 500. Elapsed time 5.54 min
# MultVAERecommender: Epoch 106 of 500. Elapsed time 5.58 min
# MultVAERecommender: Epoch 107 of 500. Elapsed time 5.61 min
# MultVAERecommender: Epoch 108 of 500. Elapsed time 5.65 min
# MultVAERecommender: Epoch 109 of 500. Elapsed time 5.68 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.10 sec. Users per second: 1653
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0056326, PRECISION_RECALL_MIN_DEN: 0.0178946, RECALL: 0.0174780, MAP: 0.0020807, MAP_MIN_DEN: 0.0069072, MRR: 0.0203443, NDCG: 0.0127079, F1: 0.0085196, HIT_RATE: 0.0552591, ARHR_ALL_HITS: 0.0205755, NOVELTY: 0.0045896, AVERAGE_POPULARITY: 0.3113161, DIVERSITY_MEAN_INTER_LIST: 0.2592304, DIVERSITY_HERFINDAHL: 0.9259200, COVERAGE_ITEM: 0.0022050, COVERAGE_ITEM_HIT: 0.0008550, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0368729, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0005952, SHANNON_ENTROPY: 3.9463053, RATIO_DIVERSITY_HERFINDAHL: 0.9262553, RATIO_DIVERSITY_GINI: 0.0017184, RATIO_SHANNON_ENTROPY: 0.3041428, RATIO_AVERAGE_POPULARITY: 2.5970304, RATIO_NOVELTY: 0.2882056,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 110 of 500. Elapsed time 5.81 min
# MultVAERecommender: Epoch 111 of 500. Elapsed time 5.84 min
# MultVAERecommender: Epoch 112 of 500. Elapsed time 5.88 min
# MultVAERecommender: Epoch 113 of 500. Elapsed time 5.91 min
# MultVAERecommender: Epoch 114 of 500. Elapsed time 5.95 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.10 sec. Users per second: 1655
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0058698, PRECISION_RECALL_MIN_DEN: 0.0185881, RECALL: 0.0181568, MAP: 0.0021330, MAP_MIN_DEN: 0.0070678, MRR: 0.0208367, NDCG: 0.0130829, F1: 0.0088716, HIT_RATE: 0.0573936, ARHR_ALL_HITS: 0.0210831, NOVELTY: 0.0045750, AVERAGE_POPULARITY: 0.3184983, DIVERSITY_MEAN_INTER_LIST: 0.2472806, DIVERSITY_HERFINDAHL: 0.9247251, COVERAGE_ITEM: 0.0018450, COVERAGE_ITEM_HIT: 0.0008550, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0382972, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0005865, SHANNON_ENTROPY: 3.9046718, RATIO_DIVERSITY_HERFINDAHL: 0.9250601, RATIO_DIVERSITY_GINI: 0.0016934, RATIO_SHANNON_ENTROPY: 0.3009341, RATIO_AVERAGE_POPULARITY: 2.6569452, RATIO_NOVELTY: 0.2872874,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 115 of 500. Elapsed time 6.08 min
# MultVAERecommender: Epoch 116 of 500. Elapsed time 6.11 min
# MultVAERecommender: Epoch 117 of 500. Elapsed time 6.15 min
# MultVAERecommender: Epoch 118 of 500. Elapsed time 6.18 min
# MultVAERecommender: Epoch 119 of 500. Elapsed time 6.22 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.14 sec. Users per second: 1641
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0059884, PRECISION_RECALL_MIN_DEN: 0.0190690, RECALL: 0.0186298, MAP: 0.0022001, MAP_MIN_DEN: 0.0072748, MRR: 0.0214442, NDCG: 0.0134211, F1: 0.0090634, HIT_RATE: 0.0583422, ARHR_ALL_HITS: 0.0217165, NOVELTY: 0.0045558, AVERAGE_POPULARITY: 0.3276868, DIVERSITY_MEAN_INTER_LIST: 0.2391226, DIVERSITY_HERFINDAHL: 0.9239094, COVERAGE_ITEM: 0.0016200, COVERAGE_ITEM_HIT: 0.0008550, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0389302, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0005797, SHANNON_ENTROPY: 3.8693279, RATIO_DIVERSITY_HERFINDAHL: 0.9242441, RATIO_DIVERSITY_GINI: 0.0016738, RATIO_SHANNON_ENTROPY: 0.2982101, RATIO_AVERAGE_POPULARITY: 2.7335969, RATIO_NOVELTY: 0.2860808,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 120 of 500. Elapsed time 6.34 min
# MultVAERecommender: Epoch 121 of 500. Elapsed time 6.38 min
# MultVAERecommender: Epoch 122 of 500. Elapsed time 6.41 min
# MultVAERecommender: Epoch 123 of 500. Elapsed time 6.45 min
# MultVAERecommender: Epoch 124 of 500. Elapsed time 6.48 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.18 sec. Users per second: 1628
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0061425, PRECISION_RECALL_MIN_DEN: 0.0193523, RECALL: 0.0189070, MAP: 0.0022191, MAP_MIN_DEN: 0.0073184, MRR: 0.0215960, NDCG: 0.0135827, F1: 0.0092726, HIT_RATE: 0.0596466, ARHR_ALL_HITS: 0.0218877, NOVELTY: 0.0045297, AVERAGE_POPULARITY: 0.3402839, DIVERSITY_MEAN_INTER_LIST: 0.2308013, DIVERSITY_HERFINDAHL: 0.9230774, COVERAGE_ITEM: 0.0013050, COVERAGE_ITEM_HIT: 0.0008550, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0398006, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0005734, SHANNON_ENTROPY: 3.8296218, RATIO_DIVERSITY_HERFINDAHL: 0.9234117, RATIO_DIVERSITY_GINI: 0.0016555, RATIO_SHANNON_ENTROPY: 0.2951499, RATIO_AVERAGE_POPULARITY: 2.8386830, RATIO_NOVELTY: 0.2844408,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 125 of 500. Elapsed time 6.61 min
# MultVAERecommender: Epoch 126 of 500. Elapsed time 6.65 min
# MultVAERecommender: Epoch 127 of 500. Elapsed time 6.68 min
# MultVAERecommender: Epoch 128 of 500. Elapsed time 6.72 min
# MultVAERecommender: Epoch 129 of 500. Elapsed time 6.75 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.16 sec. Users per second: 1635
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0064271, PRECISION_RECALL_MIN_DEN: 0.0205873, RECALL: 0.0201264, MAP: 0.0022859, MAP_MIN_DEN: 0.0074941, MRR: 0.0221972, NDCG: 0.0141056, F1: 0.0097430, HIT_RATE: 0.0624926, ARHR_ALL_HITS: 0.0225214, NOVELTY: 0.0044923, AVERAGE_POPULARITY: 0.3585312, DIVERSITY_MEAN_INTER_LIST: 0.2274486, DIVERSITY_HERFINDAHL: 0.9227422, COVERAGE_ITEM: 0.0011700, COVERAGE_ITEM_HIT: 0.0008100, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0416996, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0005718, SHANNON_ENTROPY: 3.7957651, RATIO_DIVERSITY_HERFINDAHL: 0.9230764, RATIO_DIVERSITY_GINI: 0.0016510, RATIO_SHANNON_ENTROPY: 0.2925406, RATIO_AVERAGE_POPULARITY: 2.9909035, RATIO_NOVELTY: 0.2820969,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 130 of 500. Elapsed time 6.88 min
# MultVAERecommender: Epoch 131 of 500. Elapsed time 6.92 min
# MultVAERecommender: Epoch 132 of 500. Elapsed time 6.95 min
# MultVAERecommender: Epoch 133 of 500. Elapsed time 6.99 min
# MultVAERecommender: Epoch 134 of 500. Elapsed time 7.02 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.13 sec. Users per second: 1644
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0068896, PRECISION_RECALL_MIN_DEN: 0.0217376, RECALL: 0.0212400, MAP: 0.0023687, MAP_MIN_DEN: 0.0077080, MRR: 0.0229317, NDCG: 0.0147211, F1: 0.0104043, HIT_RATE: 0.0667615, ARHR_ALL_HITS: 0.0233017, NOVELTY: 0.0044506, AVERAGE_POPULARITY: 0.3795235, DIVERSITY_MEAN_INTER_LIST: 0.2214914, DIVERSITY_HERFINDAHL: 0.9221465, COVERAGE_ITEM: 0.0012150, COVERAGE_ITEM_HIT: 0.0007200, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0445482, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0005712, SHANNON_ENTROPY: 3.7633983, RATIO_DIVERSITY_HERFINDAHL: 0.9224805, RATIO_DIVERSITY_GINI: 0.0016492, RATIO_SHANNON_ENTROPY: 0.2900461, RATIO_AVERAGE_POPULARITY: 3.1660232, RATIO_NOVELTY: 0.2794746,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 135 of 500. Elapsed time 7.15 min
# MultVAERecommender: Epoch 136 of 500. Elapsed time 7.19 min
# MultVAERecommender: Epoch 137 of 500. Elapsed time 7.22 min
# MultVAERecommender: Epoch 138 of 500. Elapsed time 7.26 min
# MultVAERecommender: Epoch 139 of 500. Elapsed time 7.29 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.12 sec. Users per second: 1648
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0073402, PRECISION_RECALL_MIN_DEN: 0.0231530, RECALL: 0.0226360, MAP: 0.0025025, MAP_MIN_DEN: 0.0081579, MRR: 0.0241990, NDCG: 0.0156124, F1: 0.0110857, HIT_RATE: 0.0711491, ARHR_ALL_HITS: 0.0246022, NOVELTY: 0.0044097, AVERAGE_POPULARITY: 0.4002636, DIVERSITY_MEAN_INTER_LIST: 0.2119447, DIVERSITY_HERFINDAHL: 0.9211920, COVERAGE_ITEM: 0.0010800, COVERAGE_ITEM_HIT: 0.0007200, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0474759, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0005668, SHANNON_ENTROPY: 3.7348276, RATIO_DIVERSITY_HERFINDAHL: 0.9215256, RATIO_DIVERSITY_GINI: 0.0016364, RATIO_SHANNON_ENTROPY: 0.2878441, RATIO_AVERAGE_POPULARITY: 3.3390396, RATIO_NOVELTY: 0.2769047,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 140 of 500. Elapsed time 7.42 min
# MultVAERecommender: Epoch 141 of 500. Elapsed time 7.45 min
# MultVAERecommender: Epoch 142 of 500. Elapsed time 7.49 min
# MultVAERecommender: Epoch 143 of 500. Elapsed time 7.52 min
# MultVAERecommender: Epoch 144 of 500. Elapsed time 7.56 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.15 sec. Users per second: 1638
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0076367, PRECISION_RECALL_MIN_DEN: 0.0244348, RECALL: 0.0239194, MAP: 0.0026158, MAP_MIN_DEN: 0.0085335, MRR: 0.0252442, NDCG: 0.0163610, F1: 0.0115771, HIT_RATE: 0.0738764, ARHR_ALL_HITS: 0.0256913, NOVELTY: 0.0043686, AVERAGE_POPULARITY: 0.4202622, DIVERSITY_MEAN_INTER_LIST: 0.1946392, DIVERSITY_HERFINDAHL: 0.9194616, COVERAGE_ITEM: 0.0010800, COVERAGE_ITEM_HIT: 0.0006750, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0492958, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0005565, SHANNON_ENTROPY: 3.7064957, RATIO_DIVERSITY_HERFINDAHL: 0.9197946, RATIO_DIVERSITY_GINI: 0.0016068, RATIO_SHANNON_ENTROPY: 0.2856606, RATIO_AVERAGE_POPULARITY: 3.5058701, RATIO_NOVELTY: 0.2743257,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 145 of 500. Elapsed time 7.69 min
# MultVAERecommender: Epoch 146 of 500. Elapsed time 7.72 min
# MultVAERecommender: Epoch 147 of 500. Elapsed time 7.76 min
# MultVAERecommender: Epoch 148 of 500. Elapsed time 7.79 min
# MultVAERecommender: Epoch 149 of 500. Elapsed time 7.83 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.14 sec. Users per second: 1641
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0078501, PRECISION_RECALL_MIN_DEN: 0.0252748, RECALL: 0.0247629, MAP: 0.0027358, MAP_MIN_DEN: 0.0089492, MRR: 0.0264065, NDCG: 0.0170459, F1: 0.0119211, HIT_RATE: 0.0758923, ARHR_ALL_HITS: 0.0268721, NOVELTY: 0.0043403, AVERAGE_POPULARITY: 0.4320194, DIVERSITY_MEAN_INTER_LIST: 0.1806131, DIVERSITY_HERFINDAHL: 0.9180592, COVERAGE_ITEM: 0.0010350, COVERAGE_ITEM_HIT: 0.0007200, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0506409, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0005506, SHANNON_ENTROPY: 3.6873348, RATIO_DIVERSITY_HERFINDAHL: 0.9183917, RATIO_DIVERSITY_GINI: 0.0015898, RATIO_SHANNON_ENTROPY: 0.2841838, RATIO_AVERAGE_POPULARITY: 3.6039495, RATIO_NOVELTY: 0.2725518,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 150 of 500. Elapsed time 7.96 min
# MultVAERecommender: Epoch 151 of 500. Elapsed time 7.99 min
# MultVAERecommender: Epoch 152 of 500. Elapsed time 8.03 min
# MultVAERecommender: Epoch 153 of 500. Elapsed time 8.06 min
# MultVAERecommender: Epoch 154 of 500. Elapsed time 8.10 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.18 sec. Users per second: 1629
# MultVAERecommender: CUTOFF: 10 - PRECISION: 0.0080873, PRECISION_RECALL_MIN_DEN: 0.0257813, RECALL: 0.0252606, MAP: 0.0028779, MAP_MIN_DEN: 0.0093656, MRR: 0.0276631, NDCG: 0.0176728, F1: 0.0122520, HIT_RATE: 0.0776711, ARHR_ALL_HITS: 0.0282111, NOVELTY: 0.0043174, AVERAGE_POPULARITY: 0.4419250, DIVERSITY_MEAN_INTER_LIST: 0.1749704, DIVERSITY_HERFINDAHL: 0.9174950, COVERAGE_ITEM: 0.0009450, COVERAGE_ITEM_HIT: 0.0007200, ITEMS_IN_GT: 0.5505805, COVERAGE_USER: 0.6672733, COVERAGE_USER_HIT: 0.0518278, USERS_IN_GT: 0.6672733, DIVERSITY_GINI: 0.0005487, SHANNON_ENTROPY: 3.6831048, RATIO_DIVERSITY_HERFINDAHL: 0.9178273, RATIO_DIVERSITY_GINI: 0.0015842, RATIO_SHANNON_ENTROPY: 0.2838578, RATIO_AVERAGE_POPULARITY: 3.6865828, RATIO_NOVELTY: 0.2711120,
#
# MultVAERecommender: New best model found! Updating.
# MultVAERecommender: Saving model in file './result_experiments/__Temp_MultVAERecommender_6911/_best_model'
# MultVAERecommender: Saving complete
# MultVAERecommender: Epoch 155 of 500. Elapsed time 8.23 min
# MultVAERecommender: Epoch 156 of 500. Elapsed time 8.26 min
# MultVAERecommender: Epoch 157 of 500. Elapsed time 8.30 min
# MultVAERecommender: Epoch 158 of 500. Elapsed time 8.33 min
# MultVAERecommender: Epoch 159 of 500. Elapsed time 8.37 min
# MultVAERecommender: Validation begins...
# EvaluatorHoldout: Processed 8433 (100.0%) in 5.16 sec. Users per second: 1633
# ...
# 2023-12-14 10:55:47.067511: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 5, Chunks in use: 5. 50.64MiB allocated for chunks. 50.64MiB in use in bin. 48.22MiB client-requested in use in bin.
# 2023-12-14 10:55:47.067529: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 3, Chunks in use: 2. 68.70MiB allocated for chunks. 47.00MiB in use in bin. 43.40MiB client-requested in use in bin.
# 2023-12-14 10:55:47.067543: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-14 10:55:47.067558: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-12-14 10:55:47.067583: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 9, Chunks in use: 8. 1.99GiB allocated for chunks. 1.82GiB in use in bin. 1.82GiB client-requested in use in bin.
# 2023-12-14 10:55:47.067610: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 2, Chunks in use: 2. 598.25MiB allocated for chunks. 598.25MiB in use in bin. 466.91MiB client-requested in use in bin.
# 2023-12-14 10:55:47.067651: I tensorflow/tsl/framework/bfc_allocator.cc:1062] Bin for 233.46MiB was 128.00MiB, Chunk State:
# 2023-12-14 10:55:47.067691: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 174.03MiB | Requested Size: 21.70MiB | in_use: 0 | bin_num: 19, prev:   Size: 9.64MiB | Requested Size: 9.64MiB | in_use: 1 | bin_num: -1, next:   Size: 233.46MiB | Requested Size: 233.46MiB | in_use: 1 | bin_num: -1
# 2023-12-14 10:55:47.067720: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 2930835456
# 2023-12-14 10:55:47.067743: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46b0000000 of size 256 next 52
# 2023-12-14 10:55:47.067763: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46b0000100 of size 256 next 59
# 2023-12-14 10:55:47.067787: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46b0000200 of size 11264 next 48
# 2023-12-14 10:55:47.067807: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46b0002e00 of size 256 next 40
# 2023-12-14 10:55:47.067818: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46b0002f00 of size 89088 next 21
# 2023-12-14 10:55:47.067825: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46b0018b00 of size 256 next 64
# 2023-12-14 10:55:47.067829: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46b0018c00 of size 11264 next 51
# 2023-12-14 10:55:47.067846: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46b001b800 of size 256 next 43
# 2023-12-14 10:55:47.067852: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46b001b900 of size 3840 next 62
# 2023-12-14 10:55:47.067857: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46b001c800 of size 256 next 22
# 2023-12-14 10:55:47.067861: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46b001c900 of size 5056512 next 49
# 2023-12-14 10:55:47.067867: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46b04ef100 of size 256 next 58
# 2023-12-14 10:55:47.067873: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46b04ef200 of size 256 next 83
# 2023-12-14 10:55:47.067880: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46b04ef300 of size 244797696 next 23
# 2023-12-14 10:55:47.067886: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46bee64400 of size 256 next 44
# 2023-12-14 10:55:47.067891: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46bee64500 of size 256 next 47
# 2023-12-14 10:55:47.067896: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46bee64600 of size 244797696 next 55
# 2023-12-14 10:55:47.067901: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46cd7d9700 of size 256 next 65
# 2023-12-14 10:55:47.067906: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46cd7d9800 of size 10112768 next 56
# 2023-12-14 10:55:47.067910: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ce17e700 of size 256 next 25
# 2023-12-14 10:55:47.067916: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ce17e800 of size 256 next 24
# 2023-12-14 10:55:47.067922: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ce17e900 of size 1280 next 19
# 2023-12-14 10:55:47.067927: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ce17ee00 of size 11264 next 18
# 2023-12-14 10:55:47.067932: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ce181a00 of size 89088 next 63
# 2023-12-14 10:55:47.067937: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ce197600 of size 10112768 next 20
# 2023-12-14 10:55:47.067942: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ceb3c500 of size 5056512 next 26
# 2023-12-14 10:55:47.067947: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46cf00ed00 of size 244797696 next 54
# 2023-12-14 10:55:47.067951: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46dd983e00 of size 244797696 next 45
# 2023-12-14 10:55:47.067956: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ec2f8f00 of size 3840 next 53
# 2023-12-14 10:55:47.067961: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ec2f9e00 of size 11264 next 60
# 2023-12-14 10:55:47.067965: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ec2fca00 of size 256 next 74
# 2023-12-14 10:55:47.067971: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ec2fcb00 of size 256 next 30
# 2023-12-14 10:55:47.067976: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ec2fcc00 of size 256 next 46
# 2023-12-14 10:55:47.067980: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ec2fcd00 of size 256 next 29
# 2023-12-14 10:55:47.067986: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ec2fce00 of size 256 next 28
# 2023-12-14 10:55:47.067990: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ec2fcf00 of size 256 next 27
# 2023-12-14 10:55:47.067995: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ec2fd000 of size 256 next 50
# 2023-12-14 10:55:47.068000: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ec2fd100 of size 256 next 85
# 2023-12-14 10:55:47.068006: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ec2fd200 of size 256 next 17
# 2023-12-14 10:55:47.068011: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ec2fd300 of size 256 next 16
# 2023-12-14 10:55:47.068016: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ec2fd400 of size 5056512 next 39
# 2023-12-14 10:55:47.068021: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ec7cfc00 of size 5056512 next 14
# 2023-12-14 10:55:47.068026: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ecca2400 of size 12644608 next 6
# 2023-12-14 10:55:47.068032: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ed8b1500 of size 26526720 next 7
# 2023-12-14 10:55:47.068038: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ef1fd900 of size 11264 next 8
# 2023-12-14 10:55:47.068043: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ef200500 of size 11264 next 32
# 2023-12-14 10:55:47.068047: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ef203100 of size 256 next 34
# 2023-12-14 10:55:47.068051: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ef203200 of size 256 next 5
# 2023-12-14 10:55:47.068057: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7f46ef203300 of size 3328 next 38
# 2023-12-14 10:55:47.068061: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ef204000 of size 3840 next 1
# 2023-12-14 10:55:47.068066: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ef204f00 of size 3840 next 42
# 2023-12-14 10:55:47.068071: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7f46ef205e00 of size 11264 next 3
# 2023-12-14 10:55:47.068077: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ef208a00 of size 11264 next 4
# 2023-12-14 10:55:47.068081: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ef20b600 of size 21248 next 57
# 2023-12-14 10:55:47.068086: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ef210900 of size 89088 next 10
# 2023-12-14 10:55:47.068091: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ef226500 of size 89088 next 13
# 2023-12-14 10:55:47.068098: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ef23c100 of size 10112768 next 2
# 2023-12-14 10:55:47.068103: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46efbe1000 of size 270219776 next 37
# 2023-12-14 10:55:47.068107: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f46ffd94a00 of size 22755328 next 31
# 2023-12-14 10:55:47.068113: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4701348200 of size 2820096 next 90
# 2023-12-14 10:55:47.068119: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f47015f8a00 of size 470016 next 92
# 2023-12-14 10:55:47.068123: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f470166b600 of size 470016 next 73
# 2023-12-14 10:55:47.068128: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7f47016de200 of size 470016 next 80
# 2023-12-14 10:55:47.068132: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4701750e00 of size 470016 next 77
# 2023-12-14 10:55:47.068137: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f47017c3a00 of size 470016 next 70
# 2023-12-14 10:55:47.068141: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4701836600 of size 470016 next 41
# 2023-12-14 10:55:47.068147: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f47018a9200 of size 470016 next 66
# 2023-12-14 10:55:47.068152: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f470191be00 of size 2820096 next 82
# 2023-12-14 10:55:47.068158: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4701bcc600 of size 2820096 next 78
# 2023-12-14 10:55:47.068165: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7f4701e7ce00 of size 22755328 next 89
# 2023-12-14 10:55:47.068170: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4703430600 of size 5056512 next 87
# 2023-12-14 10:55:47.068175: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4703902e00 of size 10112768 next 81
# 2023-12-14 10:55:47.068181: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7f47042a7d00 of size 182480128 next 33
# 2023-12-14 10:55:47.068186: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f470f0aea00 of size 244797696 next 36
# 2023-12-14 10:55:47.068191: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f471da23b00 of size 244797696 next 15
# 2023-12-14 10:55:47.068196: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f472c398c00 of size 244797696 next 9
# 2023-12-14 10:55:47.068201: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f473ad0dd00 of size 244797696 next 75
# 2023-12-14 10:55:47.068205: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4749682e00 of size 357093888 next 18446744073709551615
# 2023-12-14 10:55:47.068212: I tensorflow/tsl/framework/bfc_allocator.cc:1100]      Summary of in-use Chunks by size:
# 2023-12-14 10:55:47.068256: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 25 Chunks of size 256 totalling 6.2KiB
# 2023-12-14 10:55:47.068263: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1280 totalling 1.2KiB
# 2023-12-14 10:55:47.068269: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 3840 totalling 15.0KiB
# 2023-12-14 10:55:47.068274: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 11264 totalling 77.0KiB
# 2023-12-14 10:55:47.068279: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 21248 totalling 20.8KiB
# 2023-12-14 10:55:47.068284: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 89088 totalling 348.0KiB
# 2023-12-14 10:55:47.068289: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 6 Chunks of size 470016 totalling 2.69MiB
# 2023-12-14 10:55:47.068295: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 2820096 totalling 8.07MiB
# 2023-12-14 10:55:47.068299: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 5 Chunks of size 5056512 totalling 24.11MiB
# 2023-12-14 10:55:47.068305: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 10112768 totalling 38.58MiB
# 2023-12-14 10:55:47.068316: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 12644608 totalling 12.06MiB
# 2023-12-14 10:55:47.068323: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 22755328 totalling 21.70MiB
# 2023-12-14 10:55:47.068331: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 26526720 totalling 25.30MiB
# 2023-12-14 10:55:47.068338: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 8 Chunks of size 244797696 totalling 1.82GiB
# 2023-12-14 10:55:47.068346: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 270219776 totalling 257.70MiB
# 2023-12-14 10:55:47.068352: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 357093888 totalling 340.55MiB
# 2023-12-14 10:55:47.068359: I tensorflow/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 2.54GiB
# 2023-12-14 10:55:47.068366: I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 2930835456 memory_limit_: 2930835456 available bytes: 0 curr_region_allocation_bytes_: 5861670912
# 2023-12-14 10:55:47.068385: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                      2930835456
# InUse:                      2725115392
# MaxInUse:                   2767806976
# NumAllocs:                      682359
# MaxAllocSize:                357093888
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-12-14 10:55:47.068399: W tensorflow/tsl/framework/bfc_allocator.cc:497] *************************************************_____*******************************************xxx
# 2023-12-14 10:55:47.068460: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at matmul_op_impl.h:731 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[2754,22222] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# MultVAERecommender: Cleaning temporary files from './result_experiments/__Temp_MultVAERecommender_6911/'
# SearchBayesianSkopt: Search for 'MultVAERecommender' interrupted due to MemoryError.
# SearchBayesianSkopt: Search interrupted due to ValueError. The evaluated configurations may have had all the same value.
# Traceback (most recent call last):
#   File "/home/kinami/code/rcs/HyperparameterTuning/SearchBayesianSkopt.py", line 340, in search
#     self.result = gp_minimize(self._objective_function_list_input,
#   File "/home/kinami/.conda/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/gp.py", line 259, in gp_minimize
#     return base_minimize(
#   File "/home/kinami/.conda/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/base.py", line 300, in base_minimize
#     result = optimizer.tell(next_x, next_y)
#   File "/home/kinami/.conda/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/optimizer.py", line 483, in tell
#     self._check_y_is_valid(x, y)
#   File "/home/kinami/.conda/envs/RecSysFramework/lib/python3.8/site-packages/skopt/optimizer/optimizer.py", line 636, in _check_y_is_valid
#     raise ValueError("`func` should return a scalar")
# ValueError: `func` should return a scalar

# %%
data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + "_metadata.zip")
search_metadata['result_on_test_best']
# Out:
#        PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
# cutoff
# 10      0.043266                 0.083122  0.072094  0.018344    0.034384
#
#              MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                        ...
# 10      0.131651  0.069083  0.054078  0.311282      0.154609  ...
#
#        COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
# cutoff
# 10          0.832489          0.259139    0.832489       0.013149
#
#        SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
# cutoff
# 10            8.010796                   0.988156             0.037869
#
#        RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
# cutoff
# 10                  0.617246                 3.246544      0.285167
#
# [1 rows x 27 columns]

# %%
recommender_object = recommender_class(data_train + data_validation)
recommender_object.load_model(output_folder_path, 
                              file_name = recommender_object.RECOMMENDER_NAME + "_best_model_last.zip" )
# Out:
# MultVAERecommender: URM Detected 228 ( 1.8%) users with no interactions.
# MultVAERecommender: URM Detected 105 ( 0.5%) items with no interactions.
# MultVAERecommender: Loading model from file 'result_experiments/MultVAERecommender_best_model_last.zip'
# ---------------------------------------------------------------------------
# ReadError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 recommender_object = recommender_class(data_train + data_validation)
# ----> 2 recommender_object.load_model(output_folder_path,
#       3                               file_name = recommender_object.RECOMMENDER_NAME + "_best_model_last.zip" )
#
# File ~/code/rcs/Recommenders/Neural/MultVAERecommender.py:440, in MultVAERecommender.load_model(self, folder_path, file_name, create_zip)
#     437 self._print("Loading model from file '{}'".format(folder_path + file_name))
#     439 if create_zip:
# --> 440     shutil.unpack_archive(folder_path + file_name + ".zip",
#     441                           folder_path + file_name + "/",
#     442                           "zip")
#     444 dataIO = DataIO(folder_path=folder_path + file_name + "/")
#     445 data_dict = dataIO.load_data(file_name="fit_attributes")
#
# File ~/.conda/envs/RecSysFramework/lib/python3.8/shutil.py:1239, in unpack_archive(filename, extract_dir, format, filter)
#    1236         raise ValueError("Unknown unpack format '{0}'".format(format)) from None
#    1238     func = format_info[1]
# -> 1239     func(filename, extract_dir, **dict(format_info[2]), **filter_kwargs)
#    1240 else:
#    1241     # we need to look at the registered unpackers supported extensions
#    1242     format = _find_unpack_format(filename)
#
# File ~/.conda/envs/RecSysFramework/lib/python3.8/shutil.py:1136, in _unpack_zipfile(filename, extract_dir)
#    1133 import zipfile  # late import for breaking circular dependency
#    1135 if not zipfile.is_zipfile(filename):
# -> 1136     raise ReadError("%s is not a zip file" % filename)
#    1138 zip = zipfile.ZipFile(filename)
#    1139 try:
#
# ReadError: result_experiments/MultVAERecommender_best_model_last.zip.zip is not a zip file

# %%
from utils import write_submission

write_submission(prepare_submission(data, users, data_train + data_validation, recommender_object))
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
