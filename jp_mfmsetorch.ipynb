# %%
import os
from utils import *
import optuna

# %%
data, usermap, itemmap, users = load_data2()
data_train, data_val = split_data2(data, 0.2)

# %%
study_name = "MFMSETorch"
study = optuna.create_study(
    study_name=study_name,
    storage=get_database_url(),
    load_if_exists=True,
    direction="maximize",
)
# Out:
# [I 2024-01-08 23:56:58,344] Using an existing study with name 'MFMSETorch' instead of creating a new one.

# %%
from Recommenders.MatrixFactorization.PyTorch.MF_MSE_PyTorch import MF_MSE_PyTorch
from Evaluation.Evaluator import EvaluatorHoldout

evaluator_validation = EvaluatorHoldout(data_val, cutoff_list=[10])

def objective(trial):
    epochs = trial.suggest_int('epochs', 5, 500)
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128, 256, 512])
    num_factors = trial.suggest_int('num_factors', 8, 256)
    learning_rate = trial.suggest_float('learning_rate', 1e-8, 1)
    
    recommender = MF_MSE_PyTorch(data_train)
    recommender.fit(
        epochs=epochs,
        batch_size=batch_size,
        num_factors=num_factors,
        learning_rate=learning_rate,
        validation_every_n=10,
        stop_on_validation=True,
        evaluator_object=evaluator_validation,
        lower_validations_allowed=5,
        validation_metric="MAP",
    )
    _, _, ev_map, _, _ = evaluator(recommender, data_train, data_val)
    
    return ev_map

study.optimize(objective, n_trials=150)
# Out:
# EvaluatorHoldout: Ignoring 2226 (17.6%) Users that have less than 1 test interactions
# MF_MSE_PyTorch_Recommender: URM Detected 197 ( 1.6%) users with no interactions.
# MF_MSE_PyTorch_Recommender: URM Detected 115 ( 0.5%) items with no interactions.
# MF_MSE_PyTorch_Recommender: MF_MSE_PyTorch: Using CUDA
# /home/kinami/.conda/envs/RecSysFramework/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# MF_MSE_PyTorch_Recommender: Epoch 1, Batch: [10000/11969], Samples per second 11398.43
# MF_MSE_PyTorch_Recommender: Epoch 1, Batch: [11969/11969], Samples per second 11417.29
# MF_MSE_PyTorch_Recommender: Epoch 1 of 120. Elapsed time 33.57 sec
# MF_MSE_PyTorch_Recommender: Epoch 2, Batch: [10000/11969], Samples per second 11508.85
# MF_MSE_PyTorch_Recommender: Epoch 2, Batch: [11969/11969], Samples per second 11513.69
# MF_MSE_PyTorch_Recommender: Epoch 2 of 120. Elapsed time 1.11 min
# MF_MSE_PyTorch_Recommender: Epoch 3, Batch: [10000/11969], Samples per second 11511.36
# MF_MSE_PyTorch_Recommender: Epoch 3, Batch: [11969/11969], Samples per second 11519.68
# MF_MSE_PyTorch_Recommender: Epoch 3 of 120. Elapsed time 1.67 min
# MF_MSE_PyTorch_Recommender: Epoch 4, Batch: [10000/11969], Samples per second 11559.91
# MF_MSE_PyTorch_Recommender: Epoch 4, Batch: [11969/11969], Samples per second 11568.11
# MF_MSE_PyTorch_Recommender: Epoch 4 of 120. Elapsed time 2.22 min
# MF_MSE_PyTorch_Recommender: Epoch 5, Batch: [10000/11969], Samples per second 11522.79
# MF_MSE_PyTorch_Recommender: Epoch 5, Batch: [11969/11969], Samples per second 11527.99
# MF_MSE_PyTorch_Recommender: Epoch 5 of 120. Elapsed time 2.78 min
# MF_MSE_PyTorch_Recommender: Epoch 6, Batch: [10000/11969], Samples per second 11588.75
# MF_MSE_PyTorch_Recommender: Epoch 6, Batch: [11969/11969], Samples per second 11577.44
# MF_MSE_PyTorch_Recommender: Epoch 6 of 120. Elapsed time 3.33 min
# MF_MSE_PyTorch_Recommender: Epoch 7, Batch: [10000/11969], Samples per second 11553.30
# MF_MSE_PyTorch_Recommender: Epoch 7, Batch: [11969/11969], Samples per second 11559.28
# MF_MSE_PyTorch_Recommender: Epoch 7 of 120. Elapsed time 3.88 min
# MF_MSE_PyTorch_Recommender: Epoch 8, Batch: [10000/11969], Samples per second 11557.73
# MF_MSE_PyTorch_Recommender: Epoch 8, Batch: [11969/11969], Samples per second 11553.21
# MF_MSE_PyTorch_Recommender: Epoch 8 of 120. Elapsed time 4.43 min
# MF_MSE_PyTorch_Recommender: Epoch 9, Batch: [10000/11969], Samples per second 11504.40
# MF_MSE_PyTorch_Recommender: Epoch 9, Batch: [11969/11969], Samples per second 11512.53
# MF_MSE_PyTorch_Recommender: Epoch 9 of 120. Elapsed time 4.99 min
# MF_MSE_PyTorch_Recommender: Epoch 10, Batch: [10000/11969], Samples per second 11518.12
# MF_MSE_PyTorch_Recommender: Epoch 10, Batch: [11969/11969], Samples per second 11517.53
# MF_MSE_PyTorch_Recommender: Validation begins...
# EvaluatorHoldout: Processed 10412 (100.0%) in 5.76 sec. Users per second: 1806
# MF_MSE_PyTorch_Recommender: CUTOFF: 10 - PRECISION: 0.0025163, PRECISION_RECALL_MIN_DEN: 0.0043749, RECALL: 0.0035240, MAP: 0.0008659, MAP_MIN_DEN: 0.0014955, MRR: 0.0084186, NDCG: 0.0036291, F1: 0.0029361, HIT_RATE: 0.0242989, ARHR_ALL_HITS: 0.0085387, NOVELTY: 0.0060426, AVERAGE_POPULARITY: 0.0675508, DIVERSITY_MEAN_INTER_LIST: 0.9895798, DIVERSITY_HERFINDAHL: 0.9989485, COVERAGE_ITEM: 0.5785258, COVERAGE_ITEM_HIT: 0.0076051, ITEMS_IN_GT: 0.8018630, COVERAGE_USER: 0.8238645, COVERAGE_USER_HIT: 0.0200190, USERS_IN_GT: 0.8238645, DIVERSITY_GINI: 0.1221364, SHANNON_ENTROPY: 11.2042487, RATIO_DIVERSITY_HERFINDAHL: 0.9993099, RATIO_DIVERSITY_GINI: 0.3503118, RATIO_SHANNON_ENTROPY: 0.8631014, RATIO_AVERAGE_POPULARITY: 0.5404996, RATIO_NOVELTY: 0.3413374,
#
# MF_MSE_PyTorch_Recommender: New best model found! Updating.
# MF_MSE_PyTorch_Recommender: Epoch 10 of 120. Elapsed time 5.64 min
# MF_MSE_PyTorch_Recommender: Epoch 11, Batch: [10000/11969], Samples per second 11596.54
# MF_MSE_PyTorch_Recommender: Epoch 11, Batch: [11969/11969], Samples per second 11585.37
# MF_MSE_PyTorch_Recommender: Epoch 11 of 120. Elapsed time 6.19 min
# MF_MSE_PyTorch_Recommender: Epoch 12, Batch: [10000/11969], Samples per second 11592.20
# MF_MSE_PyTorch_Recommender: Epoch 12, Batch: [11969/11969], Samples per second 11590.92
# MF_MSE_PyTorch_Recommender: Epoch 12 of 120. Elapsed time 6.74 min
# MF_MSE_PyTorch_Recommender: Epoch 13, Batch: [10000/11969], Samples per second 11561.72
# MF_MSE_PyTorch_Recommender: Epoch 13, Batch: [11969/11969], Samples per second 11562.28
# MF_MSE_PyTorch_Recommender: Epoch 13 of 120. Elapsed time 7.29 min
# MF_MSE_PyTorch_Recommender: Epoch 14, Batch: [10000/11969], Samples per second 11550.14
# MF_MSE_PyTorch_Recommender: Epoch 14, Batch: [11969/11969], Samples per second 11549.45
# MF_MSE_PyTorch_Recommender: Epoch 14 of 120. Elapsed time 7.85 min
# MF_MSE_PyTorch_Recommender: Epoch 15, Batch: [10000/11969], Samples per second 11543.09
# MF_MSE_PyTorch_Recommender: Epoch 15, Batch: [11969/11969], Samples per second 11532.23
# MF_MSE_PyTorch_Recommender: Epoch 15 of 120. Elapsed time 8.40 min
# MF_MSE_PyTorch_Recommender: Epoch 16, Batch: [10000/11969], Samples per second 11575.37
# MF_MSE_PyTorch_Recommender: Epoch 16, Batch: [11969/11969], Samples per second 11573.91
# MF_MSE_PyTorch_Recommender: Epoch 16 of 120. Elapsed time 8.95 min
# MF_MSE_PyTorch_Recommender: Epoch 17, Batch: [10000/11969], Samples per second 11566.30
# MF_MSE_PyTorch_Recommender: Epoch 17, Batch: [11969/11969], Samples per second 11568.32
# MF_MSE_PyTorch_Recommender: Epoch 17 of 120. Elapsed time 9.51 min
# MF_MSE_PyTorch_Recommender: Epoch 18, Batch: [10000/11969], Samples per second 11517.74
# MF_MSE_PyTorch_Recommender: Epoch 18, Batch: [11969/11969], Samples per second 11530.40
# MF_MSE_PyTorch_Recommender: Epoch 18 of 120. Elapsed time 10.06 min
# MF_MSE_PyTorch_Recommender: Epoch 19, Batch: [10000/11969], Samples per second 11521.14
# MF_MSE_PyTorch_Recommender: Epoch 19, Batch: [11969/11969], Samples per second 11531.96
# MF_MSE_PyTorch_Recommender: Epoch 19 of 120. Elapsed time 10.61 min
# MF_MSE_PyTorch_Recommender: Epoch 20, Batch: [10000/11969], Samples per second 11577.94
# MF_MSE_PyTorch_Recommender: Epoch 20, Batch: [11969/11969], Samples per second 11582.61
# MF_MSE_PyTorch_Recommender: Validation begins...
# EvaluatorHoldout: Processed 10412 (100.0%) in 5.54 sec. Users per second: 1878
# MF_MSE_PyTorch_Recommender: CUTOFF: 10 - PRECISION: 0.0023050, PRECISION_RECALL_MIN_DEN: 0.0040008, RECALL: 0.0032474, MAP: 0.0007571, MAP_MIN_DEN: 0.0013125, MRR: 0.0074515, NDCG: 0.0032621, F1: 0.0026963, HIT_RATE: 0.0225701, ARHR_ALL_HITS: 0.0075112, NOVELTY: 0.0060096, AVERAGE_POPULARITY: 0.0674589, DIVERSITY_MEAN_INTER_LIST: 0.9890572, DIVERSITY_HERFINDAHL: 0.9988962, COVERAGE_ITEM: 0.5360904, COVERAGE_ITEM_HIT: 0.0073801, ITEMS_IN_GT: 0.8018630, COVERAGE_USER: 0.8238645, COVERAGE_USER_HIT: 0.0185947, USERS_IN_GT: 0.8238645, DIVERSITY_GINI: 0.1053435, SHANNON_ENTROPY: 11.0256011, RATIO_DIVERSITY_HERFINDAHL: 0.9992576, RATIO_DIVERSITY_GINI: 0.3021463, RATIO_SHANNON_ENTROPY: 0.8493396, RATIO_AVERAGE_POPULARITY: 0.5397640, RATIO_NOVELTY: 0.3394710,
#
# MF_MSE_PyTorch_Recommender: Epoch 20 of 120. Elapsed time 11.26 min
# MF_MSE_PyTorch_Recommender: Epoch 21, Batch: [10000/11969], Samples per second 11578.06
# MF_MSE_PyTorch_Recommender: Epoch 21, Batch: [11969/11969], Samples per second 11573.99
# MF_MSE_PyTorch_Recommender: Epoch 21 of 120. Elapsed time 11.81 min
# MF_MSE_PyTorch_Recommender: Epoch 22, Batch: [10000/11969], Samples per second 11588.84
# MF_MSE_PyTorch_Recommender: Epoch 22, Batch: [11969/11969], Samples per second 11585.98
# MF_MSE_PyTorch_Recommender: Epoch 22 of 120. Elapsed time 12.36 min
# MF_MSE_PyTorch_Recommender: Epoch 23, Batch: [10000/11969], Samples per second 11590.64
# MF_MSE_PyTorch_Recommender: Epoch 23, Batch: [11969/11969], Samples per second 11594.91
# MF_MSE_PyTorch_Recommender: Epoch 23 of 120. Elapsed time 12.91 min
# MF_MSE_PyTorch_Recommender: Epoch 24, Batch: [10000/11969], Samples per second 11567.46
# MF_MSE_PyTorch_Recommender: Epoch 24, Batch: [11969/11969], Samples per second 11572.84
# MF_MSE_PyTorch_Recommender: Epoch 24 of 120. Elapsed time 13.46 min
# MF_MSE_PyTorch_Recommender: Epoch 25, Batch: [10000/11969], Samples per second 11516.22
# MF_MSE_PyTorch_Recommender: Epoch 25, Batch: [11969/11969], Samples per second 11529.87
# MF_MSE_PyTorch_Recommender: Epoch 25 of 120. Elapsed time 14.02 min
# MF_MSE_PyTorch_Recommender: Epoch 26, Batch: [10000/11969], Samples per second 11539.65
# MF_MSE_PyTorch_Recommender: Epoch 26, Batch: [11969/11969], Samples per second 11546.45
# MF_MSE_PyTorch_Recommender: Epoch 26 of 120. Elapsed time 14.57 min
# MF_MSE_PyTorch_Recommender: Epoch 27, Batch: [10000/11969], Samples per second 11530.02
# MF_MSE_PyTorch_Recommender: Epoch 27, Batch: [11969/11969], Samples per second 11539.16
# MF_MSE_PyTorch_Recommender: Epoch 27 of 120. Elapsed time 15.13 min
# MF_MSE_PyTorch_Recommender: Epoch 28, Batch: [10000/11969], Samples per second 11558.50
# MF_MSE_PyTorch_Recommender: Epoch 28, Batch: [11969/11969], Samples per second 11567.74
# MF_MSE_PyTorch_Recommender: Epoch 28 of 120. Elapsed time 15.68 min
# MF_MSE_PyTorch_Recommender: Epoch 29, Batch: [10000/11969], Samples per second 11582.56
# MF_MSE_PyTorch_Recommender: Epoch 29, Batch: [11969/11969], Samples per second 11589.66
# MF_MSE_PyTorch_Recommender: Epoch 29 of 120. Elapsed time 16.23 min
# MF_MSE_PyTorch_Recommender: Epoch 30, Batch: [10000/11969], Samples per second 11602.65
# MF_MSE_PyTorch_Recommender: Epoch 30, Batch: [11969/11969], Samples per second 11602.85
# MF_MSE_PyTorch_Recommender: Validation begins...
# EvaluatorHoldout: Processed 10412 (100.0%) in 5.54 sec. Users per second: 1879
# MF_MSE_PyTorch_Recommender: CUTOFF: 10 - PRECISION: 0.0022090, PRECISION_RECALL_MIN_DEN: 0.0037997, RECALL: 0.0030183, MAP: 0.0007632, MAP_MIN_DEN: 0.0012623, MRR: 0.0074026, NDCG: 0.0031453, F1: 0.0025510, HIT_RATE: 0.0214176, ARHR_ALL_HITS: 0.0075173, NOVELTY: 0.0060084, AVERAGE_POPULARITY: 0.0660677, DIVERSITY_MEAN_INTER_LIST: 0.9891058, DIVERSITY_HERFINDAHL: 0.9989011, COVERAGE_ITEM: 0.5225902, COVERAGE_ITEM_HIT: 0.0074701, ITEMS_IN_GT: 0.8018630, COVERAGE_USER: 0.8238645, COVERAGE_USER_HIT: 0.0176452, USERS_IN_GT: 0.8238645, DIVERSITY_GINI: 0.1008014, SHANNON_ENTROPY: 10.9871002, RATIO_DIVERSITY_HERFINDAHL: 0.9992625, RATIO_DIVERSITY_GINI: 0.2891188, RATIO_SHANNON_ENTROPY: 0.8463737, RATIO_AVERAGE_POPULARITY: 0.5286326, RATIO_NOVELTY: 0.3394076,
#
# MF_MSE_PyTorch_Recommender: Epoch 30 of 120. Elapsed time 16.87 min
# MF_MSE_PyTorch_Recommender: Epoch 31, Batch: [10000/11969], Samples per second 11570.42
# MF_MSE_PyTorch_Recommender: Epoch 31, Batch: [11969/11969], Samples per second 11570.76
# MF_MSE_PyTorch_Recommender: Epoch 31 of 120. Elapsed time 17.42 min
# MF_MSE_PyTorch_Recommender: Epoch 32, Batch: [10000/11969], Samples per second 11553.74
# MF_MSE_PyTorch_Recommender: Epoch 32, Batch: [11969/11969], Samples per second 11551.32
# MF_MSE_PyTorch_Recommender: Epoch 32 of 120. Elapsed time 17.98 min
# MF_MSE_PyTorch_Recommender: Epoch 33, Batch: [10000/11969], Samples per second 11554.07
# MF_MSE_PyTorch_Recommender: Epoch 33, Batch: [11969/11969], Samples per second 11555.54
# MF_MSE_PyTorch_Recommender: Epoch 33 of 120. Elapsed time 18.53 min
# MF_MSE_PyTorch_Recommender: Epoch 34, Batch: [10000/11969], Samples per second 11534.44
# MF_MSE_PyTorch_Recommender: Epoch 34, Batch: [11969/11969], Samples per second 11535.60
# MF_MSE_PyTorch_Recommender: Epoch 34 of 120. Elapsed time 19.08 min
# MF_MSE_PyTorch_Recommender: Epoch 35, Batch: [10000/11969], Samples per second 11565.41
# MF_MSE_PyTorch_Recommender: Epoch 35, Batch: [11969/11969], Samples per second 11558.67
# MF_MSE_PyTorch_Recommender: Epoch 35 of 120. Elapsed time 19.64 min
# MF_MSE_PyTorch_Recommender: Epoch 36, Batch: [10000/11969], Samples per second 11522.98
# MF_MSE_PyTorch_Recommender: Epoch 36, Batch: [11969/11969], Samples per second 11531.99
# MF_MSE_PyTorch_Recommender: Epoch 36 of 120. Elapsed time 20.19 min
# MF_MSE_PyTorch_Recommender: Epoch 37, Batch: [10000/11969], Samples per second 11539.96
# MF_MSE_PyTorch_Recommender: Epoch 37, Batch: [11969/11969], Samples per second 11542.32
# MF_MSE_PyTorch_Recommender: Epoch 37 of 120. Elapsed time 20.74 min
# MF_MSE_PyTorch_Recommender: Epoch 38, Batch: [10000/11969], Samples per second 11545.99
# MF_MSE_PyTorch_Recommender: Epoch 38, Batch: [11969/11969], Samples per second 11541.48
# MF_MSE_PyTorch_Recommender: Epoch 38 of 120. Elapsed time 21.30 min
# MF_MSE_PyTorch_Recommender: Epoch 39, Batch: [10000/11969], Samples per second 11551.92
# MF_MSE_PyTorch_Recommender: Epoch 39, Batch: [11969/11969], Samples per second 11559.91
# MF_MSE_PyTorch_Recommender: Epoch 39 of 120. Elapsed time 21.85 min
# MF_MSE_PyTorch_Recommender: Epoch 40, Batch: [10000/11969], Samples per second 11569.98
# MF_MSE_PyTorch_Recommender: Epoch 40, Batch: [11969/11969], Samples per second 11574.74
# MF_MSE_PyTorch_Recommender: Validation begins...
# EvaluatorHoldout: Processed 10412 (100.0%) in 5.62 sec. Users per second: 1853
# MF_MSE_PyTorch_Recommender: CUTOFF: 10 - PRECISION: 0.0023146, PRECISION_RECALL_MIN_DEN: 0.0038797, RECALL: 0.0029818, MAP: 0.0007217, MAP_MIN_DEN: 0.0011845, MRR: 0.0070456, NDCG: 0.0030851, F1: 0.0026062, HIT_RATE: 0.0225701, ARHR_ALL_HITS: 0.0071313, NOVELTY: 0.0060157, AVERAGE_POPULARITY: 0.0646692, DIVERSITY_MEAN_INTER_LIST: 0.9891898, DIVERSITY_HERFINDAHL: 0.9989095, COVERAGE_ITEM: 0.5116101, COVERAGE_ITEM_HIT: 0.0074251, ITEMS_IN_GT: 0.8018630, COVERAGE_USER: 0.8238645, COVERAGE_USER_HIT: 0.0185947, USERS_IN_GT: 0.8238645, DIVERSITY_GINI: 0.0972884, SHANNON_ENTROPY: 10.9588660, RATIO_DIVERSITY_HERFINDAHL: 0.9992709, RATIO_DIVERSITY_GINI: 0.2790428, RATIO_SHANNON_ENTROPY: 0.8441987, RATIO_AVERAGE_POPULARITY: 0.5174425, RATIO_NOVELTY: 0.3398152,
#
# MF_MSE_PyTorch_Recommender: Epoch 40 of 120. Elapsed time 22.50 min
# MF_MSE_PyTorch_Recommender: Epoch 41, Batch: [10000/11969], Samples per second 11559.30
# MF_MSE_PyTorch_Recommender: Epoch 41, Batch: [11969/11969], Samples per second 11558.48
# MF_MSE_PyTorch_Recommender: Epoch 41 of 120. Elapsed time 23.05 min
# MF_MSE_PyTorch_Recommender: Epoch 42, Batch: [10000/11969], Samples per second 11537.20
# MF_MSE_PyTorch_Recommender: Epoch 42, Batch: [11969/11969], Samples per second 11537.65
# MF_MSE_PyTorch_Recommender: Epoch 42 of 120. Elapsed time 23.60 min
# MF_MSE_PyTorch_Recommender: Epoch 43, Batch: [10000/11969], Samples per second 11529.44
# MF_MSE_PyTorch_Recommender: Epoch 43, Batch: [11969/11969], Samples per second 11530.99
# MF_MSE_PyTorch_Recommender: Epoch 43 of 120. Elapsed time 24.16 min
# MF_MSE_PyTorch_Recommender: Epoch 44, Batch: [10000/11969], Samples per second 11530.80
# MF_MSE_PyTorch_Recommender: Epoch 44, Batch: [11969/11969], Samples per second 11537.04
# MF_MSE_PyTorch_Recommender: Epoch 44 of 120. Elapsed time 24.71 min
# MF_MSE_PyTorch_Recommender: Epoch 45, Batch: [10000/11969], Samples per second 11525.01
# MF_MSE_PyTorch_Recommender: Epoch 45, Batch: [11969/11969], Samples per second 11531.24
# MF_MSE_PyTorch_Recommender: Epoch 45 of 120. Elapsed time 25.26 min
# MF_MSE_PyTorch_Recommender: Epoch 46, Batch: [10000/11969], Samples per second 11547.46
# MF_MSE_PyTorch_Recommender: Epoch 46, Batch: [11969/11969], Samples per second 11551.95
# MF_MSE_PyTorch_Recommender: Epoch 46 of 120. Elapsed time 25.82 min
# MF_MSE_PyTorch_Recommender: Epoch 47, Batch: [10000/11969], Samples per second 11554.85
# MF_MSE_PyTorch_Recommender: Epoch 47, Batch: [11969/11969], Samples per second 11563.43
# MF_MSE_PyTorch_Recommender: Epoch 47 of 120. Elapsed time 26.37 min
# MF_MSE_PyTorch_Recommender: Epoch 48, Batch: [10000/11969], Samples per second 11564.31
# MF_MSE_PyTorch_Recommender: Epoch 48, Batch: [11969/11969], Samples per second 11565.06
# MF_MSE_PyTorch_Recommender: Epoch 48 of 120. Elapsed time 26.92 min
# MF_MSE_PyTorch_Recommender: Epoch 49, Batch: [10000/11969], Samples per second 11526.03
# MF_MSE_PyTorch_Recommender: Epoch 49, Batch: [11969/11969], Samples per second 11527.91
# MF_MSE_PyTorch_Recommender: Epoch 49 of 120. Elapsed time 27.48 min
# MF_MSE_PyTorch_Recommender: Epoch 50, Batch: [10000/11969], Samples per second 11569.86
# MF_MSE_PyTorch_Recommender: Epoch 50, Batch: [11969/11969], Samples per second 11566.80
# MF_MSE_PyTorch_Recommender: Validation begins...
# EvaluatorHoldout: Processed 10412 (100.0%) in 5.51 sec. Users per second: 1891
# MF_MSE_PyTorch_Recommender: CUTOFF: 10 - PRECISION: 0.0023242, PRECISION_RECALL_MIN_DEN: 0.0038893, RECALL: 0.0029825, MAP: 0.0007245, MAP_MIN_DEN: 0.0011874, MRR: 0.0070738, NDCG: 0.0030949, F1: 0.0026126, HIT_RATE: 0.0226662, ARHR_ALL_HITS: 0.0071596, NOVELTY: 0.0060163, AVERAGE_POPULARITY: 0.0646262, DIVERSITY_MEAN_INTER_LIST: 0.9891952, DIVERSITY_HERFINDAHL: 0.9989100, COVERAGE_ITEM: 0.5117901, COVERAGE_ITEM_HIT: 0.0074251, ITEMS_IN_GT: 0.8018630, COVERAGE_USER: 0.8238645, COVERAGE_USER_HIT: 0.0186738, USERS_IN_GT: 0.8238645, DIVERSITY_GINI: 0.0973968, SHANNON_ENTROPY: 10.9604658, RATIO_DIVERSITY_HERFINDAHL: 0.9992714, RATIO_DIVERSITY_GINI: 0.2793537, RATIO_SHANNON_ENTROPY: 0.8443220, RATIO_AVERAGE_POPULARITY: 0.5170990, RATIO_NOVELTY: 0.3398541,
#
# MF_MSE_PyTorch_Recommender: Epoch 50 of 120. Elapsed time 28.12 min
# MF_MSE_PyTorch_Recommender: Epoch 51, Batch: [10000/11969], Samples per second 11543.97
# MF_MSE_PyTorch_Recommender: Epoch 51, Batch: [11969/11969], Samples per second 11544.98
# MF_MSE_PyTorch_Recommender: Epoch 51 of 120. Elapsed time 28.67 min
# MF_MSE_PyTorch_Recommender: Epoch 52, Batch: [10000/11969], Samples per second 11535.24
# MF_MSE_PyTorch_Recommender: Epoch 52, Batch: [11969/11969], Samples per second 11543.21
# MF_MSE_PyTorch_Recommender: Epoch 52 of 120. Elapsed time 29.23 min
# MF_MSE_PyTorch_Recommender: Epoch 53, Batch: [10000/11969], Samples per second 11516.83
# MF_MSE_PyTorch_Recommender: Epoch 53, Batch: [11969/11969], Samples per second 11526.38
# MF_MSE_PyTorch_Recommender: Epoch 53 of 120. Elapsed time 29.78 min
# MF_MSE_PyTorch_Recommender: Epoch 54, Batch: [10000/11969], Samples per second 11532.11
# MF_MSE_PyTorch_Recommender: Epoch 54, Batch: [11969/11969], Samples per second 11534.39
# MF_MSE_PyTorch_Recommender: Epoch 54 of 120. Elapsed time 30.34 min
# MF_MSE_PyTorch_Recommender: Epoch 55, Batch: [10000/11969], Samples per second 11540.31
# MF_MSE_PyTorch_Recommender: Epoch 55, Batch: [11969/11969], Samples per second 11540.01
# MF_MSE_PyTorch_Recommender: Epoch 55 of 120. Elapsed time 30.89 min
# MF_MSE_PyTorch_Recommender: Epoch 56, Batch: [10000/11969], Samples per second 11544.01
# MF_MSE_PyTorch_Recommender: Epoch 56, Batch: [11969/11969], Samples per second 11547.39
# MF_MSE_PyTorch_Recommender: Epoch 56 of 120. Elapsed time 31.44 min
# MF_MSE_PyTorch_Recommender: Epoch 57, Batch: [10000/11969], Samples per second 11493.29
# MF_MSE_PyTorch_Recommender: Epoch 57, Batch: [11969/11969], Samples per second 11494.20
# MF_MSE_PyTorch_Recommender: Epoch 57 of 120. Elapsed time 32.00 min
# MF_MSE_PyTorch_Recommender: Epoch 58, Batch: [10000/11969], Samples per second 11580.52
# MF_MSE_PyTorch_Recommender: Epoch 58, Batch: [11969/11969], Samples per second 11579.18
# MF_MSE_PyTorch_Recommender: Epoch 58 of 120. Elapsed time 32.55 min
# MF_MSE_PyTorch_Recommender: Epoch 59, Batch: [10000/11969], Samples per second 11544.80
# MF_MSE_PyTorch_Recommender: Epoch 59, Batch: [11969/11969], Samples per second 11541.46
# MF_MSE_PyTorch_Recommender: Epoch 59 of 120. Elapsed time 33.10 min
# MF_MSE_PyTorch_Recommender: Epoch 60, Batch: [10000/11969], Samples per second 11578.20
# MF_MSE_PyTorch_Recommender: Epoch 60, Batch: [11969/11969], Samples per second 11577.38
# MF_MSE_PyTorch_Recommender: Validation begins...
# EvaluatorHoldout: Processed 10412 (100.0%) in 5.64 sec. Users per second: 1845
# MF_MSE_PyTorch_Recommender: CUTOFF: 10 - PRECISION: 0.0023242, PRECISION_RECALL_MIN_DEN: 0.0038893, RECALL: 0.0029825, MAP: 0.0007245, MAP_MIN_DEN: 0.0011874, MRR: 0.0070738, NDCG: 0.0030949, F1: 0.0026126, HIT_RATE: 0.0226662, ARHR_ALL_HITS: 0.0071596, NOVELTY: 0.0060163, AVERAGE_POPULARITY: 0.0646262, DIVERSITY_MEAN_INTER_LIST: 0.9891952, DIVERSITY_HERFINDAHL: 0.9989100, COVERAGE_ITEM: 0.5117901, COVERAGE_ITEM_HIT: 0.0074251, ITEMS_IN_GT: 0.8018630, COVERAGE_USER: 0.8238645, COVERAGE_USER_HIT: 0.0186738, USERS_IN_GT: 0.8238645, DIVERSITY_GINI: 0.0973968, SHANNON_ENTROPY: 10.9604658, RATIO_DIVERSITY_HERFINDAHL: 0.9992714, RATIO_DIVERSITY_GINI: 0.2793537, RATIO_SHANNON_ENTROPY: 0.8443220, RATIO_AVERAGE_POPULARITY: 0.5170990, RATIO_NOVELTY: 0.3398541,
#
# MF_MSE_PyTorch_Recommender: Convergence reached! Terminating at epoch 60. Best value for 'MAP' at epoch 10 is 0.0009. Elapsed time 33.75 min
# MF_MSE_PyTorch_Recommender: Epoch 60 of 120. Elapsed time 33.75 min
# [I 2024-01-09 00:31:30,558] Trial 19 finished with value: 0.0014954803455651824 and parameters: {'epochs': 120, 'batch_size': 32, 'num_factors': 196, 'learning_rate': 0.9607395094689677}. Best is trial 19 with value: 0.0014954803455651824.
# MF_MSE_PyTorch_Recommender: URM Detected 197 ( 1.6%) users with no interactions.
# MF_MSE_PyTorch_Recommender: URM Detected 115 ( 0.5%) items with no interactions.
# MF_MSE_PyTorch_Recommender: MF_MSE_PyTorch: Using CUDA
# /home/kinami/.conda/envs/RecSysFramework/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# MF_MSE_PyTorch_Recommender: Epoch 1, Batch: [10000/11969], Samples per second 10868.59
# MF_MSE_PyTorch_Recommender: Epoch 1, Batch: [11969/11969], Samples per second 10866.75
# MF_MSE_PyTorch_Recommender: Epoch 1 of 67. Elapsed time 35.28 sec
# MF_MSE_PyTorch_Recommender: Epoch 2, Batch: [10000/11969], Samples per second 10862.99
# MF_MSE_PyTorch_Recommender: Epoch 2, Batch: [11969/11969], Samples per second 10869.73
# MF_MSE_PyTorch_Recommender: Epoch 2 of 67. Elapsed time 1.18 min
# MF_MSE_PyTorch_Recommender: Epoch 3, Batch: [10000/11969], Samples per second 10875.00
# MF_MSE_PyTorch_Recommender: Epoch 3, Batch: [11969/11969], Samples per second 10864.99
# MF_MSE_PyTorch_Recommender: Epoch 3 of 67. Elapsed time 1.76 min
# MF_MSE_PyTorch_Recommender: Epoch 4, Batch: [10000/11969], Samples per second 10895.35
# MF_MSE_PyTorch_Recommender: Epoch 4, Batch: [11969/11969], Samples per second 10892.77
# MF_MSE_PyTorch_Recommender: Epoch 4 of 67. Elapsed time 2.35 min
# MF_MSE_PyTorch_Recommender: Epoch 5, Batch: [10000/11969], Samples per second 10881.36
# MF_MSE_PyTorch_Recommender: Epoch 5, Batch: [11969/11969], Samples per second 10871.50
# MF_MSE_PyTorch_Recommender: Epoch 5 of 67. Elapsed time 2.94 min
# MF_MSE_PyTorch_Recommender: Epoch 6, Batch: [10000/11969], Samples per second 10905.43
# MF_MSE_PyTorch_Recommender: Epoch 6, Batch: [11969/11969], Samples per second 10869.93
# MF_MSE_PyTorch_Recommender: Epoch 6 of 67. Elapsed time 3.53 min
# MF_MSE_PyTorch_Recommender: Epoch 7, Batch: [10000/11969], Samples per second 10841.01
# MF_MSE_PyTorch_Recommender: Epoch 7, Batch: [11969/11969], Samples per second 10844.20
# MF_MSE_PyTorch_Recommender: Epoch 7 of 67. Elapsed time 4.11 min
# MF_MSE_PyTorch_Recommender: Epoch 8, Batch: [10000/11969], Samples per second 10885.29
# MF_MSE_PyTorch_Recommender: Epoch 8, Batch: [11969/11969], Samples per second 10889.61
# MF_MSE_PyTorch_Recommender: Epoch 8 of 67. Elapsed time 4.70 min
# MF_MSE_PyTorch_Recommender: Epoch 9, Batch: [10000/11969], Samples per second 10868.45
# MF_MSE_PyTorch_Recommender: Epoch 9, Batch: [11969/11969], Samples per second 10872.93
# MF_MSE_PyTorch_Recommender: Epoch 9 of 67. Elapsed time 5.29 min
# MF_MSE_PyTorch_Recommender: Epoch 10, Batch: [10000/11969], Samples per second 10833.67
# MF_MSE_PyTorch_Recommender: Epoch 10, Batch: [11969/11969], Samples per second 10834.74
# MF_MSE_PyTorch_Recommender: Validation begins...
# EvaluatorHoldout: Processed 10412 (100.0%) in 5.74 sec. Users per second: 1814
# MF_MSE_PyTorch_Recommender: CUTOFF: 10 - PRECISION: 0.0003938, PRECISION_RECALL_MIN_DEN: 0.0005633, RECALL: 0.0003873, MAP: 0.0001195, MAP_MIN_DEN: 0.0001507, MRR: 0.0011949, NDCG: 0.0004641, F1: 0.0003905, HIT_RATE: 0.0039378, ARHR_ALL_HITS: 0.0011949, NOVELTY: 0.0069575, AVERAGE_POPULARITY: 0.0123173, DIVERSITY_MEAN_INTER_LIST: 0.9993764, DIVERSITY_HERFINDAHL: 0.9999280, COVERAGE_ITEM: 0.9423544, COVERAGE_ITEM_HIT: 0.0018450, ITEMS_IN_GT: 0.8018630, COVERAGE_USER: 0.8238645, COVERAGE_USER_HIT: 0.0032442, USERS_IN_GT: 0.8238645, DIVERSITY_GINI: 0.5912320, SHANNON_ENTROPY: 14.0261561, RATIO_DIVERSITY_HERFINDAHL: 1.0002898, RATIO_DIVERSITY_GINI: 1.6957727, RATIO_SHANNON_ENTROPY: 1.0804825, RATIO_AVERAGE_POPULARITY: 0.0985552, RATIO_NOVELTY: 0.3930171,
#
# MF_MSE_PyTorch_Recommender: New best model found! Updating.
# MF_MSE_PyTorch_Recommender: Epoch 10 of 67. Elapsed time 5.97 min
# MF_MSE_PyTorch_Recommender: Epoch 11, Batch: [10000/11969], Samples per second 10870.10
# MF_MSE_PyTorch_Recommender: Epoch 11, Batch: [11969/11969], Samples per second 10870.19
# MF_MSE_PyTorch_Recommender: Epoch 11 of 67. Elapsed time 6.56 min
# MF_MSE_PyTorch_Recommender: Epoch 12, Batch: [10000/11969], Samples per second 10903.12
# MF_MSE_PyTorch_Recommender: Epoch 12, Batch: [11969/11969], Samples per second 10905.46
# MF_MSE_PyTorch_Recommender: Epoch 12 of 67. Elapsed time 7.15 min
# MF_MSE_PyTorch_Recommender: Epoch 13, Batch: [10000/11969], Samples per second 10842.16
# MF_MSE_PyTorch_Recommender: Epoch 13, Batch: [11969/11969], Samples per second 10844.82
# MF_MSE_PyTorch_Recommender: Epoch 13 of 67. Elapsed time 7.74 min
# MF_MSE_PyTorch_Recommender: Epoch 14, Batch: [10000/11969], Samples per second 10852.78
# MF_MSE_PyTorch_Recommender: Epoch 14, Batch: [11969/11969], Samples per second 10857.31
# MF_MSE_PyTorch_Recommender: Epoch 14 of 67. Elapsed time 8.33 min
# MF_MSE_PyTorch_Recommender: Epoch 15, Batch: [10000/11969], Samples per second 10806.79
# MF_MSE_PyTorch_Recommender: Epoch 15, Batch: [11969/11969], Samples per second 10797.58
# MF_MSE_PyTorch_Recommender: Epoch 15 of 67. Elapsed time 8.92 min
# MF_MSE_PyTorch_Recommender: Epoch 16, Batch: [10000/11969], Samples per second 10864.20
# MF_MSE_PyTorch_Recommender: Epoch 16, Batch: [11969/11969], Samples per second 10868.82
# MF_MSE_PyTorch_Recommender: Epoch 16 of 67. Elapsed time 9.51 min
# MF_MSE_PyTorch_Recommender: Epoch 17, Batch: [10000/11969], Samples per second 10837.49
# MF_MSE_PyTorch_Recommender: Epoch 17, Batch: [11969/11969], Samples per second 10829.16
# MF_MSE_PyTorch_Recommender: Epoch 17 of 67. Elapsed time 10.09 min
# MF_MSE_PyTorch_Recommender: Epoch 18, Batch: [10000/11969], Samples per second 10880.90
# MF_MSE_PyTorch_Recommender: Epoch 18, Batch: [11969/11969], Samples per second 10864.25
# MF_MSE_PyTorch_Recommender: Epoch 18 of 67. Elapsed time 10.68 min
# MF_MSE_PyTorch_Recommender: Epoch 19, Batch: [10000/11969], Samples per second 10841.64
# MF_MSE_PyTorch_Recommender: Epoch 19, Batch: [11969/11969], Samples per second 10837.46
# MF_MSE_PyTorch_Recommender: Epoch 19 of 67. Elapsed time 11.27 min
# MF_MSE_PyTorch_Recommender: Epoch 20, Batch: [10000/11969], Samples per second 10896.18
# MF_MSE_PyTorch_Recommender: Epoch 20, Batch: [11969/11969], Samples per second 10902.03
# MF_MSE_PyTorch_Recommender: Validation begins...
# EvaluatorHoldout: Processed 10412 (100.0%) in 5.69 sec. Users per second: 1829
# MF_MSE_PyTorch_Recommender: CUTOFF: 10 - PRECISION: 0.0003938, PRECISION_RECALL_MIN_DEN: 0.0005633, RECALL: 0.0003873, MAP: 0.0001195, MAP_MIN_DEN: 0.0001507, MRR: 0.0011949, NDCG: 0.0004641, F1: 0.0003905, HIT_RATE: 0.0039378, ARHR_ALL_HITS: 0.0011949, NOVELTY: 0.0069578, AVERAGE_POPULARITY: 0.0122988, DIVERSITY_MEAN_INTER_LIST: 0.9993761, DIVERSITY_HERFINDAHL: 0.9999280, COVERAGE_ITEM: 0.9421294, COVERAGE_ITEM_HIT: 0.0018450, ITEMS_IN_GT: 0.8018630, COVERAGE_USER: 0.8238645, COVERAGE_USER_HIT: 0.0032442, USERS_IN_GT: 0.8238645, DIVERSITY_GINI: 0.5910352, SHANNON_ENTROPY: 14.0257105, RATIO_DIVERSITY_HERFINDAHL: 1.0002898, RATIO_DIVERSITY_GINI: 1.6952080, RATIO_SHANNON_ENTROPY: 1.0804482, RATIO_AVERAGE_POPULARITY: 0.0984071, RATIO_NOVELTY: 0.3930380,
#
# MF_MSE_PyTorch_Recommender: Epoch 20 of 67. Elapsed time 11.95 min
# MF_MSE_PyTorch_Recommender: Epoch 21, Batch: [10000/11969], Samples per second 10841.02
# MF_MSE_PyTorch_Recommender: Epoch 21, Batch: [11969/11969], Samples per second 10841.80
# MF_MSE_PyTorch_Recommender: Epoch 21 of 67. Elapsed time 12.54 min
# MF_MSE_PyTorch_Recommender: Epoch 22, Batch: [10000/11969], Samples per second 10790.95
# MF_MSE_PyTorch_Recommender: Epoch 22, Batch: [11969/11969], Samples per second 10795.34
# MF_MSE_PyTorch_Recommender: Epoch 22 of 67. Elapsed time 13.13 min
# MF_MSE_PyTorch_Recommender: Epoch 23, Batch: [10000/11969], Samples per second 10850.73
# MF_MSE_PyTorch_Recommender: Epoch 23, Batch: [11969/11969], Samples per second 10853.04
# MF_MSE_PyTorch_Recommender: Epoch 23 of 67. Elapsed time 13.72 min
# MF_MSE_PyTorch_Recommender: Epoch 24, Batch: [10000/11969], Samples per second 10852.99
# MF_MSE_PyTorch_Recommender: Epoch 24, Batch: [11969/11969], Samples per second 10862.56
# MF_MSE_PyTorch_Recommender: Epoch 24 of 67. Elapsed time 14.31 min
# MF_MSE_PyTorch_Recommender: Epoch 25, Batch: [10000/11969], Samples per second 10894.30
# MF_MSE_PyTorch_Recommender: Epoch 25, Batch: [11969/11969], Samples per second 10884.31
# MF_MSE_PyTorch_Recommender: Epoch 25 of 67. Elapsed time 14.90 min
# MF_MSE_PyTorch_Recommender: Epoch 26, Batch: [10000/11969], Samples per second 10870.63
# MF_MSE_PyTorch_Recommender: Epoch 26, Batch: [11969/11969], Samples per second 10872.12
# MF_MSE_PyTorch_Recommender: Epoch 26 of 67. Elapsed time 15.49 min
# MF_MSE_PyTorch_Recommender: Epoch 27, Batch: [10000/11969], Samples per second 10843.07
# MF_MSE_PyTorch_Recommender: Epoch 27, Batch: [11969/11969], Samples per second 10839.45
# MF_MSE_PyTorch_Recommender: Epoch 27 of 67. Elapsed time 16.08 min
# MF_MSE_PyTorch_Recommender: Epoch 28, Batch: [10000/11969], Samples per second 10867.73
# MF_MSE_PyTorch_Recommender: Epoch 28, Batch: [11969/11969], Samples per second 10866.99
# MF_MSE_PyTorch_Recommender: Epoch 28 of 67. Elapsed time 16.66 min
# MF_MSE_PyTorch_Recommender: Epoch 29, Batch: [10000/11969], Samples per second 10875.28
# MF_MSE_PyTorch_Recommender: Epoch 29, Batch: [11969/11969], Samples per second 10880.68
# MF_MSE_PyTorch_Recommender: Epoch 29 of 67. Elapsed time 17.25 min
# MF_MSE_PyTorch_Recommender: Epoch 30, Batch: [10000/11969], Samples per second 10894.71
# MF_MSE_PyTorch_Recommender: Epoch 30, Batch: [11969/11969], Samples per second 10893.99
# MF_MSE_PyTorch_Recommender: Validation begins...
# EvaluatorHoldout: Processed 10412 (100.0%) in 5.70 sec. Users per second: 1827
# MF_MSE_PyTorch_Recommender: CUTOFF: 10 - PRECISION: 0.0003938, PRECISION_RECALL_MIN_DEN: 0.0005633, RECALL: 0.0003873, MAP: 0.0001195, MAP_MIN_DEN: 0.0001507, MRR: 0.0011949, NDCG: 0.0004641, F1: 0.0003905, HIT_RATE: 0.0039378, ARHR_ALL_HITS: 0.0011949, NOVELTY: 0.0069578, AVERAGE_POPULARITY: 0.0122991, DIVERSITY_MEAN_INTER_LIST: 0.9993760, DIVERSITY_HERFINDAHL: 0.9999280, COVERAGE_ITEM: 0.9421294, COVERAGE_ITEM_HIT: 0.0018450, ITEMS_IN_GT: 0.8018630, COVERAGE_USER: 0.8238645, COVERAGE_USER_HIT: 0.0032442, USERS_IN_GT: 0.8238645, DIVERSITY_GINI: 0.5909678, SHANNON_ENTROPY: 14.0255783, RATIO_DIVERSITY_HERFINDAHL: 1.0002898, RATIO_DIVERSITY_GINI: 1.6950147, RATIO_SHANNON_ENTROPY: 1.0804380, RATIO_AVERAGE_POPULARITY: 0.0984097, RATIO_NOVELTY: 0.3930365,
#
# MF_MSE_PyTorch_Recommender: Epoch 30 of 67. Elapsed time 17.93 min
# MF_MSE_PyTorch_Recommender: Epoch 31, Batch: [10000/11969], Samples per second 10870.06
# MF_MSE_PyTorch_Recommender: Epoch 31, Batch: [11969/11969], Samples per second 10879.32
# MF_MSE_PyTorch_Recommender: Epoch 31 of 67. Elapsed time 18.52 min
# MF_MSE_PyTorch_Recommender: Epoch 32, Batch: [10000/11969], Samples per second 10873.29
# MF_MSE_PyTorch_Recommender: Epoch 32, Batch: [11969/11969], Samples per second 10871.11
# MF_MSE_PyTorch_Recommender: Epoch 32 of 67. Elapsed time 19.11 min
# MF_MSE_PyTorch_Recommender: Epoch 33, Batch: [10000/11969], Samples per second 10858.26
# MF_MSE_PyTorch_Recommender: Epoch 33, Batch: [11969/11969], Samples per second 10855.93
# MF_MSE_PyTorch_Recommender: Epoch 33 of 67. Elapsed time 19.70 min
# MF_MSE_PyTorch_Recommender: Epoch 34, Batch: [10000/11969], Samples per second 10841.05
# MF_MSE_PyTorch_Recommender: Epoch 34, Batch: [11969/11969], Samples per second 10835.22
# MF_MSE_PyTorch_Recommender: Epoch 34 of 67. Elapsed time 20.29 min
# MF_MSE_PyTorch_Recommender: Epoch 35, Batch: [10000/11969], Samples per second 10861.91
# MF_MSE_PyTorch_Recommender: Epoch 35, Batch: [11969/11969], Samples per second 10857.96
# MF_MSE_PyTorch_Recommender: Epoch 35 of 67. Elapsed time 20.87 min
# MF_MSE_PyTorch_Recommender: Epoch 36, Batch: [10000/11969], Samples per second 10849.76
# MF_MSE_PyTorch_Recommender: Epoch 36, Batch: [11969/11969], Samples per second 10847.69
# MF_MSE_PyTorch_Recommender: Epoch 36 of 67. Elapsed time 21.46 min
# MF_MSE_PyTorch_Recommender: Epoch 37, Batch: [10000/11969], Samples per second 10877.44
# MF_MSE_PyTorch_Recommender: Epoch 37, Batch: [11969/11969], Samples per second 10880.39
# MF_MSE_PyTorch_Recommender: Epoch 37 of 67. Elapsed time 22.05 min
# MF_MSE_PyTorch_Recommender: Epoch 38, Batch: [10000/11969], Samples per second 10831.25
# MF_MSE_PyTorch_Recommender: Epoch 38, Batch: [11969/11969], Samples per second 10835.31
# MF_MSE_PyTorch_Recommender: Epoch 38 of 67. Elapsed time 22.64 min
# MF_MSE_PyTorch_Recommender: Epoch 39, Batch: [10000/11969], Samples per second 10817.89
# MF_MSE_PyTorch_Recommender: Epoch 39, Batch: [11969/11969], Samples per second 10823.09
# MF_MSE_PyTorch_Recommender: Epoch 39 of 67. Elapsed time 23.23 min
# MF_MSE_PyTorch_Recommender: Epoch 40, Batch: [10000/11969], Samples per second 10836.78
# MF_MSE_PyTorch_Recommender: Epoch 40, Batch: [11969/11969], Samples per second 10837.15
# MF_MSE_PyTorch_Recommender: Validation begins...
# EvaluatorHoldout: Processed 10412 (100.0%) in 5.72 sec. Users per second: 1819
# MF_MSE_PyTorch_Recommender: CUTOFF: 10 - PRECISION: 0.0003938, PRECISION_RECALL_MIN_DEN: 0.0005633, RECALL: 0.0003873, MAP: 0.0001195, MAP_MIN_DEN: 0.0001507, MRR: 0.0011949, NDCG: 0.0004641, F1: 0.0003905, HIT_RATE: 0.0039378, ARHR_ALL_HITS: 0.0011949, NOVELTY: 0.0069578, AVERAGE_POPULARITY: 0.0122977, DIVERSITY_MEAN_INTER_LIST: 0.9993760, DIVERSITY_HERFINDAHL: 0.9999280, COVERAGE_ITEM: 0.9421294, COVERAGE_ITEM_HIT: 0.0018450, ITEMS_IN_GT: 0.8018630, COVERAGE_USER: 0.8238645, COVERAGE_USER_HIT: 0.0032442, USERS_IN_GT: 0.8238645, DIVERSITY_GINI: 0.5909776, SHANNON_ENTROPY: 14.0255946, RATIO_DIVERSITY_HERFINDAHL: 1.0002898, RATIO_DIVERSITY_GINI: 1.6950428, RATIO_SHANNON_ENTROPY: 1.0804393, RATIO_AVERAGE_POPULARITY: 0.0983984, RATIO_NOVELTY: 0.3930377,
#
# MF_MSE_PyTorch_Recommender: Epoch 40 of 67. Elapsed time 23.92 min
# MF_MSE_PyTorch_Recommender: Epoch 41, Batch: [10000/11969], Samples per second 10872.66
# MF_MSE_PyTorch_Recommender: Epoch 41, Batch: [11969/11969], Samples per second 10870.96
# MF_MSE_PyTorch_Recommender: Epoch 41 of 67. Elapsed time 24.50 min
# MF_MSE_PyTorch_Recommender: Epoch 42, Batch: [10000/11969], Samples per second 10850.89
# MF_MSE_PyTorch_Recommender: Epoch 42, Batch: [11969/11969], Samples per second 10846.10
# MF_MSE_PyTorch_Recommender: Epoch 42 of 67. Elapsed time 25.09 min
# MF_MSE_PyTorch_Recommender: Epoch 43, Batch: [10000/11969], Samples per second 10882.84
# MF_MSE_PyTorch_Recommender: Epoch 43, Batch: [11969/11969], Samples per second 10880.12
# MF_MSE_PyTorch_Recommender: Epoch 43 of 67. Elapsed time 25.68 min
# MF_MSE_PyTorch_Recommender: Epoch 44, Batch: [10000/11969], Samples per second 10853.56
# MF_MSE_PyTorch_Recommender: Epoch 44, Batch: [11969/11969], Samples per second 10855.02
# MF_MSE_PyTorch_Recommender: Epoch 44 of 67. Elapsed time 26.27 min
# MF_MSE_PyTorch_Recommender: Epoch 45, Batch: [10000/11969], Samples per second 10846.69
# MF_MSE_PyTorch_Recommender: Epoch 45, Batch: [11969/11969], Samples per second 10837.72
# MF_MSE_PyTorch_Recommender: Epoch 45 of 67. Elapsed time 26.86 min
# MF_MSE_PyTorch_Recommender: Epoch 46, Batch: [10000/11969], Samples per second 10867.76
# MF_MSE_PyTorch_Recommender: Epoch 46, Batch: [11969/11969], Samples per second 10867.24
# MF_MSE_PyTorch_Recommender: Epoch 46 of 67. Elapsed time 27.44 min
# MF_MSE_PyTorch_Recommender: Epoch 47, Batch: [10000/11969], Samples per second 10876.95
# MF_MSE_PyTorch_Recommender: Epoch 47, Batch: [11969/11969], Samples per second 10876.08
# MF_MSE_PyTorch_Recommender: Epoch 47 of 67. Elapsed time 28.03 min
# MF_MSE_PyTorch_Recommender: Epoch 48, Batch: [10000/11969], Samples per second 10873.76
# MF_MSE_PyTorch_Recommender: Epoch 48, Batch: [11969/11969], Samples per second 10879.65
# MF_MSE_PyTorch_Recommender: Epoch 48 of 67. Elapsed time 28.62 min
# MF_MSE_PyTorch_Recommender: Epoch 49, Batch: [10000/11969], Samples per second 10861.85
# MF_MSE_PyTorch_Recommender: Epoch 49, Batch: [11969/11969], Samples per second 10867.02
# MF_MSE_PyTorch_Recommender: Epoch 49 of 67. Elapsed time 29.21 min
# MF_MSE_PyTorch_Recommender: Epoch 50, Batch: [10000/11969], Samples per second 10863.67
# MF_MSE_PyTorch_Recommender: Epoch 50, Batch: [11969/11969], Samples per second 10866.12
# MF_MSE_PyTorch_Recommender: Validation begins...
# EvaluatorHoldout: Processed 10412 (100.0%) in 5.70 sec. Users per second: 1826
# MF_MSE_PyTorch_Recommender: CUTOFF: 10 - PRECISION: 0.0003938, PRECISION_RECALL_MIN_DEN: 0.0005633, RECALL: 0.0003873, MAP: 0.0001195, MAP_MIN_DEN: 0.0001507, MRR: 0.0011949, NDCG: 0.0004641, F1: 0.0003905, HIT_RATE: 0.0039378, ARHR_ALL_HITS: 0.0011949, NOVELTY: 0.0069578, AVERAGE_POPULARITY: 0.0122979, DIVERSITY_MEAN_INTER_LIST: 0.9993760, DIVERSITY_HERFINDAHL: 0.9999280, COVERAGE_ITEM: 0.9421294, COVERAGE_ITEM_HIT: 0.0018450, ITEMS_IN_GT: 0.8018630, COVERAGE_USER: 0.8238645, COVERAGE_USER_HIT: 0.0032442, USERS_IN_GT: 0.8238645, DIVERSITY_GINI: 0.5909750, SHANNON_ENTROPY: 14.0255939, RATIO_DIVERSITY_HERFINDAHL: 1.0002898, RATIO_DIVERSITY_GINI: 1.6950355, RATIO_SHANNON_ENTROPY: 1.0804392, RATIO_AVERAGE_POPULARITY: 0.0984000, RATIO_NOVELTY: 0.3930371,
#
# MF_MSE_PyTorch_Recommender: Epoch 50 of 67. Elapsed time 29.89 min
# MF_MSE_PyTorch_Recommender: Epoch 51, Batch: [10000/11969], Samples per second 10819.60
# MF_MSE_PyTorch_Recommender: Epoch 51, Batch: [11969/11969], Samples per second 10816.74
# MF_MSE_PyTorch_Recommender: Epoch 51 of 67. Elapsed time 30.48 min
# MF_MSE_PyTorch_Recommender: Epoch 52, Batch: [10000/11969], Samples per second 10879.30
# MF_MSE_PyTorch_Recommender: Epoch 52, Batch: [11969/11969], Samples per second 10888.08
# MF_MSE_PyTorch_Recommender: Epoch 52 of 67. Elapsed time 31.07 min
# MF_MSE_PyTorch_Recommender: Epoch 53, Batch: [10000/11969], Samples per second 10857.44
# MF_MSE_PyTorch_Recommender: Epoch 53, Batch: [11969/11969], Samples per second 10858.27
# MF_MSE_PyTorch_Recommender: Epoch 53 of 67. Elapsed time 31.66 min
# MF_MSE_PyTorch_Recommender: Epoch 54, Batch: [10000/11969], Samples per second 10868.64
# MF_MSE_PyTorch_Recommender: Epoch 54, Batch: [11969/11969], Samples per second 10868.09
# MF_MSE_PyTorch_Recommender: Epoch 54 of 67. Elapsed time 32.24 min
# MF_MSE_PyTorch_Recommender: Epoch 55, Batch: [10000/11969], Samples per second 10844.00
# MF_MSE_PyTorch_Recommender: Epoch 55, Batch: [11969/11969], Samples per second 10848.72
# MF_MSE_PyTorch_Recommender: Epoch 55 of 67. Elapsed time 32.83 min
# MF_MSE_PyTorch_Recommender: Epoch 56, Batch: [10000/11969], Samples per second 10857.56
# MF_MSE_PyTorch_Recommender: Epoch 56, Batch: [11969/11969], Samples per second 10857.80
# MF_MSE_PyTorch_Recommender: Epoch 56 of 67. Elapsed time 33.42 min
# MF_MSE_PyTorch_Recommender: Epoch 57, Batch: [10000/11969], Samples per second 10834.01
# MF_MSE_PyTorch_Recommender: Epoch 57, Batch: [11969/11969], Samples per second 10837.05
# MF_MSE_PyTorch_Recommender: Epoch 57 of 67. Elapsed time 34.01 min
# MF_MSE_PyTorch_Recommender: Epoch 58, Batch: [10000/11969], Samples per second 10895.97
# MF_MSE_PyTorch_Recommender: Epoch 58, Batch: [11969/11969], Samples per second 10890.48
# MF_MSE_PyTorch_Recommender: Epoch 58 of 67. Elapsed time 34.60 min
# MF_MSE_PyTorch_Recommender: Epoch 59, Batch: [10000/11969], Samples per second 10863.21
# MF_MSE_PyTorch_Recommender: Epoch 59, Batch: [11969/11969], Samples per second 10865.74
# MF_MSE_PyTorch_Recommender: Epoch 59 of 67. Elapsed time 35.19 min
# MF_MSE_PyTorch_Recommender: Epoch 60, Batch: [10000/11969], Samples per second 10845.53
# MF_MSE_PyTorch_Recommender: Epoch 60, Batch: [11969/11969], Samples per second 10849.23
# MF_MSE_PyTorch_Recommender: Validation begins...
# EvaluatorHoldout: Processed 10412 (100.0%) in 5.70 sec. Users per second: 1828
# MF_MSE_PyTorch_Recommender: CUTOFF: 10 - PRECISION: 0.0003938, PRECISION_RECALL_MIN_DEN: 0.0005633, RECALL: 0.0003873, MAP: 0.0001195, MAP_MIN_DEN: 0.0001507, MRR: 0.0011949, NDCG: 0.0004641, F1: 0.0003905, HIT_RATE: 0.0039378, ARHR_ALL_HITS: 0.0011949, NOVELTY: 0.0069578, AVERAGE_POPULARITY: 0.0122979, DIVERSITY_MEAN_INTER_LIST: 0.9993760, DIVERSITY_HERFINDAHL: 0.9999280, COVERAGE_ITEM: 0.9421294, COVERAGE_ITEM_HIT: 0.0018450, ITEMS_IN_GT: 0.8018630, COVERAGE_USER: 0.8238645, COVERAGE_USER_HIT: 0.0032442, USERS_IN_GT: 0.8238645, DIVERSITY_GINI: 0.5909797, SHANNON_ENTROPY: 14.0256010, RATIO_DIVERSITY_HERFINDAHL: 1.0002898, RATIO_DIVERSITY_GINI: 1.6950488, RATIO_SHANNON_ENTROPY: 1.0804398, RATIO_AVERAGE_POPULARITY: 0.0983997, RATIO_NOVELTY: 0.3930374,
#
# MF_MSE_PyTorch_Recommender: Convergence reached! Terminating at epoch 60. Best value for 'MAP' at epoch 10 is 0.0001. Elapsed time 35.87 min
# MF_MSE_PyTorch_Recommender: Epoch 60 of 67. Elapsed time 35.87 min
# [I 2024-01-09 01:08:04,724] Trial 20 finished with value: 0.00015070624655718782 and parameters: {'epochs': 67, 'batch_size': 32, 'num_factors': 199, 'learning_rate': 0.0007437243041865105}. Best is trial 19 with value: 0.0014954803455651824.
# MF_MSE_PyTorch_Recommender: URM Detected 197 ( 1.6%) users with no interactions.
# MF_MSE_PyTorch_Recommender: URM Detected 115 ( 0.5%) items with no interactions.
# MF_MSE_PyTorch_Recommender: MF_MSE_PyTorch: Using CUDA
# /home/kinami/.conda/envs/RecSysFramework/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# MF_MSE_PyTorch_Recommender: Epoch 1, Batch: [10000/11969], Samples per second 12471.72
# MF_MSE_PyTorch_Recommender: Epoch 1, Batch: [11969/11969], Samples per second 12467.54
# MF_MSE_PyTorch_Recommender: Epoch 1 of 99. Elapsed time 30.74 sec
# MF_MSE_PyTorch_Recommender: Epoch 2, Batch: [10000/11969], Samples per second 12475.17
# MF_MSE_PyTorch_Recommender: Epoch 2, Batch: [11969/11969], Samples per second 12467.10
# MF_MSE_PyTorch_Recommender: Epoch 2 of 99. Elapsed time 1.02 min
# MF_MSE_PyTorch_Recommender: Epoch 3, Batch: [10000/11969], Samples per second 12400.76
# MF_MSE_PyTorch_Recommender: Epoch 3, Batch: [11969/11969], Samples per second 12402.81
# MF_MSE_PyTorch_Recommender: Epoch 3 of 99. Elapsed time 1.54 min
# MF_MSE_PyTorch_Recommender: Epoch 4, Batch: [10000/11969], Samples per second 12399.35
# MF_MSE_PyTorch_Recommender: Epoch 4, Batch: [11969/11969], Samples per second 12407.98
# MF_MSE_PyTorch_Recommender: Epoch 4 of 99. Elapsed time 2.06 min
# MF_MSE_PyTorch_Recommender: Epoch 5, Batch: [10000/11969], Samples per second 12382.32
# MF_MSE_PyTorch_Recommender: Epoch 5, Batch: [11969/11969], Samples per second 12394.53
# MF_MSE_PyTorch_Recommender: Epoch 5 of 99. Elapsed time 2.57 min
# MF_MSE_PyTorch_Recommender: Epoch 6, Batch: [10000/11969], Samples per second 12475.78
# MF_MSE_PyTorch_Recommender: Epoch 6, Batch: [11969/11969], Samples per second 12479.68
# MF_MSE_PyTorch_Recommender: Epoch 6 of 99. Elapsed time 3.08 min
# MF_MSE_PyTorch_Recommender: Epoch 7, Batch: [10000/11969], Samples per second 12407.91
# MF_MSE_PyTorch_Recommender: Epoch 7, Batch: [11969/11969], Samples per second 12409.09
# MF_MSE_PyTorch_Recommender: Epoch 7 of 99. Elapsed time 3.60 min
# MF_MSE_PyTorch_Recommender: Epoch 8, Batch: [10000/11969], Samples per second 12463.79
# MF_MSE_PyTorch_Recommender: Epoch 8, Batch: [11969/11969], Samples per second 12475.40
# MF_MSE_PyTorch_Recommender: Epoch 8 of 99. Elapsed time 4.11 min
# MF_MSE_PyTorch_Recommender: Epoch 9, Batch: [10000/11969], Samples per second 12458.84
# MF_MSE_PyTorch_Recommender: Epoch 9, Batch: [11969/11969], Samples per second 12451.05
# MF_MSE_PyTorch_Recommender: Epoch 9 of 99. Elapsed time 4.62 min
# MF_MSE_PyTorch_Recommender: Epoch 10, Batch: [10000/11969], Samples per second 12469.18
# MF_MSE_PyTorch_Recommender: Epoch 10, Batch: [11969/11969], Samples per second 12471.35
# MF_MSE_PyTorch_Recommender: Validation begins...
# EvaluatorHoldout: Processed 10412 (100.0%) in 5.59 sec. Users per second: 1862
# MF_MSE_PyTorch_Recommender: CUTOFF: 10 - PRECISION: 0.0023434, PRECISION_RECALL_MIN_DEN: 0.0034775, RECALL: 0.0025859, MAP: 0.0007176, MAP_MIN_DEN: 0.0010871, MRR: 0.0070098, NDCG: 0.0029363, F1: 0.0024587, HIT_RATE: 0.0227622, ARHR_ALL_HITS: 0.0070929, NOVELTY: 0.0059209, AVERAGE_POPULARITY: 0.0613356, DIVERSITY_MEAN_INTER_LIST: 0.9939554, DIVERSITY_HERFINDAHL: 0.9993860, COVERAGE_ITEM: 0.3352084, COVERAGE_ITEM_HIT: 0.0090901, ITEMS_IN_GT: 0.8018630, COVERAGE_USER: 0.8238645, COVERAGE_USER_HIT: 0.0187530, USERS_IN_GT: 0.8238645, DIVERSITY_GINI: 0.0907910, SHANNON_ENTROPY: 11.3572538, RATIO_DIVERSITY_HERFINDAHL: 0.9997476, RATIO_DIVERSITY_GINI: 0.2604070, RATIO_SHANNON_ENTROPY: 0.8748879, RATIO_AVERAGE_POPULARITY: 0.4907694, RATIO_NOVELTY: 0.3344609,
#
# MF_MSE_PyTorch_Recommender: New best model found! Updating.
# MF_MSE_PyTorch_Recommender: Epoch 10 of 99. Elapsed time 5.23 min
# MF_MSE_PyTorch_Recommender: Epoch 11, Batch: [10000/11969], Samples per second 12442.14
# MF_MSE_PyTorch_Recommender: Epoch 11, Batch: [11969/11969], Samples per second 12438.08
# MF_MSE_PyTorch_Recommender: Epoch 11 of 99. Elapsed time 5.74 min
# MF_MSE_PyTorch_Recommender: Epoch 12, Batch: [10000/11969], Samples per second 12397.91
# MF_MSE_PyTorch_Recommender: Epoch 12, Batch: [11969/11969], Samples per second 12413.62
# MF_MSE_PyTorch_Recommender: Epoch 12 of 99. Elapsed time 6.26 min
# MF_MSE_PyTorch_Recommender: Epoch 13, Batch: [10000/11969], Samples per second 12427.31
# MF_MSE_PyTorch_Recommender: Epoch 13, Batch: [11969/11969], Samples per second 12439.65
# MF_MSE_PyTorch_Recommender: Epoch 13 of 99. Elapsed time 6.77 min
# MF_MSE_PyTorch_Recommender: Epoch 14, Batch: [10000/11969], Samples per second 12438.36
# MF_MSE_PyTorch_Recommender: Epoch 14, Batch: [11969/11969], Samples per second 12444.15
# MF_MSE_PyTorch_Recommender: Epoch 14 of 99. Elapsed time 7.28 min
# MF_MSE_PyTorch_Recommender: Epoch 15, Batch: [10000/11969], Samples per second 12457.93
# MF_MSE_PyTorch_Recommender: Epoch 15, Batch: [11969/11969], Samples per second 12463.44
# MF_MSE_PyTorch_Recommender: Epoch 15 of 99. Elapsed time 7.80 min
# MF_MSE_PyTorch_Recommender: Epoch 16, Batch: [10000/11969], Samples per second 12426.84
# MF_MSE_PyTorch_Recommender: Epoch 16, Batch: [11969/11969], Samples per second 12428.12
# MF_MSE_PyTorch_Recommender: Epoch 16 of 99. Elapsed time 8.31 min
# MF_MSE_PyTorch_Recommender: Epoch 17, Batch: [10000/11969], Samples per second 12388.54
# MF_MSE_PyTorch_Recommender: Epoch 17, Batch: [11969/11969], Samples per second 12395.91
# MF_MSE_PyTorch_Recommender: Epoch 17 of 99. Elapsed time 8.83 min
# MF_MSE_PyTorch_Recommender: Epoch 18, Batch: [10000/11969], Samples per second 12442.63
# MF_MSE_PyTorch_Recommender: Epoch 18, Batch: [11969/11969], Samples per second 12443.21
# MF_MSE_PyTorch_Recommender: Epoch 18 of 99. Elapsed time 9.34 min
# MF_MSE_PyTorch_Recommender: Epoch 19, Batch: [10000/11969], Samples per second 12411.24
# MF_MSE_PyTorch_Recommender: Epoch 19, Batch: [11969/11969], Samples per second 12403.59
# MF_MSE_PyTorch_Recommender: Epoch 19 of 99. Elapsed time 9.86 min
# MF_MSE_PyTorch_Recommender: Epoch 20, Batch: [10000/11969], Samples per second 12456.48
# MF_MSE_PyTorch_Recommender: Epoch 20, Batch: [11969/11969], Samples per second 12470.15
# MF_MSE_PyTorch_Recommender: Validation begins...
# EvaluatorHoldout: Processed 10412 (100.0%) in 5.43 sec. Users per second: 1918
# ...
#   warnings.warn(warning.format(ret))
# MF_MSE_PyTorch_Recommender: Epoch 1, Batch: [10000/11969], Samples per second 11861.78
# MF_MSE_PyTorch_Recommender: Epoch 1, Batch: [11969/11969], Samples per second 11872.09
# MF_MSE_PyTorch_Recommender: Epoch 1 of 409. Elapsed time 32.30 sec
# MF_MSE_PyTorch_Recommender: Epoch 2, Batch: [10000/11969], Samples per second 11837.40
# MF_MSE_PyTorch_Recommender: Epoch 2, Batch: [11969/11969], Samples per second 11846.74
# MF_MSE_PyTorch_Recommender: Epoch 2 of 409. Elapsed time 1.08 min
# MF_MSE_PyTorch_Recommender: Epoch 3, Batch: [10000/11969], Samples per second 11909.11
# MF_MSE_PyTorch_Recommender: Epoch 3, Batch: [11969/11969], Samples per second 11920.48
# MF_MSE_PyTorch_Recommender: Epoch 3 of 409. Elapsed time 1.61 min
# MF_MSE_PyTorch_Recommender: Epoch 4, Batch: [10000/11969], Samples per second 11929.16
# MF_MSE_PyTorch_Recommender: Epoch 4, Batch: [11969/11969], Samples per second 11922.48
# MF_MSE_PyTorch_Recommender: Epoch 4 of 409. Elapsed time 2.15 min
# MF_MSE_PyTorch_Recommender: Epoch 5, Batch: [10000/11969], Samples per second 11894.52
# MF_MSE_PyTorch_Recommender: Epoch 5, Batch: [11969/11969], Samples per second 11903.03
# MF_MSE_PyTorch_Recommender: Epoch 5 of 409. Elapsed time 2.69 min
# MF_MSE_PyTorch_Recommender: Epoch 6, Batch: [10000/11969], Samples per second 11898.22
# MF_MSE_PyTorch_Recommender: Epoch 6, Batch: [11969/11969], Samples per second 11894.05
# MF_MSE_PyTorch_Recommender: Epoch 6 of 409. Elapsed time 3.22 min
# MF_MSE_PyTorch_Recommender: Epoch 7, Batch: [10000/11969], Samples per second 11894.75
# MF_MSE_PyTorch_Recommender: Epoch 7, Batch: [11969/11969], Samples per second 11891.70
# MF_MSE_PyTorch_Recommender: Epoch 7 of 409. Elapsed time 3.76 min
# MF_MSE_PyTorch_Recommender: Epoch 8, Batch: [10000/11969], Samples per second 11906.83
# MF_MSE_PyTorch_Recommender: Epoch 8, Batch: [11969/11969], Samples per second 11898.34
# MF_MSE_PyTorch_Recommender: Epoch 8 of 409. Elapsed time 4.30 min
# MF_MSE_PyTorch_Recommender: Epoch 9, Batch: [10000/11969], Samples per second 11892.38
# MF_MSE_PyTorch_Recommender: Epoch 9, Batch: [11969/11969], Samples per second 11896.89
# MF_MSE_PyTorch_Recommender: Epoch 9 of 409. Elapsed time 4.84 min
# MF_MSE_PyTorch_Recommender: Epoch 10, Batch: [10000/11969], Samples per second 11895.89
# MF_MSE_PyTorch_Recommender: Epoch 10, Batch: [11969/11969], Samples per second 11900.69
# MF_MSE_PyTorch_Recommender: Validation begins...
# EvaluatorHoldout: Processed 10412 (100.0%) in 5.29 sec. Users per second: 1968
# MF_MSE_PyTorch_Recommender: CUTOFF: 10 - PRECISION: 0.0026700, PRECISION_RECALL_MIN_DEN: 0.0041246, RECALL: 0.0030885, MAP: 0.0009120, MAP_MIN_DEN: 0.0012477, MRR: 0.0084421, NDCG: 0.0034355, F1: 0.0028640, HIT_RATE: 0.0246831, ARHR_ALL_HITS: 0.0087710, NOVELTY: 0.0060409, AVERAGE_POPULARITY: 0.0662271, DIVERSITY_MEAN_INTER_LIST: 0.9895027, DIVERSITY_HERFINDAHL: 0.9989408, COVERAGE_ITEM: 0.5496805, COVERAGE_ITEM_HIT: 0.0078301, ITEMS_IN_GT: 0.8018630, COVERAGE_USER: 0.8238645, COVERAGE_USER_HIT: 0.0203355, USERS_IN_GT: 0.8238645, DIVERSITY_GINI: 0.1115549, SHANNON_ENTROPY: 11.1161744, RATIO_DIVERSITY_HERFINDAHL: 0.9993022, RATIO_DIVERSITY_GINI: 0.3199619, RATIO_SHANNON_ENTROPY: 0.8563167, RATIO_AVERAGE_POPULARITY: 0.5299084, RATIO_NOVELTY: 0.3412424,
#
# MF_MSE_PyTorch_Recommender: New best model found! Updating.
# MF_MSE_PyTorch_Recommender: Epoch 10 of 409. Elapsed time 5.46 min
# MF_MSE_PyTorch_Recommender: Epoch 11, Batch: [10000/11969], Samples per second 11872.39
# MF_MSE_PyTorch_Recommender: Epoch 11, Batch: [11969/11969], Samples per second 11870.03
# MF_MSE_PyTorch_Recommender: Epoch 11 of 409. Elapsed time 6.00 min
# MF_MSE_PyTorch_Recommender: Epoch 12, Batch: [10000/11969], Samples per second 11879.88
# MF_MSE_PyTorch_Recommender: Epoch 12, Batch: [11969/11969], Samples per second 11885.35
# MF_MSE_PyTorch_Recommender: Epoch 12 of 409. Elapsed time 6.54 min
# MF_MSE_PyTorch_Recommender: Epoch 13, Batch: [10000/11969], Samples per second 11862.35
# MF_MSE_PyTorch_Recommender: Epoch 13, Batch: [11969/11969], Samples per second 11860.65
# MF_MSE_PyTorch_Recommender: Epoch 13 of 409. Elapsed time 7.08 min
# MF_MSE_PyTorch_Recommender: Epoch 14, Batch: [10000/11969], Samples per second 11890.24
# MF_MSE_PyTorch_Recommender: Epoch 14, Batch: [11969/11969], Samples per second 11894.24
# MF_MSE_PyTorch_Recommender: Epoch 14 of 409. Elapsed time 7.61 min
# MF_MSE_PyTorch_Recommender: Epoch 15, Batch: [10000/11969], Samples per second 11892.47
# MF_MSE_PyTorch_Recommender: Epoch 15, Batch: [11969/11969], Samples per second 11895.44
# MF_MSE_PyTorch_Recommender: Epoch 15 of 409. Elapsed time 8.15 min
# MF_MSE_PyTorch_Recommender: Epoch 16, Batch: [10000/11969], Samples per second 11927.44
# MF_MSE_PyTorch_Recommender: Epoch 16, Batch: [11969/11969], Samples per second 11929.16
# MF_MSE_PyTorch_Recommender: Epoch 16 of 409. Elapsed time 8.68 min
# MF_MSE_PyTorch_Recommender: Epoch 17, Batch: [10000/11969], Samples per second 11927.95
# MF_MSE_PyTorch_Recommender: Epoch 17, Batch: [11969/11969], Samples per second 11922.67
# MF_MSE_PyTorch_Recommender: Epoch 17 of 409. Elapsed time 9.22 min
# MF_MSE_PyTorch_Recommender: Epoch 18, Batch: [10000/11969], Samples per second 11912.29
# MF_MSE_PyTorch_Recommender: Epoch 18, Batch: [11969/11969], Samples per second 11918.14
# MF_MSE_PyTorch_Recommender: Epoch 18 of 409. Elapsed time 9.76 min
# MF_MSE_PyTorch_Recommender: Epoch 19, Batch: [10000/11969], Samples per second 11898.69
# MF_MSE_PyTorch_Recommender: Epoch 19, Batch: [11969/11969], Samples per second 11898.10
# MF_MSE_PyTorch_Recommender: Epoch 19 of 409. Elapsed time 10.29 min
# MF_MSE_PyTorch_Recommender: Epoch 20, Batch: [10000/11969], Samples per second 11885.60
# MF_MSE_PyTorch_Recommender: Epoch 20, Batch: [11969/11969], Samples per second 11889.55
# MF_MSE_PyTorch_Recommender: Validation begins...
# EvaluatorHoldout: Processed 10412 (100.0%) in 5.32 sec. Users per second: 1958
# MF_MSE_PyTorch_Recommender: CUTOFF: 10 - PRECISION: 0.0024587, PRECISION_RECALL_MIN_DEN: 0.0036723, RECALL: 0.0026981, MAP: 0.0008568, MAP_MIN_DEN: 0.0011662, MRR: 0.0079984, NDCG: 0.0031774, F1: 0.0025728, HIT_RATE: 0.0230503, ARHR_ALL_HITS: 0.0082833, NOVELTY: 0.0060444, AVERAGE_POPULARITY: 0.0645334, DIVERSITY_MEAN_INTER_LIST: 0.9894876, DIVERSITY_HERFINDAHL: 0.9989393, COVERAGE_ITEM: 0.5361804, COVERAGE_ITEM_HIT: 0.0076951, ITEMS_IN_GT: 0.8018630, COVERAGE_USER: 0.8238645, COVERAGE_USER_HIT: 0.0189903, USERS_IN_GT: 0.8238645, DIVERSITY_GINI: 0.1067227, SHANNON_ENTROPY: 11.0732573, RATIO_DIVERSITY_HERFINDAHL: 0.9993007, RATIO_DIVERSITY_GINI: 0.3061021, RATIO_SHANNON_ENTROPY: 0.8530107, RATIO_AVERAGE_POPULARITY: 0.5163564, RATIO_NOVELTY: 0.3414411,
#
# MF_MSE_PyTorch_Recommender: Epoch 20 of 409. Elapsed time 10.92 min
# MF_MSE_PyTorch_Recommender: Epoch 21, Batch: [10000/11969], Samples per second 11877.13
# MF_MSE_PyTorch_Recommender: Epoch 21, Batch: [11969/11969], Samples per second 11878.01
# MF_MSE_PyTorch_Recommender: Epoch 21 of 409. Elapsed time 11.46 min
# MF_MSE_PyTorch_Recommender: Epoch 22, Batch: [10000/11969], Samples per second 11903.77
# MF_MSE_PyTorch_Recommender: Epoch 22, Batch: [11969/11969], Samples per second 11911.49
# MF_MSE_PyTorch_Recommender: Epoch 22 of 409. Elapsed time 11.99 min
# MF_MSE_PyTorch_Recommender: Epoch 23, Batch: [10000/11969], Samples per second 11843.29
# MF_MSE_PyTorch_Recommender: Epoch 23, Batch: [11969/11969], Samples per second 11852.66
# MF_MSE_PyTorch_Recommender: Epoch 23 of 409. Elapsed time 12.53 min
# MF_MSE_PyTorch_Recommender: Epoch 24, Batch: [10000/11969], Samples per second 11889.29
# MF_MSE_PyTorch_Recommender: Epoch 24, Batch: [11969/11969], Samples per second 11893.49
# MF_MSE_PyTorch_Recommender: Epoch 24 of 409. Elapsed time 13.07 min
# MF_MSE_PyTorch_Recommender: Epoch 25, Batch: [10000/11969], Samples per second 11852.91
# MF_MSE_PyTorch_Recommender: Epoch 25, Batch: [11969/11969], Samples per second 11866.50
# MF_MSE_PyTorch_Recommender: Epoch 25 of 409. Elapsed time 13.61 min
# MF_MSE_PyTorch_Recommender: Epoch 26, Batch: [10000/11969], Samples per second 11948.60
# MF_MSE_PyTorch_Recommender: Epoch 26, Batch: [11969/11969], Samples per second 11936.78
# MF_MSE_PyTorch_Recommender: Epoch 26 of 409. Elapsed time 14.14 min
# MF_MSE_PyTorch_Recommender: Epoch 27, Batch: [10000/11969], Samples per second 11898.99
# MF_MSE_PyTorch_Recommender: Epoch 27, Batch: [11969/11969], Samples per second 11907.78
# MF_MSE_PyTorch_Recommender: Epoch 27 of 409. Elapsed time 14.68 min
# MF_MSE_PyTorch_Recommender: Epoch 28, Batch: [10000/11969], Samples per second 11898.18
# MF_MSE_PyTorch_Recommender: Epoch 28, Batch: [11969/11969], Samples per second 11903.16
# MF_MSE_PyTorch_Recommender: Epoch 28 of 409. Elapsed time 15.22 min
# MF_MSE_PyTorch_Recommender: Epoch 29, Batch: [10000/11969], Samples per second 11880.70
# MF_MSE_PyTorch_Recommender: Epoch 29, Batch: [11969/11969], Samples per second 11876.65
# MF_MSE_PyTorch_Recommender: Epoch 29 of 409. Elapsed time 15.76 min
# MF_MSE_PyTorch_Recommender: Epoch 30, Batch: [10000/11969], Samples per second 11831.84
# [W 2024-01-09 09:18:26,203] Trial 49 failed with parameters: {'epochs': 409, 'batch_size': 32, 'num_factors': 188, 'learning_rate': 0.9545657231700944} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/kinami/.conda/envs/RecSysFramework/lib/python3.8/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_223385/1820081744.py", line 13, in objective
#     recommender.fit(
#   File "/home/kinami/code/rcs/Recommenders/MatrixFactorization/PyTorch/MF_MSE_PyTorch.py", line 83, in fit
#     self._train_with_early_stopping(epochs,
#   File "/home/kinami/code/rcs/Recommenders/Incremental_Training_Early_Stopping.py", line 199, in _train_with_early_stopping
#     self._run_epoch(epochs_current)
#   File "/home/kinami/code/rcs/Recommenders/MatrixFactorization/PyTorch/MF_MSE_PyTorch.py", line 115, in _run_epoch
#     input_data_tensor = Variable(input_data).to(self.device)
# KeyboardInterrupt
# [W 2024-01-09 09:18:26,204] Trial 49 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 28
#      24     _, _, ev_map, _, _ = evaluator(recommender, data_train, data_val)
#      26     return ev_map
# ---> 28 study.optimize(objective, n_trials=150)
#
# File ~/.conda/envs/RecSysFramework/lib/python3.8/site-packages/optuna/study/study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File ~/.conda/envs/RecSysFramework/lib/python3.8/site-packages/optuna/study/_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File ~/.conda/envs/RecSysFramework/lib/python3.8/site-packages/optuna/study/_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File ~/.conda/envs/RecSysFramework/lib/python3.8/site-packages/optuna/study/_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File ~/.conda/envs/RecSysFramework/lib/python3.8/site-packages/optuna/study/_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[4], line 13, in objective(trial)
#      10 learning_rate = trial.suggest_float('learning_rate', 1e-8, 1)
#      12 recommender = MF_MSE_PyTorch(data_train)
# ---> 13 recommender.fit(
#      14     epochs=epochs,
#      15     batch_size=batch_size,
#      16     num_factors=num_factors,
#      17     learning_rate=learning_rate,
#      18     validation_every_n=10,
#      19     stop_on_validation=True,
#      20     evaluator_object=evaluator_validation,
#      21     lower_validations_allowed=5,
#      22     validation_metric="MAP",
#      23 )
#      24 _, _, ev_map, _, _ = evaluator(recommender, data_train, data_val)
#      26 return ev_map
#
# File ~/code/rcs/Recommenders/MatrixFactorization/PyTorch/MF_MSE_PyTorch.py:83, in MF_MSE_PyTorch.fit(self, epochs, batch_size, num_factors, learning_rate, use_cuda, **earlystopping_kwargs)
#      80 self._prepare_model_for_validation()
#      81 self._update_best_model()
# ---> 83 self._train_with_early_stopping(epochs,
#      84                                 algorithm_name = self.RECOMMENDER_NAME,
#      85                                 **earlystopping_kwargs)
#      88 self.ITEM_factors = self.ITEM_factors_best.copy()
#      89 self.USER_factors = self.USER_factors_best.copy()
#
# File ~/code/rcs/Recommenders/Incremental_Training_Early_Stopping.py:199, in Incremental_Training_Early_Stopping._train_with_early_stopping(self, epochs_max, epochs_min, validation_every_n, stop_on_validation, validation_metric, lower_validations_allowed, evaluator_object, algorithm_name)
#     195 epochs_current = 0
#     197 while epochs_current < epochs_max and not convergence:
# --> 199     self._run_epoch(epochs_current)
#     201     # If no validation required, always keep the latest
#     202     if evaluator_object is None:
#
# File ~/code/rcs/Recommenders/MatrixFactorization/PyTorch/MF_MSE_PyTorch.py:115, in MF_MSE_PyTorch._run_epoch(self, num_epoch)
#     111     self._print("Epoch {}, Batch: [{}/{}], Samples per second {:.2f}".format(num_epoch+1, num_batch+1, len(self.train_data_loader), (num_batch+1)*self.batch_size/(time.time()-start_time)))
#     113 # On windows requires int64, on ubuntu int32
#     114 #input_data_tensor = Variable(torch.from_numpy(np.asarray(input_data, dtype=int))).to(self.device)
# --> 115 input_data_tensor = Variable(input_data).to(self.device)
#     117 label_tensor = Variable(label).to(self.device)
#     120 user_coordinates = input_data_tensor[:,0]
#
# KeyboardInterrupt:
