# %%
import os
from utils import *
import optuna

# %%
data, usermap, itemmap, users = load_data2()
data_train, data_val=split_data2(data, 0.2)

# %%
rat_rank_study = optuna.create_study(
    study_name="rating+ranking",
    storage=get_database_url(),
    load_if_exists=True,
    direction="maximize",
)
# Out:
# [I 2024-01-06 15:16:13,954] A new study created in memory with name: rating+ranking

# %%
slim_bpr_study = optuna.create_study(
    study_name="slim_bpr",
    storage=get_database_url(),
    load_if_exists=True,
    direction="maximize",
)
# Out:
# [I 2024-01-06 15:16:13,976] A new study created in memory with name: slim_bpr

# %%
from Recommenders.SLIM.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython

slim_bpr_recommender = SLIM_BPR_Cython(data_train, verbose=False)
slim_bpr_recommender.fit(epochs=411, 
                symmetric=True, 
                lambda_i=0.3776970357741607, 
                lambda_j=0.04722986062962217, 
                learning_rate=0.0003013846889808713, 
                topK=60, 
                sgd_mode="adagrad", 
                gamma=1.1938389128360214e-05, 
                beta_1=0.002818160651487956, 
                beta_2=3.307005474510783e-07)

#slimbpr [epochs: 411, symmetric: True, lambda_i: 0.3776970357741607, lambda_j: 0.04722986062962217, learning_rate: 0.0003013846889808713, topK: 60, sgd_mode: adagrad, gamma: 1.1938389128360214e-05, beta_1: 0.002818160651487956, beta_2: 3.307005474510783e-07]
# Out:
# Deallocating Cython objects
# Unable to read memory status: list index out of range
# SLIM_BPR_Recommender: Epoch 1 of 411. Elapsed time 0.05 sec
# SLIM_BPR_Recommender: Epoch 2 of 411. Elapsed time 0.11 sec
# SLIM_BPR_Recommender: Epoch 3 of 411. Elapsed time 0.17 sec
# SLIM_BPR_Recommender: Epoch 4 of 411. Elapsed time 0.23 sec
# SLIM_BPR_Recommender: Epoch 5 of 411. Elapsed time 0.29 sec
# SLIM_BPR_Recommender: Epoch 6 of 411. Elapsed time 0.34 sec
# SLIM_BPR_Recommender: Epoch 7 of 411. Elapsed time 0.40 sec
# SLIM_BPR_Recommender: Epoch 8 of 411. Elapsed time 0.47 sec
# SLIM_BPR_Recommender: Epoch 9 of 411. Elapsed time 0.53 sec
# SLIM_BPR_Recommender: Epoch 10 of 411. Elapsed time 0.59 sec
# SLIM_BPR_Recommender: Epoch 11 of 411. Elapsed time 0.64 sec
# SLIM_BPR_Recommender: Epoch 12 of 411. Elapsed time 0.69 sec
# SLIM_BPR_Recommender: Epoch 13 of 411. Elapsed time 0.73 sec
# SLIM_BPR_Recommender: Epoch 14 of 411. Elapsed time 0.80 sec
# SLIM_BPR_Recommender: Epoch 15 of 411. Elapsed time 0.86 sec
# SLIM_BPR_Recommender: Epoch 16 of 411. Elapsed time 0.91 sec
# SLIM_BPR_Recommender: Epoch 17 of 411. Elapsed time 0.95 sec
# SLIM_BPR_Recommender: Epoch 18 of 411. Elapsed time 1.01 sec
# SLIM_BPR_Recommender: Epoch 19 of 411. Elapsed time 1.07 sec
# SLIM_BPR_Recommender: Epoch 20 of 411. Elapsed time 1.12 sec
# SLIM_BPR_Recommender: Epoch 21 of 411. Elapsed time 1.17 sec
# SLIM_BPR_Recommender: Epoch 22 of 411. Elapsed time 1.22 sec
# SLIM_BPR_Recommender: Epoch 23 of 411. Elapsed time 1.28 sec
# SLIM_BPR_Recommender: Epoch 24 of 411. Elapsed time 1.33 sec
# SLIM_BPR_Recommender: Epoch 25 of 411. Elapsed time 1.39 sec
# SLIM_BPR_Recommender: Epoch 26 of 411. Elapsed time 1.44 sec
# SLIM_BPR_Recommender: Epoch 27 of 411. Elapsed time 1.49 sec
# SLIM_BPR_Recommender: Epoch 28 of 411. Elapsed time 1.53 sec
# SLIM_BPR_Recommender: Epoch 29 of 411. Elapsed time 1.59 sec
# SLIM_BPR_Recommender: Epoch 30 of 411. Elapsed time 1.65 sec
# SLIM_BPR_Recommender: Epoch 31 of 411. Elapsed time 1.69 sec
# SLIM_BPR_Recommender: Epoch 32 of 411. Elapsed time 1.74 sec
# SLIM_BPR_Recommender: Epoch 33 of 411. Elapsed time 1.78 sec
# SLIM_BPR_Recommender: Epoch 34 of 411. Elapsed time 1.82 sec
# SLIM_BPR_Recommender: Epoch 35 of 411. Elapsed time 1.91 sec
# SLIM_BPR_Recommender: Epoch 36 of 411. Elapsed time 1.96 sec
# SLIM_BPR_Recommender: Epoch 37 of 411. Elapsed time 2.00 sec
# SLIM_BPR_Recommender: Epoch 38 of 411. Elapsed time 2.04 sec
# SLIM_BPR_Recommender: Epoch 39 of 411. Elapsed time 2.08 sec
# SLIM_BPR_Recommender: Epoch 40 of 411. Elapsed time 2.12 sec
# SLIM_BPR_Recommender: Epoch 41 of 411. Elapsed time 2.17 sec
# SLIM_BPR_Recommender: Epoch 42 of 411. Elapsed time 2.22 sec
# SLIM_BPR_Recommender: Epoch 43 of 411. Elapsed time 2.25 sec
# SLIM_BPR_Recommender: Epoch 44 of 411. Elapsed time 2.30 sec
# SLIM_BPR_Recommender: Epoch 45 of 411. Elapsed time 2.35 sec
# SLIM_BPR_Recommender: Epoch 46 of 411. Elapsed time 2.40 sec
# SLIM_BPR_Recommender: Epoch 47 of 411. Elapsed time 2.44 sec
# SLIM_BPR_Recommender: Epoch 48 of 411. Elapsed time 2.49 sec
# SLIM_BPR_Recommender: Epoch 49 of 411. Elapsed time 2.53 sec
# SLIM_BPR_Recommender: Epoch 50 of 411. Elapsed time 2.58 sec
# SLIM_BPR_Recommender: Epoch 51 of 411. Elapsed time 2.62 sec
# SLIM_BPR_Recommender: Epoch 52 of 411. Elapsed time 2.67 sec
# SLIM_BPR_Recommender: Epoch 53 of 411. Elapsed time 2.71 sec
# SLIM_BPR_Recommender: Epoch 54 of 411. Elapsed time 2.77 sec
# SLIM_BPR_Recommender: Epoch 55 of 411. Elapsed time 2.83 sec
# SLIM_BPR_Recommender: Epoch 56 of 411. Elapsed time 2.88 sec
# SLIM_BPR_Recommender: Epoch 57 of 411. Elapsed time 2.93 sec
# SLIM_BPR_Recommender: Epoch 58 of 411. Elapsed time 2.97 sec
# SLIM_BPR_Recommender: Epoch 59 of 411. Elapsed time 3.02 sec
# SLIM_BPR_Recommender: Epoch 60 of 411. Elapsed time 3.06 sec
# SLIM_BPR_Recommender: Epoch 61 of 411. Elapsed time 3.12 sec
# SLIM_BPR_Recommender: Epoch 62 of 411. Elapsed time 3.17 sec
# SLIM_BPR_Recommender: Epoch 63 of 411. Elapsed time 3.22 sec
# SLIM_BPR_Recommender: Epoch 64 of 411. Elapsed time 3.26 sec
# SLIM_BPR_Recommender: Epoch 65 of 411. Elapsed time 3.32 sec
# SLIM_BPR_Recommender: Epoch 66 of 411. Elapsed time 3.35 sec
# SLIM_BPR_Recommender: Epoch 67 of 411. Elapsed time 3.40 sec
# SLIM_BPR_Recommender: Epoch 68 of 411. Elapsed time 3.45 sec
# SLIM_BPR_Recommender: Epoch 69 of 411. Elapsed time 3.52 sec
# SLIM_BPR_Recommender: Epoch 70 of 411. Elapsed time 3.58 sec
# SLIM_BPR_Recommender: Epoch 71 of 411. Elapsed time 3.63 sec
# SLIM_BPR_Recommender: Epoch 72 of 411. Elapsed time 3.68 sec
# SLIM_BPR_Recommender: Epoch 73 of 411. Elapsed time 3.73 sec
# SLIM_BPR_Recommender: Epoch 74 of 411. Elapsed time 3.78 sec
# SLIM_BPR_Recommender: Epoch 75 of 411. Elapsed time 3.83 sec
# SLIM_BPR_Recommender: Epoch 76 of 411. Elapsed time 3.88 sec
# SLIM_BPR_Recommender: Epoch 77 of 411. Elapsed time 3.93 sec
# SLIM_BPR_Recommender: Epoch 78 of 411. Elapsed time 3.98 sec
# SLIM_BPR_Recommender: Epoch 79 of 411. Elapsed time 4.03 sec
# SLIM_BPR_Recommender: Epoch 80 of 411. Elapsed time 4.07 sec
# SLIM_BPR_Recommender: Epoch 81 of 411. Elapsed time 4.12 sec
# SLIM_BPR_Recommender: Epoch 82 of 411. Elapsed time 4.18 sec
# SLIM_BPR_Recommender: Epoch 83 of 411. Elapsed time 4.23 sec
# SLIM_BPR_Recommender: Epoch 84 of 411. Elapsed time 4.28 sec
# SLIM_BPR_Recommender: Epoch 85 of 411. Elapsed time 4.33 sec
# SLIM_BPR_Recommender: Epoch 86 of 411. Elapsed time 4.39 sec
# SLIM_BPR_Recommender: Epoch 87 of 411. Elapsed time 4.44 sec
# SLIM_BPR_Recommender: Epoch 88 of 411. Elapsed time 4.49 sec
# SLIM_BPR_Recommender: Epoch 89 of 411. Elapsed time 4.54 sec
# SLIM_BPR_Recommender: Epoch 90 of 411. Elapsed time 4.59 sec
# SLIM_BPR_Recommender: Epoch 91 of 411. Elapsed time 4.64 sec
# SLIM_BPR_Recommender: Epoch 92 of 411. Elapsed time 4.69 sec
# SLIM_BPR_Recommender: Epoch 93 of 411. Elapsed time 4.73 sec
# SLIM_BPR_Recommender: Epoch 94 of 411. Elapsed time 4.82 sec
# SLIM_BPR_Recommender: Epoch 95 of 411. Elapsed time 4.86 sec
# SLIM_BPR_Recommender: Epoch 96 of 411. Elapsed time 4.90 sec
# SLIM_BPR_Recommender: Epoch 172 of 411. Elapsed time 8.74 sec
# SLIM_BPR_Recommender: Epoch 173 of 411. Elapsed time 8.80 sec
# SLIM_BPR_Recommender: Epoch 174 of 411. Elapsed time 8.84 sec
# SLIM_BPR_Recommender: Epoch 175 of 411. Elapsed time 8.89 sec
# SLIM_BPR_Recommender: Epoch 176 of 411. Elapsed time 8.93 sec
# SLIM_BPR_Recommender: Epoch 177 of 411. Elapsed time 8.97 sec
# SLIM_BPR_Recommender: Epoch 178 of 411. Elapsed time 9.02 sec
# SLIM_BPR_Recommender: Epoch 179 of 411. Elapsed time 9.06 sec
# SLIM_BPR_Recommender: Epoch 180 of 411. Elapsed time 9.11 sec
# SLIM_BPR_Recommender: Epoch 181 of 411. Elapsed time 9.15 sec
# SLIM_BPR_Recommender: Epoch 182 of 411. Elapsed time 9.20 sec
# SLIM_BPR_Recommender: Epoch 183 of 411. Elapsed time 9.23 sec
# SLIM_BPR_Recommender: Epoch 184 of 411. Elapsed time 9.29 sec
# SLIM_BPR_Recommender: Epoch 185 of 411. Elapsed time 9.33 sec
# SLIM_BPR_Recommender: Epoch 186 of 411. Elapsed time 9.38 sec
# SLIM_BPR_Recommender: Epoch 187 of 411. Elapsed time 9.42 sec
# SLIM_BPR_Recommender: Epoch 188 of 411. Elapsed time 9.47 sec
# SLIM_BPR_Recommender: Epoch 189 of 411. Elapsed time 9.52 sec
# SLIM_BPR_Recommender: Epoch 190 of 411. Elapsed time 9.56 sec
# SLIM_BPR_Recommender: Epoch 191 of 411. Elapsed time 9.60 sec
# SLIM_BPR_Recommender: Epoch 192 of 411. Elapsed time 9.66 sec
# SLIM_BPR_Recommender: Epoch 193 of 411. Elapsed time 9.69 sec
# SLIM_BPR_Recommender: Epoch 194 of 411. Elapsed time 9.75 sec
# SLIM_BPR_Recommender: Epoch 195 of 411. Elapsed time 9.80 sec
# SLIM_BPR_Recommender: Epoch 196 of 411. Elapsed time 9.84 sec
# SLIM_BPR_Recommender: Epoch 197 of 411. Elapsed time 9.88 sec
# SLIM_BPR_Recommender: Epoch 198 of 411. Elapsed time 9.93 sec
# SLIM_BPR_Recommender: Epoch 199 of 411. Elapsed time 9.97 sec
# SLIM_BPR_Recommender: Epoch 200 of 411. Elapsed time 10.02 sec
# SLIM_BPR_Recommender: Epoch 201 of 411. Elapsed time 10.07 sec
# SLIM_BPR_Recommender: Epoch 202 of 411. Elapsed time 10.10 sec
# SLIM_BPR_Recommender: Epoch 203 of 411. Elapsed time 10.15 sec
# SLIM_BPR_Recommender: Epoch 204 of 411. Elapsed time 10.20 sec
# SLIM_BPR_Recommender: Epoch 205 of 411. Elapsed time 10.24 sec
# SLIM_BPR_Recommender: Epoch 206 of 411. Elapsed time 10.32 sec
# SLIM_BPR_Recommender: Epoch 207 of 411. Elapsed time 10.38 sec
# SLIM_BPR_Recommender: Epoch 208 of 411. Elapsed time 10.43 sec
# SLIM_BPR_Recommender: Epoch 209 of 411. Elapsed time 10.47 sec
# SLIM_BPR_Recommender: Epoch 210 of 411. Elapsed time 10.51 sec
# SLIM_BPR_Recommender: Epoch 211 of 411. Elapsed time 10.57 sec
# SLIM_BPR_Recommender: Epoch 212 of 411. Elapsed time 10.60 sec
# SLIM_BPR_Recommender: Epoch 213 of 411. Elapsed time 10.66 sec
# SLIM_BPR_Recommender: Epoch 214 of 411. Elapsed time 10.70 sec
# SLIM_BPR_Recommender: Epoch 215 of 411. Elapsed time 10.75 sec
# SLIM_BPR_Recommender: Epoch 216 of 411. Elapsed time 10.80 sec
# SLIM_BPR_Recommender: Epoch 217 of 411. Elapsed time 10.84 sec
# SLIM_BPR_Recommender: Epoch 218 of 411. Elapsed time 10.89 sec
# SLIM_BPR_Recommender: Epoch 219 of 411. Elapsed time 10.93 sec
# SLIM_BPR_Recommender: Epoch 220 of 411. Elapsed time 10.98 sec
# SLIM_BPR_Recommender: Epoch 221 of 411. Elapsed time 11.02 sec
# SLIM_BPR_Recommender: Epoch 222 of 411. Elapsed time 11.07 sec
# SLIM_BPR_Recommender: Epoch 223 of 411. Elapsed time 11.11 sec
# SLIM_BPR_Recommender: Epoch 224 of 411. Elapsed time 11.15 sec
# SLIM_BPR_Recommender: Epoch 225 of 411. Elapsed time 11.19 sec
# SLIM_BPR_Recommender: Epoch 226 of 411. Elapsed time 11.25 sec
# SLIM_BPR_Recommender: Epoch 227 of 411. Elapsed time 11.28 sec
# SLIM_BPR_Recommender: Epoch 228 of 411. Elapsed time 11.33 sec
# SLIM_BPR_Recommender: Epoch 229 of 411. Elapsed time 11.38 sec
# SLIM_BPR_Recommender: Epoch 230 of 411. Elapsed time 11.42 sec
# SLIM_BPR_Recommender: Epoch 231 of 411. Elapsed time 11.46 sec
# SLIM_BPR_Recommender: Epoch 232 of 411. Elapsed time 11.51 sec
# SLIM_BPR_Recommender: Epoch 233 of 411. Elapsed time 11.55 sec
# SLIM_BPR_Recommender: Epoch 234 of 411. Elapsed time 11.58 sec
# SLIM_BPR_Recommender: Epoch 235 of 411. Elapsed time 11.63 sec
# SLIM_BPR_Recommender: Epoch 236 of 411. Elapsed time 11.68 sec
# SLIM_BPR_Recommender: Epoch 237 of 411. Elapsed time 11.72 sec
# SLIM_BPR_Recommender: Epoch 238 of 411. Elapsed time 11.76 sec
# SLIM_BPR_Recommender: Epoch 239 of 411. Elapsed time 11.81 sec
# SLIM_BPR_Recommender: Epoch 240 of 411. Elapsed time 11.85 sec
# SLIM_BPR_Recommender: Epoch 241 of 411. Elapsed time 11.89 sec
# SLIM_BPR_Recommender: Epoch 242 of 411. Elapsed time 11.93 sec
# SLIM_BPR_Recommender: Epoch 243 of 411. Elapsed time 11.98 sec
# SLIM_BPR_Recommender: Epoch 244 of 411. Elapsed time 12.02 sec
# SLIM_BPR_Recommender: Epoch 245 of 411. Elapsed time 12.07 sec
# SLIM_BPR_Recommender: Epoch 246 of 411. Elapsed time 12.11 sec
# SLIM_BPR_Recommender: Epoch 247 of 411. Elapsed time 12.15 sec
# SLIM_BPR_Recommender: Epoch 361 of 411. Elapsed time 17.40 sec
# SLIM_BPR_Recommender: Epoch 362 of 411. Elapsed time 17.44 sec
# SLIM_BPR_Recommender: Epoch 363 of 411. Elapsed time 17.49 sec
# SLIM_BPR_Recommender: Epoch 364 of 411. Elapsed time 17.53 sec
# SLIM_BPR_Recommender: Epoch 365 of 411. Elapsed time 17.58 sec
# SLIM_BPR_Recommender: Epoch 366 of 411. Elapsed time 17.63 sec
# SLIM_BPR_Recommender: Epoch 367 of 411. Elapsed time 17.67 sec
# SLIM_BPR_Recommender: Epoch 368 of 411. Elapsed time 17.72 sec
# SLIM_BPR_Recommender: Epoch 369 of 411. Elapsed time 17.76 sec
# SLIM_BPR_Recommender: Epoch 370 of 411. Elapsed time 17.81 sec
# SLIM_BPR_Recommender: Epoch 371 of 411. Elapsed time 17.85 sec
# SLIM_BPR_Recommender: Epoch 372 of 411. Elapsed time 17.90 sec
# SLIM_BPR_Recommender: Epoch 373 of 411. Elapsed time 17.94 sec
# SLIM_BPR_Recommender: Epoch 374 of 411. Elapsed time 17.98 sec
# SLIM_BPR_Recommender: Epoch 375 of 411. Elapsed time 18.07 sec
# SLIM_BPR_Recommender: Epoch 376 of 411. Elapsed time 18.12 sec
# SLIM_BPR_Recommender: Epoch 377 of 411. Elapsed time 18.16 sec
# SLIM_BPR_Recommender: Epoch 378 of 411. Elapsed time 18.21 sec
# SLIM_BPR_Recommender: Epoch 379 of 411. Elapsed time 18.26 sec
# SLIM_BPR_Recommender: Epoch 380 of 411. Elapsed time 18.31 sec
# SLIM_BPR_Recommender: Epoch 381 of 411. Elapsed time 18.35 sec
# SLIM_BPR_Recommender: Epoch 382 of 411. Elapsed time 18.40 sec
# SLIM_BPR_Recommender: Epoch 383 of 411. Elapsed time 18.44 sec
# SLIM_BPR_Recommender: Epoch 384 of 411. Elapsed time 18.48 sec
# SLIM_BPR_Recommender: Epoch 385 of 411. Elapsed time 18.53 sec
# SLIM_BPR_Recommender: Epoch 386 of 411. Elapsed time 18.57 sec
# SLIM_BPR_Recommender: Epoch 387 of 411. Elapsed time 18.63 sec
# SLIM_BPR_Recommender: Epoch 388 of 411. Elapsed time 18.67 sec
# SLIM_BPR_Recommender: Epoch 389 of 411. Elapsed time 18.72 sec
# SLIM_BPR_Recommender: Epoch 390 of 411. Elapsed time 18.78 sec
# SLIM_BPR_Recommender: Epoch 391 of 411. Elapsed time 18.82 sec
# SLIM_BPR_Recommender: Epoch 392 of 411. Elapsed time 18.87 sec
# SLIM_BPR_Recommender: Epoch 393 of 411. Elapsed time 18.91 sec
# SLIM_BPR_Recommender: Epoch 394 of 411. Elapsed time 18.96 sec
# SLIM_BPR_Recommender: Epoch 395 of 411. Elapsed time 19.00 sec
# SLIM_BPR_Recommender: Epoch 396 of 411. Elapsed time 19.04 sec
# SLIM_BPR_Recommender: Epoch 397 of 411. Elapsed time 19.08 sec
# SLIM_BPR_Recommender: Epoch 398 of 411. Elapsed time 19.13 sec
# SLIM_BPR_Recommender: Epoch 399 of 411. Elapsed time 19.16 sec
# SLIM_BPR_Recommender: Epoch 400 of 411. Elapsed time 19.22 sec
# SLIM_BPR_Recommender: Epoch 401 of 411. Elapsed time 19.25 sec
# SLIM_BPR_Recommender: Epoch 402 of 411. Elapsed time 19.30 sec
# SLIM_BPR_Recommender: Epoch 403 of 411. Elapsed time 19.34 sec
# SLIM_BPR_Recommender: Epoch 404 of 411. Elapsed time 19.39 sec
# SLIM_BPR_Recommender: Epoch 405 of 411. Elapsed time 19.43 sec
# SLIM_BPR_Recommender: Epoch 406 of 411. Elapsed time 19.47 sec
# SLIM_BPR_Recommender: Epoch 407 of 411. Elapsed time 19.51 sec
# SLIM_BPR_Recommender: Epoch 408 of 411. Elapsed time 19.56 sec
# SLIM_BPR_Recommender: Epoch 409 of 411. Elapsed time 19.60 sec
# SLIM_BPR_Recommender: Epoch 410 of 411. Elapsed time 19.64 sec
# SLIM_BPR_Recommender: Epoch 411 of 411. Elapsed time 19.69 sec
# SLIM_BPR_Recommender: Terminating at epoch 411. Elapsed time 25.82 sec
# Deallocating Cython objects

# %%
rp3beta_study = optuna.create_study(
    study_name="P3Beta",
    storage=get_database_url(),
    load_if_exists=True,
    direction="maximize",
)
# Out:
# [I 2024-01-06 15:16:50,620] A new study created in memory with name: P3Beta

# %%
from Recommenders.GraphBased.RP3betaRecommender import RP3betaRecommender

rp3beta_recommender = RP3betaRecommender(data_train+data_val, verbose=False)
rp3beta_recommender.fit(topK=35, alpha=0.3598110596257423, beta=0.1558338653772352, implicit=True, normalize_similarity=True)

_, _, ev_map, _, _ = evaluator(rp3beta_recommender, data_train, data_val)

#p3beta [topK: 35, alpha: 0.3598110596257423, beta: 0.1558338653772352, implicit: True, normalize_similarity: True]

# %%
#slim_el_study = optuna.create_study(
#    study_name="slim_el",
#    storage=get_database_url(),
#    load_if_exists=True,
#    direction="maximize",
#)

# %%
#from Recommenders.SLIM.SLIMElasticNetRecommender import MultiThreadSLIM_SLIMElasticNetRecommender
#
#slim_el_recommender = MultiThreadSLIM_SLIMElasticNetRecommender(data_train, verbose=False)
#slim_el_recommender.fit(alpha=0.003495947934879827, 
#                        topK=531, 
#                        l1_ratio=0.0030148508221821105)
#
#[alpha: 0.003495947934879827, topK: 531, l1_ratio: 0.0030148508221821105]

# %%
user_id=50

# %%
slim_bpr_score = slim_bpr_recommender._compute_item_score(user_id).flatten()
slim_bpr_score
# Out:
# array([0.        , 0.00711592, 0.00860063, ..., 0.        , 0.        ,
#        0.        ])

# %%
rp3beta_score = rp3beta_recommender._compute_item_score(user_id).flatten()
rp3beta_score
# Out:
# array([0.        , 0.06496861, 0.        , ..., 0.        , 0.        ,
#        0.        ])

# %%
import seaborn as sns
from numpy import linalg as LA
import matplotlib.pyplot as plt

l1_slim_bpr = LA.norm([slim_bpr_score], 1)
l1_slim_bpr_scores = slim_bpr_score / l1_slim_bpr

l2_slim_bpr = LA.norm([slim_bpr_score], 2)
l2_slim_bpr_scores = slim_bpr_score / l2_slim_bpr

linf_slim_bpr = LA.norm(slim_bpr_score, np.inf)
linf_slim_bpr_scores = slim_bpr_score / linf_slim_bpr

lminusinf_slim_bpr = LA.norm(slim_bpr_score, -np.inf)
lminusinf_slim_bpr_scores = slim_bpr_score / lminusinf_slim_bpr

print(slim_bpr_score, l1_slim_bpr, l2_slim_bpr, linf_slim_bpr, lminusinf_slim_bpr)

_ = plt.figure(figsize=(16,7))
ax = sns.scatterplot(data=slim_bpr_score)
ax = sns.scatterplot(data=l1_slim_bpr_scores) 
ax = sns.scatterplot(data=l2_slim_bpr_scores) 
ax = sns.scatterplot(data=linf_slim_bpr_scores) 
ax = sns.scatterplot(data=lminusinf_slim_bpr_scores) 
ax.legend(["slim_bpr Score", "L1 Scores", "L2 Scores", "LInf Scores", "LMinusInf Scores"])
# Out:
# [0.         0.00711592 0.00860063 ... 0.         0.         0.        ] 0.02812575944699347 0.10784300686095293 0.02812575944699347 0.0
# C:\Users\Francesco1\AppData\Local\Temp\ipykernel_2136\1317543415.py:15: RuntimeWarning: divide by zero encountered in divide
#   lminusinf_slim_bpr_scores = slim_bpr_score / lminusinf_slim_bpr
# C:\Users\Francesco1\AppData\Local\Temp\ipykernel_2136\1317543415.py:15: RuntimeWarning: invalid value encountered in divide
#   lminusinf_slim_bpr_scores = slim_bpr_score / lminusinf_slim_bpr

# %%
l1_rp3beta = LA.norm(rp3beta_score, 1)
l1_rp3beta_scores = rp3beta_score / l1_rp3beta

l2_rp3beta = LA.norm(rp3beta_score, 2)
l2_rp3beta_scores = rp3beta_score / l2_rp3beta

linf_rp3beta = LA.norm(rp3beta_score, np.inf)
linf_rp3beta_scores = rp3beta_score / linf_rp3beta

lminusinf_rp3beta = LA.norm(rp3beta_score, -np.inf)
lminusinf_rp3beta_scores = rp3beta_score / lminusinf_rp3beta

print(rp3beta_score, l1_rp3beta, l2_rp3beta, linf_rp3beta, lminusinf_rp3beta)

_ = plt.figure(figsize=(16,9))
ax = sns.scatterplot(data=rp3beta_score)
ax = sns.scatterplot(data=l1_rp3beta_scores) 
ax = sns.scatterplot(data=l2_rp3beta_scores) 
ax = sns.scatterplot(data=linf_rp3beta_scores) 
ax = sns.scatterplot(data=lminusinf_rp3beta_scores) 
ax.legend(["rp3beta Score", "L1 Scores", "L2 Scores", "LInf Scores", "LMinusInf Scores"])
# Out:
# [0.         0.06496861 0.         ... 0.         0.         0.        ] 12.804430795063972 0.8246175518100011 0.21698849850958996 0.0
# C:\Users\Francesco1\AppData\Local\Temp\ipykernel_2136\2849860516.py:11: RuntimeWarning: divide by zero encountered in divide
#   lminusinf_rp3beta_scores = rp3beta_score / lminusinf_rp3beta
# C:\Users\Francesco1\AppData\Local\Temp\ipykernel_2136\2849860516.py:11: RuntimeWarning: invalid value encountered in divide
#   lminusinf_rp3beta_scores = rp3beta_score / lminusinf_rp3beta

# %%
lambda_weights = 0.66

l1_new_scores = lambda_weights * l1_rp3beta_scores + (1 - lambda_weights) * l1_slim_bpr_scores
l2_new_scores = lambda_weights * l2_rp3beta_scores + (1 - lambda_weights) * l2_slim_bpr_scores
linf_new_scores = lambda_weights * linf_rp3beta_scores + (1 - lambda_weights) * linf_slim_bpr_scores
lminusinf_new_scores = lambda_weights * lminusinf_rp3beta_scores + (1 - lambda_weights) * lminusinf_slim_bpr_scores

_ = plt.figure(figsize=(16,9))
ax = sns.scatterplot(data=l1_new_scores)
ax = sns.scatterplot(data=l2_new_scores) 
ax = sns.scatterplot(data=linf_new_scores) 
ax = sns.scatterplot(data=lminusinf_new_scores) 
ax.legend(["L1 Scores", "L2 Scores", "LInf Scores", "LMinusInf Scores"])

# %%
from Recommenders.BaseRecommender import BaseRecommender
import scipy.sparse as sps

class DifferentLossScoresHybridRecommender(BaseRecommender):
    """ ScoresHybridRecommender
    Hybrid of two prediction scores R = R1/norm*alpha + R2/norm*(1-alpha) where R1 and R2 come from
    algorithms trained on different loss functions.

    """

    RECOMMENDER_NAME = "DifferentLossScoresHybridRecommender"


    def __init__(self, URM_train, recommender_1, recommender_2):
        super(DifferentLossScoresHybridRecommender, self).__init__(URM_train)

        self.URM_train = sps.csr_matrix(URM_train)
        self.recommender_1 = recommender_1
        self.recommender_2 = recommender_2
        
        
        
    def fit(self, norm, alpha = 0.5):

        self.alpha = alpha
        self.norm = norm


    def _compute_item_score(self, user_id_array, items_to_compute):
        
        item_weights_1 = self.recommender_1._compute_item_score(user_id_array)
        item_weights_2 = self.recommender_2._compute_item_score(user_id_array)

        norm_item_weights_1 = LA.norm(item_weights_1, self.norm)
        norm_item_weights_2 = LA.norm(item_weights_2, self.norm)
        
        
        if norm_item_weights_1 == 0:
            norm_item_weights_1 = 0.0000001
            #raise ValueError("Norm {} of item weights for recommender 1 is zero. Avoiding division by zero".format(self.norm))
        
        if norm_item_weights_2 == 0:
            norm_item_weights_2 = 0.0000001
            #raise ValueError("Norm {} of item weights for recommender 2 is zero. Avoiding division by zero".format(self.norm))
        
        item_weights = item_weights_1 / norm_item_weights_1 * self.alpha + item_weights_2 / norm_item_weights_2 * (1-self.alpha)

        return item_weights

# %%
def objective(trial):
    norm = trial.suggest_categorical("norm", [1, 2, np.inf, -np.inf])

    recommender_object = DifferentLossScoresHybridRecommender(data_train, slim_bpr_recommender, rp3beta_recommender)
    recommender_object.fit(
        norm = norm, 
        alpha = 0.66)

    _, _, ev_map, _, _ = evaluator(recommender_object, data_train, data_val)
    
    return ev_map

rat_rank_study.optimize(objective, n_trials=150)
# Out:
# DifferentLossScoresHybridRecommender: URM Detected 218 ( 1.7%) users with no interactions.
# DifferentLossScoresHybridRecommender: URM Detected 100 ( 0.5%) items with no interactions.
# [I 2024-01-06 15:17:19,217] Trial 0 finished with value: 0.09968723203037815 and parameters: {'norm': 2}. Best is trial 0 with value: 0.09968723203037815.
# DifferentLossScoresHybridRecommender: URM Detected 218 ( 1.7%) users with no interactions.
# DifferentLossScoresHybridRecommender: URM Detected 100 ( 0.5%) items with no interactions.
# [I 2024-01-06 15:17:29,257] Trial 1 finished with value: 0.11896544669102167 and parameters: {'norm': -inf}. Best is trial 1 with value: 0.11896544669102167.
# DifferentLossScoresHybridRecommender: URM Detected 218 ( 1.7%) users with no interactions.
# DifferentLossScoresHybridRecommender: URM Detected 100 ( 0.5%) items with no interactions.
# [I 2024-01-06 15:17:39,474] Trial 2 finished with value: 0.09607502434042371 and parameters: {'norm': 1}. Best is trial 1 with value: 0.11896544669102167.
# DifferentLossScoresHybridRecommender: URM Detected 218 ( 1.7%) users with no interactions.
# DifferentLossScoresHybridRecommender: URM Detected 100 ( 0.5%) items with no interactions.
# [I 2024-01-06 15:17:49,373] Trial 3 finished with value: 0.11896544669102167 and parameters: {'norm': inf}. Best is trial 1 with value: 0.11896544669102167.
# DifferentLossScoresHybridRecommender: URM Detected 218 ( 1.7%) users with no interactions.
# DifferentLossScoresHybridRecommender: URM Detected 100 ( 0.5%) items with no interactions.
# [I 2024-01-06 15:17:59,218] Trial 4 finished with value: 0.11896544669102167 and parameters: {'norm': -inf}. Best is trial 1 with value: 0.11896544669102167.
# DifferentLossScoresHybridRecommender: URM Detected 218 ( 1.7%) users with no interactions.
# DifferentLossScoresHybridRecommender: URM Detected 100 ( 0.5%) items with no interactions.
# [I 2024-01-06 15:18:08,983] Trial 5 finished with value: 0.11896544669102167 and parameters: {'norm': -inf}. Best is trial 1 with value: 0.11896544669102167.
# DifferentLossScoresHybridRecommender: URM Detected 218 ( 1.7%) users with no interactions.
# DifferentLossScoresHybridRecommender: URM Detected 100 ( 0.5%) items with no interactions.
# [I 2024-01-06 15:18:19,006] Trial 6 finished with value: 0.09607502434042371 and parameters: {'norm': 1}. Best is trial 1 with value: 0.11896544669102167.
# DifferentLossScoresHybridRecommender: URM Detected 218 ( 1.7%) users with no interactions.
# DifferentLossScoresHybridRecommender: URM Detected 100 ( 0.5%) items with no interactions.
# [W 2024-01-06 15:18:27,757] Trial 7 failed with parameters: {'norm': 2} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\Francesco1\miniconda3\envs\RecSysFramework\lib\site-packages\optuna\study\_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\Francesco1\AppData\Local\Temp\ipykernel_2136\161391165.py", line 9, in objective
#     _, _, ev_map, _, _ = evaluator(recommender_object, data_train, data_val)
#   File "c:\Users\Francesco1\Desktop\rcs\utils.py", line 146, in evaluator
#     recommendations = np.array(recommender.recommend(user_id,
#   File "c:\Users\Francesco1\Desktop\rcs\Recommenders\BaseRecommender.py", line 169, in recommend
#     relevant_items_partition = np.argpartition(-scores_batch, cutoff-1, axis=1)[:,0:cutoff]
# KeyboardInterrupt
# [W 2024-01-06 15:18:27,759] Trial 7 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 13
#       9     _, _, ev_map, _, _ = evaluator(recommender_object, data_train, data_val)
#      11     return ev_map
# ---> 13 rat_rank_study.optimize(objective, n_trials=150)
#
# File c:\Users\Francesco1\miniconda3\envs\RecSysFramework\lib\site-packages\optuna\study\study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File c:\Users\Francesco1\miniconda3\envs\RecSysFramework\lib\site-packages\optuna\study\_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File c:\Users\Francesco1\miniconda3\envs\RecSysFramework\lib\site-packages\optuna\study\_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File c:\Users\Francesco1\miniconda3\envs\RecSysFramework\lib\site-packages\optuna\study\_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File c:\Users\Francesco1\miniconda3\envs\RecSysFramework\lib\site-packages\optuna\study\_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[32], line 9, in objective(trial)
#       4 recommender_object = DifferentLossScoresHybridRecommender(data_train, slim_bpr_recommender, rp3beta_recommender)
#       5 recommender_object.fit(
#       6     norm = norm,
#       7     alpha = 0.66)
# ----> 9 _, _, ev_map, _, _ = evaluator(recommender_object, data_train, data_val)
#      11 return ev_map
#
# File c:\Users\Francesco1\Desktop\rcs\utils.py:146, in evaluator(recommender, data_train, data_test, recommendation_length)
#     143     num_users_skipped += 1
#     144     continue
# --> 146 recommendations = np.array(recommender.recommend(user_id,
#     147                                         cutoff=recommendation_length))
#     149 accum_precision += precision(recommendations, relevant_items)
#     150 accum_recall += recall(recommendations, relevant_items)
#
# File c:\Users\Francesco1\Desktop\rcs\Recommenders\BaseRecommender.py:169, in BaseRecommender.recommend(self, user_id_array, cutoff, remove_seen_flag, items_to_compute, remove_top_pop_flag, remove_custom_items_flag, return_scores)
#     162     scores_batch = self._remove_custom_items_on_scores(scores_batch)
#     164 # Sorting is done in three steps. Faster then plain np.argsort for higher number of items
#     165 # - Partition the data to extract the set of relevant items
#     166 # - Sort only the relevant items
#     167 # - Get the original item index
#     168 # relevant_items_partition is block_size x cutoff
# --> 169 relevant_items_partition = np.argpartition(-scores_batch, cutoff-1, axis=1)[:,0:cutoff]
#     171 # Get original value and sort it
#     172 # [:, None] adds 1 dimension to the array, from (block_size,) to (block_size,1)
#     173 # This is done to correctly get scores_batch value as [row, relevant_items_partition[row,:]]
#     174 relevant_items_partition_original_value = scores_batch[np.arange(scores_batch.shape[0])[:, None], relevant_items_partition]
#
# KeyboardInterrupt:

# %%
rat_rank_study.best_params
# Out:
# {'norm': -inf}

# %%
recommender_object = DifferentLossScoresHybridRecommender(data_train, slim_bpr_recommender, rp3beta_recommender)
recommender_object.fit(**rat_rank_study.best_params)
# Out:
# DifferentLossScoresHybridRecommender: URM Detected 218 ( 1.7%) users with no interactions.
# DifferentLossScoresHybridRecommender: URM Detected 100 ( 0.5%) items with no interactions.

# %%
submission2(recommender_object, users, usermap, itemmap, data_train)
# Out:
# TopPopRecommender: URM Detected 218 ( 1.7%) users with no interactions.
# TopPopRecommender: URM Detected 100 ( 0.5%) items with no interactions.
